# %% [markdown]
# # Few-shot translation with a language model
#
# - [ ] Zip together the source and target sentences into a single list of tuples.
# - [ ] Split the data into train and test sets.
# - [ ] Store the sentences in a Chroma vectorstore.
# - [ ] Move through the test sentences one at a time.
# - [ ] Use LangChain to dynamically feed similar examples to the current sentence on the fly.
# - [ ] Use OpenAI's LLM for annotating new translations on the test sentences using the examples.
# - [ ] Backtranslate the results to the source language without seeing the original translations.
# - [ ] Compare the resulting target translation and back-translated source to the original sentence pair.

# %%
# !pip install kor
# Out:
# Collecting kor
#   Using cached kor-0.9.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: langchain>=0.0.110 in /opt/homebrew/lib/python3.10/site-packages (from kor) (0.0.177)
# Requirement already satisfied: openai<0.28,>=0.27 in /opt/homebrew/lib/python3.10/site-packages (from kor) (0.27.6)
# Requirement already satisfied: pandas<2.0.0,>=1.5.3 in /opt/homebrew/lib/python3.10/site-packages (from kor) (1.5.3)
# Requirement already satisfied: PyYAML>=5.4.1 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (2.0.13)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (0.5.7)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (1.23.5)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (1.2.4)
# Requirement already satisfied: pydantic<2,>=1 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (1.10.7)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (2.30.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/homebrew/lib/python3.10/site-packages (from langchain>=0.0.110->kor) (8.2.2)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.10/site-packages (from openai<0.28,>=0.27->kor) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/ryderwishart/Library/Python/3.10/lib/python/site-packages (from pandas<2.0.0,>=1.5.3->kor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas<2.0.0,>=1.5.3->kor) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.110->kor) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.110->kor) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.110->kor) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.110->kor) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.110->kor) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain>=0.0.110->kor) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /opt/homebrew/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain>=0.0.110->kor) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /opt/homebrew/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain>=0.0.110->kor) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /opt/homebrew/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain>=0.0.110->kor) (0.8.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/homebrew/lib/python3.10/site-packages (from pydantic<2,>=1->langchain>=0.0.110->kor) (4.5.0)
# Requirement already satisfied: six>=1.5 in /Users/ryderwishart/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.5.3->kor) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2->langchain>=0.0.110->kor) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2->langchain>=0.0.110->kor) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests<3,>=2->langchain>=0.0.110->kor) (2023.5.7)
# Requirement already satisfied: packaging>=17.0 in /Users/ryderwishart/Library/Python/3.10/lib/python/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain>=0.0.110->kor) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.10/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain>=0.0.110->kor) (1.0.0)
# Installing collected packages: kor
# Successfully installed kor-0.9.2

# %%
# Import required libraries
import openai
from kor import create_extraction_chain, Object, Text
from langchain.chat_models import ChatOpenAI
from sklearn.model_selection import train_test_split
from langchain.vectorstores import Chroma
import os
import json

# %%
import getpass
secret_key = getpass.getpass('Enter OpenAI secret key: ')
os.environ['OPENAI_API_KEY'] = secret_key

# %% [markdown]
# ## Scrape some target language data

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Using cached bs4-0.0.1-py3-none-any.whl
# Collecting beautifulsoup4 (from bs4)
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Using cached soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.12.2 bs4-0.0.1 soupsieve-2.4.1

# %%
import requests
from bs4 import BeautifulSoup
import json

def scrape_url(url, chapter_number):
    # Send a get request to the webpage
    response = requests.get(url)

    # Parse the response text with BeautifulSoup using the html.parser
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the 'chapter justify' div
    chapter_div = soup.find('div', class_='chapter justify')

    # chapter looks like """<div class="chapter justify"><span class="drop-caps">1</span>"""
    chapter = chapter_div.find('span', class_='drop-caps').text
    
    # Find all span elements with the class 'align-left' in the div
    verse_spans = chapter_div.find_all('span', class_='align-left')

    # Extract chapter, verse, and text from each span and store in a dictionary
    verse_dicts = []
    for span in verse_spans:
        verse = span['data-verseid']
        text = span.find('span', {'data-verseid': verse}).text
        verse_dicts.append({'ch': str(chapter_number), 'v': verse, 'text': text})
        print(chapter_number, verse, text)
    # Convert list of dictionaries to json
    # verse_json = json.dumps(verse_dicts)
    
    return verse_dicts

# Replace this with your actual URL
url = "http://live.bible.is/bible/ABMTSC/LUK/"

target_verses = []
# Luke has 24 chapters
for i in range(1, 25):
    # print(scrape_url(url + str(i)))
    # break
    target_verses.append(scrape_url(url + str(i), i))

print(len(target_verses))
# Out:
# 1 1 Tiyɔfilɔs agbem anɛ agba nɔg ayɛlɛ nsɔl yi ɛlɔ lem na agira.
# 1 2 Ɛyog nsɔl yifa na anyɔ anɛ ba akɔlɔ amir abɔ ayɛn nsɔl yi ɛlemɔ na ɛkuma nub na anɛ ba abongɔ alom Ɔsɔwɔ.
# 1 3 Mɛ ngba nar biji nkpele nsɔl fɛb na ɛkuma nub ntamɛ ntu ɛlama ndɛ mɛ nyɛlɛ nsɔl yifɔ jangjang mɔng ɛjɔlɔ Tiyɔfilɔs.
# 1 4 Mɛ nem jifa na ji wɔ ɔla kun ɛtete ɔbangɛ kpakpa nsɔl yi alɔ wa teb.
# 1 5 Ngara yi Hɛrɔd ajɔlɔ ntol na Judiya ɛbɛl nemanjɔm Ɔsɔwɔ yɔ ajɔl wɛ kog arɛ Sakariya yɔ ajogɔ na ɔgu bi balemanjɔm Ɔsɔwɔ bi Abija. Nkal ɔwɛ Ɛlisabɛt ajog ɔgu bi Ɛrɔng.
# 1 6 Abɔ anɛ abalabal ajɔl ateng anɛ na libri Ɔsɔwɔ afɛng ajɔ bom ajing ya Tata na ajigi ayɛ.
# 1 7 Abɔ abɔn agbɛlam, ateb arɛ Ɛlisabɛt amalam ayibi ɔla. Abɔ anɛ abal abal agba kol.
# 1 8 Ɔfo brang ɛbɔngɛ balemanjɔm Ɔsɔwɔ ji Sakariya ajɔl na litom, ajɔl jege Ɔsɔwɔ mɔng nemanjɔm.
# 1 9 Mɔng ligbɛna li balemanjɔm Ɔsɔwɔ, atob lifanga ayege Sakariya arɛ asɔng na njo Ɔsɔwɔ ɔfo bifɔ aji sɔ nsɔl yi ɛkpenɔ ɛteng ɛlu akarɛ Ɔsɔwɔ.
# 1 10 Anɛ ajɔl kag ɔrɔ na ɛtegla na ji ajɔl sɔ nsɔl yi ɛkpenɔ ɛteng ɛlu.
# 1 11 Na ngara yi fɔ nteb ɔteb a Tata alima aba naji Sakariya ayema na ɔbɔ bilom bi ɛkun Ɔsɔwɔ ji asɔga ateng a nsɔl ya akpenɔ ɛteng ɛlu.
# 1 12 Sakariya agbɔ ɔjɔb ɛkokob ɛbɔbɛ na ji ayɛnɔ nteb ɔteb Ɔsɔwɔ.
# 1 13 Nteb ɔteb Ɔsɔwɔ abong atɔgɛ arɛ, “Sakariya! Ɔtɔb kpɛ bɛ, Ɔsɔwɔ agba yog ɔrɔ ɛba. Nkal ɔwa Ɛlisabɛt ala gbɛl mɔn yɔ ɔlom ɔlɛ gore mbeng a Jɔn.
# 1 14 Mɔn ɔfa ala jɔl ɛyɛbalitem na liranga akarɛ ɛgbem anɛ ala rang na ɔgbɛl ɛbɛ.
# 1 15 Ala jɔl ntakpa nɛ na libri Tata. Anim teg awɔ amum ayiayi ɛjɔl akora amum ɛkɔ ji mbara ɛtugi ɛla jɔl na nɛ na ngara yi alɛ gbɛl.
# 1 16 Jɔn alatu agbem anɛ ba Isrɛl afɛngɛ na ji Tata Ɔsɔwɔ abɔ.
# 1 17 Ala gbɔ Tata mba, na ɛkɔ na ɛtugi mɔng Ɛlayija, ateb ɛsi ɛjɛ, ala sibe ntem ba ndɛ atu abɔn. Anɛ ba akoresi ala lem abɔ atamɛ na anɛ ba akpenɔ ɛkukuna ji anɛ ba alema nɔba, ala tore anɛ abom Tata.”
# 1 18 Sakariya abong atɔg nteb ɔteb Ɔsɔwɔ, “Mɛ nalem nan nkun? Ateb mɛ na nkalɔma ɛgba kol.”
# 1 19 Nteb ɔteb Ɔsɔwɔ afanga wɛ, “Mɛ Gɛbrɛl, mɛ nyim na libri Ɔsɔwɔ.Wɛ atom mam arɛ ntebe wa ɛteng ɔteb.
# 1 20 Na ji ɔdɛnɔ tamɛ ɔteb ɛbama ɔgbɔ ɛmum ɔnim kpɛ mal ɔbong ntɔga tɛtɛ ji ntɔgɔ wa ɛlem.”
# 1 21 Ɛbɔngɛ anɛ ba ajɔl seg Sakariya ɛkpɔ abɔ ɛsi na ji alɔ lɛna na Njo Ɔsɔwɔ.
# 1 22 Naji ajogɔ amalam abong ntɔga abɔ akukun arɛ agba yɛn amir na Njo Ɔsɔwɔ, wɛ ajɔl fuk abɔ amalam abong ntɔga.
# 1 23 Naji litom Sakariya ɛlɔ mal na Njo Ɔsɔwɔ afɛngɛ njim na ɛtɛk.
# 1 24 Naji jifɔ ɛlɔ seng Ɛlisabɛt ajɔl na ɔla, ategam ajog na ɛtekla na anwɛ arɔn, wɛ abong,
# 1 25 “Tata agba lem jifa akam, agba mam teb ndɔn ɛyɛ agba mam yege ɛsɔnɛ na amir anɛ.”
# 1 26 Naji ɔla Ɛlisabɛt ɛlɔ rir anwɛ aragra Ɔsɔwɔ atom nteb ɔteb a Gɛbrɛl na ɛkpa ɛgbɛ Nasarɛt na Ɛjiba Galili,
# 1 27 naji nɛ yɔ adɛdɛ sib nɛnom, yɔ alagɔ nɔ bal Josɛf yɔ ajogɔ ɔgu bi Defid. Nɛ yɔ adɛdɛ sib nɛ akoga wɛ arɛ Meri.
# 1 28 Nteb ɔteb akak Meri nyɔ abong, lifola Tata ɛre na na.
# 1 29 Meri abɛl ɛkokob abangɛ alom ya nteb ɔteb abongɔ ɛfɛngɛ ɛkpɔ wɛ ɛsi bi nyɔ kag kag bifa ɛjogɔ.
# 1 30 Fɔyɔ nteb ɔteb Ɔsɔwɔ atɔgɔ Meri arɛ, “Ɔtɔb kpɛ bɛ; Ɔsɔwɔ akpe ɛyɛbalitem na na.
# 1 31 Wɔ ɔla yibi ɔla ɔgbɛl mɔn yɔ ɔlom, ɔlɛ gore mbeng a Jisɔs.
# 1 32 Ala jɔl ntakpa nɛ ajɔ kogɛ Mɔn a Ɔsɔwɔ bi Ɛyurɔyura. Tata Ɔsɔwɔ alɛ kone ɔtol, mɔng nsɔjɛ yɔ ɔkol Defid.
# 1 33 Ala fele anɛ ba Jɛkɔb na nsinsi ɛjiba ɔtol ɛbɛ ɛnim teg ɛbɛl nkulsi.”
# 1 34 Meri abib nteb ɔteb Ɔsɔwɔ, “Mɛ nɛnom nka sibam, jifa ɛla lem nan ɛleba?”
# 1 35 Nteb ɔteb Ɔsɔwɔ afanga wɛ, “Mbara Ɛtugi ala bole, ɛkɔ Ɔsɔwɔ ji ɛgalɔyura ɛla jɔl nana, ateb arɛ mbara mɔn yɔ ɔlom yɔ ɔla gbɛl alɛ kog arɛ mɔn Ɔsɔwɔ.
# 1 36 Ɛjɔl Ɛlisabɛt nɛ a nub ɔwa ala gbɛl mɔn na ɔkol, ajɔl bong arɛ wɛ ngom batig ɔla ɛbɛ ɛgba rir anwɛ aragra.
# 1 37 Ateb arɛ ɛjom sang ji Ɔsɔwɔ adɛ mal alem.”
# 1 38 Meri afanga, “Mɛ ndɔgalitom a Tata yɔ nɔng ɛjɔl anɔ mɔng ɔbongɔ.” Nteb ɔteb Ɔsɔwɔ atumɛ asa.
# 1 39 Na ngara yifɔ Meri asubi aji na ɛkpa ɛgbɛ ji ɛrenɔ na mfom a ɛwɔng ɛlagɛ ɛjiba Judiya.
# 1 40 Ayɛl na ɛtɛk Sakariya aji kag Ɛlisabɛt nyɔ.
# 1 41 Naji Ɛlisabɛt ayogɔ nyɔ bi Meri akagɔ, mɔn a Ɛlisabɛt atumɛ na ala, Mbara Ɛtugi aror wɛ.
# 1 42 Ɛlisabɛt akɔn na nyura lilom atɔgɛ: “Na lirɔng abakal wɔ yɔ ɔgalɔ bɛl lifola, lifola ɛjɔl ɛkarɛ mɔn yɔ ɔla gbɛl!
# 1 43 Fa ba ntakpa ɔfa yi nɔ ter ɛla ker nan nyɛn Tata aba rebam?
# 1 44 Naji nyogɔ nyɔ ɛba, mɔn yɔ ayɔbɔ na ala atum na ɛyɛbalitem.
# 1 45 Lifola ɛjɔl na nɛ yɔ akpenɔ ntamɛ arɛ ji Tata abongɔ ɛla lelem.”
# 1 46 Meri abong, “Litem ɛlama jige Tata.
# 1 47 Ɛtugi ɛjama ɛkpe ɛyɛba litem na Ɔsɔwɔ Nyanyangɛ ɔma.
# 1 48 Ateb arɛ wɛ ali gbɔ nter ɛma nɛ a ndɔn a ndɔgalitom ɔwɛ, bɔm batig anɛ kpakpa alam kog arɛ lifola.
# 1 49 Ateb Ɔsɔwɔ yɔ agalɔ jɔg agba lem atakpa nsɔl akam, mbeng ɛyɛ ajɔl mbara.
# 1 50 Bɔm na ɛkuma nub ɛyeng ɔlome na ɛyeng nkulsi sang, wɛ abɛl ndɔn na anɛ ba abɛga wɛ.
# 1 51 Tata agba lem akpɔga ɛsi a nsɔl na abɔ ayɛ, agba yama anɛ ba atababiji na ntem abɔ.
# 1 52 Agba budi atakpa atol na nji abɔ, atab akugbɛn ayura.
# 1 53 Akarɛ anɛ ba njal ateng a nsɔl, akam afang anɛ abɔ abɔ.
# 1 54 Agba nyangɛ ndɔgalitom ɔwɛ Isrɛl, agbɔ nter ɛsig a nyɔ ji ndɔn.
# 1 55 Asig Ɛbram nyɔ ndɔn na nub ɛyɛ na nsinsi.”
# 1 56 Meri akar na Ɛlisabɛt mɔng anwɛ ara, nig afɛngɛ akuri na ɛtɛk.
# 1 57 Na ngara yi ɔgbɛl bi Ɛlisabɛt ɛrirɔ, agbɛl mɔn yɔ ɔlom.
# 1 58 Na ji anɛ ba nkɔn tɛk na abɔnyɛn ayogɔ arɛ Tata agba wɛ teb ntakpa ndɔn, abɛl ɛyɛbalitem na nɛ.
# 1 59 Naji mɔn alɔ akar mfo ɛnigni, abɔ fɛb abal arɛ aba lemɛ ɔjangkon, agara arɛ akarɛ mbeng yi Sakariya, yi ndɛ.
# 1 60 Ɛlisabɛt atɛn arɛ, “Mɔn ala nyina Mbeng a Jɔn.”
# 1 61 Abong atɔgɛ arɛ, “Mbeng yi fɔ Jɔn aream na nub ɛya.”
# 1 62 Akɔ abɔ abib Sakariya asɛba mbeng a mɔn yi akɔrɔ wɛ.
# 1 63 Sakariya abib arɛ akarɛ ɛjom wɛ ayɛlɛ, ayɛlɛ arɛ, “Mbeng ɛyɛ anyina arɛ Jɔn.” Ɛkpɔ abɔ ɛsi!
# 1 64 Fɔtutu Sakariya nyɔ ɛribi lirebe ɛfungi abɔm ntɔga mbonga, atiga Ɔsɔwɔ.
# 1 65 Ɛkokob ɛjɔl na anɛ ba nkɔn tɛk, ɛteng ɛka jifa ɛnyada na bijiba bi ɛkonɔ na biwɔng bi Judiya.
# 1 66 Nɛ yɔ ayogɔ abangɛ nsɔl yi ɛlemɔ akɛrɛ abib, “Bɛ ɛjom ji mɔn yɔfa abaga njɔla?” Na ɛtete ɔbɔ bi Tata ɛre nanɛ.
# 1 67 Ndɛ Jɔn, Sakariya aror na Mbara Ɛtugi, abong alom Ɔsɔwɔ:
# 1 68 “Baba wur ɛtig Tata Ɔsɔwɔ bi Isrɛl! ateb wɛ agba ba naji anɛ abɛ arɛ aba nyangɛ abɔ.
# 1 69 Agba tom ntakpa Nyanyangɛ, yɔ arunɔ ɔgu bi ndɔgalitom ɔwɛ ntol a Defid.
# 1 70 Agba sik nyɔ mba angɔ atɔg abara bayɛn amir Ɔsɔwɔ.
# 1 71 Ala wur nyangɛ na abɔ anɛ ba ajing abira na anɛ ba agbaga wur.
# 1 72 Asig nyɔ arɛ ala bɛl ndɔn na anɛ bakol ala tɔb agbɔ nter yi mbara ɛnwɔngɛ.
# 1 73 Ɛsiga nyɔ ji akɔlɔ na nsɔjira Ɛbram:
# 1 74 Ala wur yege na abɔ ya anɛ ba ɔjing abra, na ji ɛmal ɛrɔgɛ wɛ ɛdɛ bɛl ɛkokob.
# 1 75 Na ji wur ɛla jɔl mbara na ntɔra ligbɛna na libri ɛlɛ na kpakpa afo a likpen ɛlira.
# 1 76 “Wɔ mɔn ɔma ɔla jɔl nyɛn amir yɔ Ɔsɔwɔ bi Ɛyurɔyura; wɔ ɔlaji na osi bi Tata ɔji tore mba ɔbomɛ.
# 1 77 Ala lem anɛ abɛ akun arɛ ala bɛl ɔnyangɛ, ala tum akarɛ abɔ na abeɔfɛm.
# 1 78 Ateb arɛ Ɔsɔwɔ ɛbra akpe ndɔn. ji ɛla tɔna fɔ liro ɛlɛ ɛla ba na agra mɔng njol yi ayaga na libo.
# 1 79 Liro ɛla jɔl ɛkarɛ anɛ ba arenɔ na ɛjingi na ɛtugi akuanɛ, ɛfɛng ɛbabɛ aja ayira atu na mba likɔna.”
# 1 80 Mɔn ɔfɔ abenga akore na ɛtugi, ajɔl na ɛkpelele tɛtɛ aji teb ɛlɛ na ɛtekla ɛgor Isrɛl.
# 2 1 Na ngara yi fɔ ntakpa ntol a Rom Ɔgɔstus akarɛ ɛjigi arɛ afal anɛ na bijiba Rom.
# 2 2 Fɔ yɔ ajɔlɔ ngbɔgamba ɛfala anɛ bɔm na ji Kwiriniyus ajɔlɔ ntol a Siriya.
# 2 3 Anɛ kpakpa atum aji na bijiba abɔ arɛ aji kag abeng.
# 2 4 Fɔ yɔ Josɛf atumɔ lijɛn na Nasarɛt ji Galili, arir Bɛtlɛm ji Judiya, ɛjiba ntola Defid, ateb arɛ wɛ Josɛf aru ɔgu bifɔ bi Defid.
# 2 5 Ajil fɔ na Mɛri, arɛ aji kag mbeng yɔ wɛ akɔlɔ mɔng nkal, Meri ɔla ɛgba kol ɛrir na ngbɛla.
# 2 6 Aji abɔ ajɔlɔ fɔ, ngara ɔgbɛl arir.
# 2 7 Mɛri agbɛl mgbɔga mba mɔn yɔ ɔlom. Akɔ abɔma afu wɛ atabɛ akak na ɛkpagnte ɛliga nsɔl ɔjɔra, ateb ɛyaga ɛjɔlam na ɛtɛk ajɛna nɛ.
# 2 8 Alagtu afɔ, ba babɛ ɔjɔra ajɔl na ɛmɛ alagɛ Bɛtlɛm ababɛ ɔjɔra abɔ.
# 2 9 Nteb ɔteb a Tata ajil ajog naji abɔ, liloba li Tata ɛbole abɔ, ɛkokob ɛbɔb abɔ.
# 2 10 Nteb ɔteb Ɔsɔwɔ abong atɔg abɔ, “Wun ɔtɔb kpɛ bɛ! Mbal na ɛteng ɔteb nkarɛ bi ɛla karɛ anɛ kpakpa ntakpa ɛyɛbalitem.
# 2 11 Ɛlɛl na ɛjiba Defid aligbɛl nyanyangɛ akarɛ wun, wɛ yɔ arɛ nɔ Krayis Tata.
# 2 12 Wun ɔla yɛn ndenge yi fa: Ɔla yɛn mɔn na ji alɔ wɛ fu abɔma abomɛ na ɛkpagnte ji ɔjɔra ɛliga nsɔl.”
# 2 13 Fɔ tutu ɛbɔngɛ ba tebe ɔteb Ɔsɔwɔ, abal akpa na nteb ɔteb yɔnga ajege Ɔsɔwɔ abonga,
# 2 14 “Lijega ɛjɔl na Ɔsɔwɔ na libonta, likɔna ɛjɔl na anɛ ba nde ba linɔba ɛlɛ ɛrenɔ ɛkarɛ abɔ.”
# 2 15 Na ji bateb ɔteb Ɔsɔwɔ alɔ tum abɔ asa afɛngɛ njim ajɛn na libonta, ba babe ɔjɔra akuma mbonga atɔga atɛm, “Ɛjɛn na Bɛtlɛm ɛji yɛn nsɔl yi ɛlɔ lem ji Tata alɔ wur tɔg.”
# 2 16 Abɔ asubi ajɛn aji yɛn Josɛf na Meri na mɔn, anɔngɔ na ɛkpagnte ji ɔjɔra ɛliga nsɔl.
# 2 17 Na ji ba babɛ ɔjɔra alɔ wɛ yɛn, atɔg abɔ ji nteb ɔteb Ɔsɔwɔ atɔgɔ abɔ abangɛ mɔn.
# 2 18 kpakpa anɛ ba ayogɔ ɔtɔga bifa bi ba babe ɔjɔra ɛkpɔl abɔ ɛsi.
# 2 19 Meri akak ɔtɔga bifɔ na litem afɛngɛ abɛl nkanter abangɛ.
# 2 20 Ba babɛ ɔjɔra afɛngɛ akuri, ajege, atiga Ɔsɔwɔ ateb ji abɔ ayogɔ afɛngɛ ayɛn na amir. Kpakpa nsɔl ɛjɔla anɔ mɔng ba tebe ɔteb Ɔsɔwɔ abongɔ.
# 2 21 Na mfo ɛnigni, alem wɛ ɔjangkon, agore wɛ mbeng a Jisɔs yi nteb ɔteb Ɔsɔwɔ akarɔ wɛ nig ayibi ɔla ɛbɛ.
# 2 22 Na ji ngara alɔ lome yi Josɛf na Meri alagɔnɔ lem ligbɛna li aroga li abɔ mɔng ajing a Mosis abongɔ, abɔ atab Jisɔs aji na Jɛrusɛlɛm na Njo Ɔsɔwɔ arɛ aji karɛ Tata.
# 2 23 mɔng ayɛlɔ na Ajing ya Tata, “Arɛ ngbɔgamba mɔn yɔ lom ajɔga ajɔla akarɛ Tata.”
# 2 24 Josɛf na Meri akarɛ ɛyarɛ mɔng Ajing a Tata abongɔ: “ɔdɛnɔ bɛl ɛmɛb bibal ɔkɔ ɛblagom bibal ɔlem ɛyarɛ ji fɔ.”
# 2 25 Ngara yi fɔ ɛbɛl nɛnom wurang na Jɛrusɛlɛm, akoga wɛ arɛ Simiyɔn, ajɔl ɛteng nɛ abɛga Ɔsɔwɔ. Ajɔl seg arɛ ayɛn nyanyangɛ Isrɛl. Ɛtugi Ɔsɔwɔ ɛjɔl na nɛ.
# 2 26 Ɛtugi Ɔsɔwɔ ɛtɔg wɛ arɛ anim teg akpɔ tɛtɛ wɛ ayɛn Krayis yɔ Tata asigɔ nyɔ.
# 2 27 Na ji Josɛf na Meri atabɔ Jisɔs arɛ aba lem mɔng ajing abongɔ, Ɛtugi Ɔsɔwɔ ɛtabɛ ɛji na Njo Ɔsɔwɔ.
# 2 28 Sayimɔn atab mɔn na abɔ ayɛ ajege Ɔsɔwɔ abonga,
# 2 29 Tata, ndɔgalitom ɔwa amal akpɔ batig na likɔna, ateb arɛ wɔ ɔgba lem ji ɔbongɔ.
# 2 30 Amir ama agba yɛn ɔnyangɛ ɛba,
# 2 31 Anɛ kpakpa ala yɛn.
# 2 32 Ɛla jɔl Liro ɛkarɛ anɛ ba Jɛntal,na liloba li anɛ aba Isrɛl.
# 2 33 Ndɛ na nyɛn mɔn ɛkpɔla bɔ ɛsi abangɛ ji abongɔ abangɛ wɛ.
# 2 34 Simiyɔn akarɛ abɔ lifola abong atɔg Meri ji nyɛn, “Ɔsɔwɔ agba rang mɔn ɔfa akarɛ ndungi na ɔnyangɛ ɛkarɛ agbem anɛ na Isrɛl. Ɛla jɔl ndenge yi Ɛgbem anɛ na Isrɛl ala bong abangɛ.
# 2 35 naji nkanter ɛgbem anɛ ala ribi. Wɔ Mɛri, ɔkankang ɛla yara litem.”
# 2 36 Ana nyɛn amir, atɔb ajɔl na Njo Ɔsɔwɔ. Ajɔl mɔn ɔkal yɔ Fanuwɛl, yɔ ajogɔ ɔgu bi Asa. Ajɔl ɛkpa kola nɛ,agba jɔl na libal na nya arima.
# 2 37 Ajɔl akpɔ asa na nya atila ani na ɛni, ɛfente na alagtu ajɔl kponi Ɔsɔwɔ na Njo Ɔsɔwɔ akaga ɔrɔ afɛngɛ ajɔla njal.
# 2 38 Ana titi abal akag Ɔsɔwɔ sam, abong abangɛ mɔn atɔg anɛ kpakpa ba ajɔlɔ seg Ɔsɔwɔ arɛ aba nyangɛ Jɛrusɛlɛm.
# 2 39 Josɛf na Meri alem ji Ajing a Tata abongɔ, afɛngɛ njim na Nasarɛt ɛjiba abɔ na Galili.
# 2 40 Jisɔs abenga afɛngɛ akore, abɛl ɛkukuna, lifola Ɔsɔwɔ ɛjɔl na nɛ.
# 2 41 Liya aliali nyɛn na ndɛ Jisɔs ajiga na Jɛrusɛlɛm na Likag li Aseng Asa.
# 2 42 Na ji Jisɔs alɔ rir nya woba na ɛbal, abɔ atɔna aji Likag mɔng ligbɛna ɛbongɔ.
# 2 43 Na ji Likag ɛlɔ mal, ndɛ na nyɛn atum akuri,mɔn ji Jisɔs asal na njim na Jɛrusɛlɛm abɔ akunam.
# 2 44 Abɔ akɛrɛ arɛ agba tɔna ɛbɔngɛ anɛ ba lijɛn akuri, ajɛn ɔfo kpukpul. Nig aji kuma wɛ nsɛba na ɛbɔngɛ abɔnyɛn na atɛm.
# 2 45 Na ji adɛnɔ wɛ yɛn, afɛngɛ njim na Jɛrusɛlɛm aji kuma wɛ nsɛba.
# 2 46 Naji ɛlɔ seng mfo ɛra ajil ayɛn nɛ na Njo Ɔsɔwɔ, na ji ajigɔ na ba teteba, ayonge atong afɛnga abiba abɔ abiba.
# 2 47 Anɛ kpakpa ba ayogɔ wɛ ɛkpɔl abɔ ɛsi na ɛkukuna ɛjɛ na nfanga ɛyɛ.
# 2 48 Naji ndɛ na nyɛn ayɛnɔ nɔ wɛ, ɛkpɔl abɔ ɛsi. Nyɛn abong atɔgɛ, “Mɔn, bɛjom ji ɛkerɔ ɔlem wur ana? Mɛ na nsɔja ɛgba wur fɛgayɔ ɛsɛba wa.”
# 2 49 Jisɔs afanga abɔ, “Bɛjom ji wun ɔsɛba mam? Wun ɔnyim arɛ mɛ nteg njɔl na ɛtɛk nsɔjama ɛ?”
# 2 50 Abɔ ɛsaram ji wɛ abongɔ.
# 2 51 Jisɔs afɛngɛ na Nasarɛt na ndɛ na nyɛn. Wɛ ayoga abɔ. Nyɛn atore nsɔl yi ɛlɔ lɛm na Litem.
# 2 52 Jisɔs abenga na biji na ɛkukuna. Ɔsɔwɔ abɛl ɛyɛbalitem na nɛ anɛ atɔb abɛl ɛyɛbalitem na nɛ.
# 3 1 Nfɔntim antol Tibɛrɔs ajɔl ntakpa ntol a Rom na nya liko na ngara yifɔ Pɔntus Payilet yɔ ajɔlɔ mbabɛ a Judiya, Hɛrɔd ntol a Galili, na mɔnyɛn ɔwɛ Filip yɔ atɔb ajɔl ɛtɔna ntol a Ituriya na Trakonit, na Lysanya ntol a Abilɛnɛ.
# 3 2 na ngara yi fɔ atakpa anɛ ba anyina arɛ Anas na Kefas, ajɔl balemanjɔm Ɔsɔwɔ, Ɔsɔwɔ abong atɔg Jɔn mɔn a Sakariya ngɔ na Ɛkpelele.
# 3 3 Jɔn atum ajɛn bijiba bi ɛrenɔ ɛlagɛ Aya Jɔdan, abonga alom Ɔsɔwɔ, arɛ anɛ agbɔ ndɔn na abeɔfɛm abɔ, awuri alib, Ɔsɔwɔ atum akarɛ abɔ.
# 3 4 Mɔng ayɛlɛ na nwɛr a Isaya nyɛn amir Ɔsɔwɔ: “Lilom li nɛ ɛkɔna ngɔ na ɛkpelele, ‘Tore mba ɔkarɛ Tata, wɔ ɔlem mba atɔr ɔkarɛ.
# 3 5 Rore adɛmɛ kpakpa, rɛnɛ atakpa na asusuga biwɔng, agɔdɛ aba atɔr, aba akpɔ kpɔk ajɔl sɛl.
# 3 6 Kpakpa anɛ ala yɛn ɔnyangɛ bi Ɔsɔwɔ.’ ”
# 3 7 Jɔn atɔg lirɔng anɛ ba abalɔ alib nwuri arɛ, “Wun abɔn ɛgbɔda! Wun ɔkɛrɛ arɛ ɔmamal ɔrɛm ɛyama litem ji Ɔsɔwɔ ji ɛla ba ɛ?
# 3 8 Ba bɛl likpen li ɛla teb arɛ wun ɔgba gbɔ ndɔn na abeɔfɛm. Wun ɔdɛ bong ɔtɔg ɛlina arɛ wun ɔkpe Ɛbram mɔng nsɔjina. Mɛ ntɔga wun ndɛ Ɔsɔwɔ amal alem atal yafa ajɔl abɔn ba Ɛbram.
# 3 9 Lifog ɛla gbɛg nub ɔte ayiayi na arug, lifog ɛnɔng na nub ote ayiayi yi adɔgɔnɔ kab ateng akab ala gbɛg arɔ akag na ngon.”
# 3 10 Anɛ ba fɔ abib Jɔn, “Wur ɛla lem nan?”
# 3 11 Jɔn afanga abɔ, “Nɛ yɔ akpenɔ ɛlimi bibal, karɛ nɛ yɔ adɛnɔ bɛl, nɛ yɔ akpenɔ nsɔl lili abanga na nɛ yɔ adɛnɔ bɛl.”
# 3 12 Bafora ataksi abal arɛ aba wuri alib abib bɛ “Nteteba, wur ɛla lem nan?”
# 3 13 Atɔg abɔ arɛ, “Ɔtɔb teg ɔkɔ ɔseng mɔng akɔga.”
# 3 14 Ɔsɔja ɛbibɛ, “Wur ɛla lem nan?” Jɔn afanga abɔ, “Ɔtɔb tabɛ nɛ akpuga na ɛbe mba, ɔtɔb lagɛ anɛ nfɛm mbɔlmbɔl, ji akpega wa ɛbenga wa.”
# 3 15 Anɛ ajɔl seg Krayis, akɛrɛ na ntem abɔ afi Jɔn arenɔ Krayis.
# 3 16 Jɔn afanga abɔ kpakpa, “Mɛ nkɔga alib nyanga nwuri wun. Nɛ yɔ akpenɔ ɛkɔ aseng am ayɔbak, mɛ ndiram yɔ mal nfungi aligi na akpagata ayɛ. Ala wun wuri alib na Mbara Ɛtugi na ngon.
# 3 17 Ɛkoriya ɛfɛba nsɔl ɛyɔbɛ nɔ ɔbɔ, ji alagɔ afɛb akpaga ayege. Akɔ amug atore na ɛbonge afengɛ asɔ akpaga na libar ngon li ɛdɛg lim.”
# 3 18 Jɔn akag abɔ ɛkora biji na ɛgbem alom, abong alom Ɔsɔwɔ atɔg abɔ.
# 3 19 Na ji Jɔn atobɔ ntol a Hɛrɔd ɛgan ateb akɔl Hɛrɔdiya, nkal a mɔnyɛn, na ɛgbem abeɔfɛm ya alɔ lem.
# 3 20 Hɛrɔd alem ɛbe naji akagɔ Jɔn na ngbakɔbɔ.
# 3 21 Na ji anɛ awuri alib, Jisɔs atɔb awuri. Na ji ajɔl kag ɔrɔ libo ɛribi.
# 3 22 Mbara Ɛtugi abudi abole wɛ na biji mɔng ɛmɛb. Lilom ɛjog na libonta: “Wɔ mɔn ɔma, yɔ ɔkɔra mam nkpe ɛyɛbalitem na na.”
# 3 23 Na ji Jisɔs alɔ rir nya litil na woba, abɔm litom ɛlɛ. Anɛ anyinyi arɛ Jisɔs mɔn a Josɛf yɔ arenɔ mɔn a Hɛli.
# 3 24 Hɛli mɔn a Matat, Matat mɔn a Lɛfi, Lɛfi mɔn a Mɛliki, Mɛliki mɔn a Janayi, Janayi mɔn a Josɛf,
# 3 25 Josɛf mɔn a Matatayas, Matatayas mɔn a Amɔs, Amɔs mɔn a Nahum, Nahum mɔn a Ɛsili, Ɛsili mɔn a Nagayi,
# 3 26 Nagayi mɔn a Mati, Mati mɔn a Matatayas, Matatayas mɔn a Sɛmeyi, Sɛmeyi mɔn a Jɔsek, Jɔsek mɔn a Joda,
# 3 27 Joda mɔn a Jowana, Jowana mɔn a Resa, Resa mɔn a Serubabɛ, Serbabɛ mɔn a Selitiyɛ, Selitiyɛ mɔn a Nɛri, Nɛri
# 3 28 mɔn a Mɛliki, Mɛliki mɔn a Adi, Adi mɔn a Kosam, Kosam mɔn a Ɛlimadam, Ɛlimadam mɔn a Ɛr.
# 3 29 Ɛr mɔn a Josuwa, Josuwa mɔn a Ɛliyɛsa, Ɛliyɛsa mɔn a Jorim, Jorim mɔn a Matat, Matat mɔn a Lɛfi,
# 3 30 Lɛfi mɔn a Simiyɔn, Simiyɔn mɔn a Juda, Juda mɔn a Josɛf, Josɛf mɔn a Jonam, Jonam mɔn a Ɛliyakim,
# 3 31 Ɛliyakim mɔn a Mɛlɛya, Mɛlɛya mɔn a Mɛna, Mɛna mɔn a Matata, Matata mɔn a Natan, Natan mɔn a Defid,
# 3 32 Defid mɔn a Jɛsɛ, Jɛsɛ mɔn a Ɔbɛd, Ɔbɛd mɔn a Bowas, Bowas mɔn a Salimɔn, Salimɔ mɔn a Nasɔn,
# 3 33 Nasɔn mɔn a Aminadab, Aminadab mɔn a Adimin, Adimin mɔn a Arni, Arni mɔn a Hɛsirɔn, Hɛsirɔn mɔn a Pɛrɛs, Pɛrɛs mɔn a Juda,
# 3 34 Juda mɔn a Jɛkɔb, Jɛkɔb mɔn a Asak, Asak mɔn a Ɛbram, Ɛbram mɔn a Tɛra, Tɛra mɔn a Nahɔ,
# 3 35 Nahɔ mɔn a Sɛrug, Sɛrug mɔn a Rɛyu, Rɛyu mɔn a Pɛlɛg, Pɛlɛg mɔn a Ɛba, Ɛba mɔn a Sɛla,
# 3 36 Sɛla mɔn a Kenan, Kenan mɔn a Afasat, Afasat mɔn a Sɛm, Sɛm mɔn a Nowa, Nowa mɔn a Lamɛk,
# 3 37 Lamɛk mɔn a Mɛtusɛla, Mɛtusɛla mɔn a Ɛnɔk, Ɛnɔk mɔn a Jarɛd, Jarɛd mɔn a Mahalalɛ, Mahalalɛ mɔn a Kenan,
# 3 38 Kenan mɔn a Ɛnɔs, Ɛnɔs mɔn a Sɛt, Sɛt mɔn a Adam, Adam mɔn a Ɔsɔwɔ.
# 4 1 Jisɔs afɛngɛ njim na Jɔdan, Mbara Ɛtugi aror wɛ, atu wɛ arir na ɛkpelele,
# 4 2 na mfom yi nim agarɔ wɛ na mfo atil abal, na afo afɔ fɛb jisɔk alilam, na nklusi njal ayamɛ.
# 4 3 Nim abong atɔgɛ, “Ɛlɔ jɔlarɛ wɔ Mɔn Ɔsɔwɔ, yɔ tɔg lital lifa ɛyanga ngba brɛd.”
# 4 4 Jisɔs afanga, “Agba yɛlɛ na nwɛr yi Ɔsɔwɔ arɛ nɛ anim kpena na brɛd nanting.”
# 4 5 Nim akpɛ wɛ tab aji na nyura mfom atebɛ ɛjiba ɔtol ji ɛyeng na ngara yifɔ.
# 4 6 Nim abong atɔgɛ, “Na karɛ ɛkɔ fɛb na afang fɛb ateb agba dabɔ fɛb akam, mɛ mal nkarɛ nɛ yɔ akɔrɔ nɔ mam.
# 4 7 Yifa kpakpa ɛla jɔl ɛkara, wɔ ɔlɔ kponi mam.”
# 4 8 Jisɔs afanga arɛ, “Agba yɛlɛ na nwɛr yi Ɔsɔwɔ arɛ, ‘Kponi Tata Ɔsɔwɔ ɛba wɔ ɔfɛngɛ ɔrɔgɛ wɛ nanting a ntinga.’ ”
# 4 9 Nim akpɛ wɛ tab aji na Jɛrusɛlɛm aji lemɛ akoma na nyura mfom yi Njo Ɔsɔwɔ abong atɔgɛ “Ɛlɔ jɔlare wɔ mɔn Ɔsɔwɔ yɔ, rɔ ɛla na nde na ji ɔyemɔ fa.
# 4 10 Ateb agba yɛlɛ na nwɛr yi Ɔsɔwɔ, ‘Ɔsɔwɔ ala tom bateb ɔteb abɛ ababɛ wa,
# 4 11 abɔ ala gbeba na abɔ ɔnim teg ɔrom ɔta ɔkag na lital.’ ”
# 4 12 Jisɔs afanga wɛ, “Agba yɛlɛ na nwɛr Ɔsɔwɔ arɛ, ‘Ɔtɔb teg ɔgara Tata Ɔsɔwɔ ɛba.’ ”
# 4 13 Na ji nim alɔ wɛ gara na mba ayiayi, atumɛ asa.
# 4 14 Jisɔs afɛngɛ njim na Galili, ɛkɔ ji Mbara Ɛtugi ɛjɔl na nɛ. Ɔteb abangɛ wɛ ɛnyada na bijiba kpa kpa.
# 4 15 Ateb anɛ na ɛkpasega kpakpa atigɛ.
# 4 16 Jisɔs ajil na Nasarɛt na mfom yi alɛlɔ wɛ, na ɔfo ɛrɛdɛkɛr ajil na ɛkpasega mɔng ligbɛna ɛlɛ, atum ayema akog nwɛr Ɔsɔwɔ.
# 4 17 Atab nwɛr a nyɛna amir Isaya akarɛ aribi aji yɛn mfom yi ayɛlɔ,
# 4 18 “Ɛtugi ji Tata ɛre na nama, na ateb arɛ agba mam rang arɛ mɛ mbong ɛteng ɔteb nkarɛ akpak. Agba mam tom arɛ mɛ ntɔg agbakɔbɔ arɛ Ɔsɔwɔ ala fungi abɔ adabɔ nem alaga amir ayɛn, nyege anɛ ba ayɔbɔ na ɛgir.
# 4 19 Mɛ ntebe liya li ɔnyangɛ bi Ɔsɔwɔ.”
# 4 20 Jisɔs afud nwɛr akarɛ nɛ yɔ ayimɔ fɔ atore ajɔl. Amir anɛ kpakpa na ɛkpasega ajɔlɛ bri.
# 4 21 “Ɛlɛl alom ya Ɔsɔwɔ agba leba.”
# 4 22 Abɔ fɛb abonga ateng a nsɔl abangɛ wɛ ɛkpɔ abɔ ɛsi na ateng alom ya ajoga wɛ abɔ abib, “Fa mɔn a Josɛf arig ɛ?”
# 4 23 Jisɔs abong atɔg abɔ, “Na ɛtete nyiyi ndɛ Wun ɔtɔb ɔmal ɔtobam ligan lifa, ‘Nɛ ɛte lem ɛla wɔ ɔnɔb, lem na ɛjiba ɛja mɔng wur ɛyogɔ ji wɔ ɔlemɔ na Kapanum.’ ”
# 4 24 “Ɛtete ji mɛ ntɔga wa, nyɛn amir sang yɔ akpenɔ liloba na ɛjiba ɛjɛ.
# 4 25 Mɛ ntɔga wa ndɛ agbem akal akuanɛ ajɔl na Isrɛl na ngara Ɛlayija. Naji alib adɛnɔ na na nya ɛra na ɛja nkore ɔgba ajɔjɔl na nde.
# 4 26 Ɛjɔl Ɛlayija wɛ atomam atu nkala nkuanɛ awiawi, ndɛg nkala nkuanɛ na Sarafad na ɛjiba ji Sayidɔn.
# 4 27 Ɛgbem anɛ ajɔjɔl na Isrɛl ba abɛlɔ abele na ngara nyɛn amir a Ɛlayisa, ɛjɔl wurang anɔbam ndɛg Naman yɔ arunɔ Siriya.”
# 4 28 Anɛ kpakpa na njo ɔrɔ abɛl ɛyama litem na ji ayogɔ ɔtɔga bifa.
# 4 29 Atum ayema akamɛ ayege na ɛjiba ji fɔ atabɛ aji na nkul ɛwɔng yi asilɔ na ɛjiba jifɔ, atole wɛ ɛsi arɛ arɔ wɛ na nde.
# 4 30 Ajɛn aseng na ɛbɔngɛ anɛ asɔnga mba ɛyɛ.
# 4 31 Fɔyɔ Jisɔs ajilɔ na Kapanum, ɛjiba ji ɛrenɔ na Galili. Na Ɔfo Ɛrɛdɛkɛr akuma anɛ nteba.
# 4 32 Ɛkpɔl abɔ ɛsi na ngara yi ajɔl teb, ateb arɛ ajɔl bong na ɛkɔ.
# 4 33 Na ɛkpasega ɛbɛl nɛnom wurang yɔ abɛlɔ ɛbe ɛtugi, akɔn na nyura lilom,
# 4 34 “Ee! Bɛjom ji ɔsɛba na agira, Jisɔs yɔ Nasarɛt? Ɔbal wur ndungi ɛ? Mɛ nyiyi nɛ yɔ wɔ ɔrenɔ, wɔ ɔru naji Ɔsɔwɔ!”
# 4 35 Jisɔs abong nkore nkore, “Bole nyɔ! Jogɛ na biji!” Ɛbe Ɛtugi ɛrɔ nɛnom ɔfɔ ɛtob na nde na libri abɔ ɛjɔl ɛlɛm wɛ ɛteram.
# 4 36 Anɛ kpakpa ɛkpɔl abɔ ɛsi akuma mbonga atɔga atɛm, “Fa ba ligan nteba yifa? Na ɛkɔ na nsim yi abongɔ atɔg ɛbe Ɛtugi abɔ fɛb ajog!”
# 4 37 Ɔteb abangɛ Jisɔs ɛnyada na bijiba ɛtob ɛsibi.
# 4 38 Jisɔs atum na ɛkpasega aji na ɛtɛk Sayimɔn. Nyɛn nkal a Sayimɔn ajɔl yam nkore ɛsi amil, abɔ atɔg Jisɔs arɛ anyangɛ wɛ.
# 4 39 Ajil ayema alagɛ ɛgbenga ɛjɛ atob ɛgan ɛsi amil ɛda wɛ abɔ, fɔ tutu atum ayema arɔgɛ abɔ litom.
# 4 40 Naji njol alɔ lim, kpakpa abal na anɛ ba ayam na nkpakankpak abal na abɔ aba karɛ Jisɔs, akɔ abɔ ayɛ akone abɔ na bisi alem abɔ anɔb.
# 4 41 Abe atugi ajog na biji ɛgbem anɛ akɔna, “Wɔ mɔn Ɔsɔwɔ yɔ!” Jisɔs anyam abɔ anɔngam abɔ arɛ abong ntɔga ateb arɛ abɔ anyinyi arɛ wɛ arenɔ Krayis.
# 4 42 Naji ɔforanfo ɛlɔ kparɛ Jisɔs atum ɛjiba asa aji yema na nara mfom. Anɛ akuma wɛ nsɛba, naji ayɛnɔ wɛ anɔngam wɛ tum abɔ asa.
# 4 43 Jisɔs abong atɔga abɔ, “Mɛ nteg mbong ɛteng ɔteb bi ɛjiba ɔtol Ɔsɔwɔ na bijiba bingɔ titi, ateb arɛ jifɔ ji Ɔsɔwɔ atomɔnɔ mam arɛ nem.”
# 4 44 Ajɔl bong alom na ɛgrigri na kpakpa bijiba Judiya.
# 5 1 Ɔfo brang na ji Jisɔs ajɔl bong alom na ɛgbok Aya ya Jɛnɛsarɛt, ɛbɔngɛ anɛ atobɛ asibi agbola atɛm arɛ ayog alom Ɔsɔwɔ.
# 5 2 Ayɛn ɛgba bibal na nkɛ alib naji ba bem ɔri alɔ tum asa, aroga atonfong abɔ.
# 5 3 Jisɔs ayɛl na ɛgba jirang, ɛgba jifɔ ji Sayimɔn. Jisɔs atɔg Sayimɔn arɛ atimi ɛgba sed na nkɛ akag na alib. Wɛ ajɔl na ɛgba ateba ɛbɔngɛ anɛ ji fɔ.
# 5 4 Na ji amalɔ ntɔga mbonga wɛ atɔg Sayimɔn, “Timi Sɔng na mfom yi adulɔ dul wun ɔdabɔ na ntofong ayɛl wun ɔbɔb ɔri.”
# 5 5 Sayimɔn afanga, “Nsɔjama njo, ɛgba lem litom nkore nkore na alagtu afa ɛmalam ɛbɔb nyam alib ayiayi, naji ɔlɔ bong anɔ nɔng mɛ nkpɛ gara.”
# 5 6 Na ji alemɔ anɔ abɔb ɔri ɛgbem ɛgbem ntofong aror akuma nyara.
# 5 7 Akog atɛm na ɛgba jingɔ arɛ aba tɔb abɔ, ɔri ɛror na ɛgba ji fɔ bibal ɛgba ɛkuma ntɛra.
# 5 8 Naji Sayimɔn Pita ayɛnɔ ji ɛlɔ lem ajumi ndung na libri Jisɔs abong, “Tata jɛra sɔng ngɔ mɛ nɛ abeɔfɛm yɔ.”
# 5 9 Ɛkpɔ wɛ ɛsi na anɛ bangɔ na ɛgbem ɔri bi abɔbɔ.
# 5 10 Jemsi na Jɔn, abɔn balom ba Sɛbɛdi atɛm a Simiyɔn ɛtɔb ɛkpɔ abɔ ɛsi. Jisɔs abong atɔg Sayimɔn, “Ɔtɔb bɛ, bɔm batig ana sɔng ɔsi, ɔjɔ fɛn ɔbem anɛ.”
# 5 11 Abɔ atur bigba atu na ɛgbok, atum kpakpa nsɔl asa atɔna Jisɔs.
# 5 12 Naji Jisɔs ajɔlɔ na ɛjiba jirang, ɛbɛl nɛnom yɔ ajɔl yam abele. Naji ayɛnɔ Jisɔs ajumi ndung akug libri na nde agɔrɛ wɛ abong, “Tata, ɛlɔ yɛbɛ wa ɔmal ɔlemam mɛ nɔb.”
# 5 13 Jisɔs atini ɔbɔ alagɛ abong, “Ɛnɔngɛ ɛkɔra mam, ndɛ wɔ ɔnɔb.” fɔtutu abele afɔ amal.
# 5 14 Jisɔs arigi wɛ, “Ɔtɔb tɔg nɛ awiawi. Sɔng teb ɛla naji nemanjɔm Ɔsɔwɔ wɔ ɔlem mɔng ajing a Mosis abongɔ ya arenɔ akarɛ ɛroga biji wɔ ɔteb anɛ arɛ wɔ ɔgba nɔb.”
# 5 15 Ɛjɔl naji akarɔ wɛ lirigi lifɔ, ɔteb abangɛ Jisɔs ɛnyada na kpakpa afom ɛbɔngɛ anɛ abal arɛ aba yogɛ ɛtɔnafɔ anɔb ayam abɔ.
# 5 16 Jisɔs ajɔga atuma ajiga na nara mfom aji kag ɔrɔ.
# 5 17 Ɔfo birang na ji Jisɔs ajɔl teb, anɛ ba Farasi na ba teba ajing ba, ajogɔ na akpa ɛgbɛ kpakpa ya Galili bɔm na Judiya na Jɛrusɛlɛm. Ɛkɔ ji Tata ɛjɔl na Jisɔs ji ɛla lem anɛ ba ayam anɔb.
# 5 18 Abalom asima njoga ata na ɛkpa agara arɛ atabɛ akag na ɛtɛk abomɛ na mfom yi Jisɔs arenɔ.
# 5 19 Na ji adɛnɔ nɔ yɛn mba ateb ɛbɔngɛ anɛ ji ɛjɔlɔ, ayur na likɔng ɛtɛk li ɛrenɔ dandan aribi arɛda wɛ na ɛkpa ɛjɛ aseng na lika li ɛbɔngɛ anɛ abomɛ na libri Jisɔs.
# 5 20 Na ji Jisɔs ayɛnɔ ntamɛ abɔ abong atɔgɛ arɛ, “Ntɛm, nitum nkara na abeɔfɛm aya.”
# 5 21 Anɛ ba Farasi na ba teba Ajing akuma mbiba liabɔ, “Fa ba nɛ yɔ atoga Ɔsɔwɔ? Ba nɛ yɔ amala atum akara abeɔfɛm ndɛg Ɔsɔwɔ nanting?”
# 5 22 Jisɔs akukun ji abɔ ajɔlɔ kɛrɛ, “Bɛjom ji wun ɔkɛrɛ nsɔl yi fa na ntem?
# 5 23 Njin yi agalɔ jɔl ndɛra ɛjom arɛ ɔbong, ‘Ali tum akara na abeɔfɛm aya’ afi wɔ ɔbong arɛ ‘Tum yema wɔ ɔjɛn?’
# 5 24 Nsɛb ndɛ wɔ ɔkun arɛ mɛ Mɔn a Nɛnom yɔ akpenɔ ɛkɔ na nde yɔ atum akarɛ abeɔfɛm.” Abong atɔg nɛnom yɔ ata alɔ jog, “Mɛ ntɔga wa, tum yema tab ɛkpa ɛja sɔng kuri.”
# 5 25 Fɔtutu nɛnom ɔfɔ atum ayema na libri abɔ, atab ɛkpa ɛjɛ atum akuri atiga Ɔsɔwɔ.
# 5 26 Anɛ kpakpa ɛkpɔl abɔ ɛsi ajɔ tig Ɔsɔwɔ. Abɛl ɛkokob abangɛ ji abɔ ayɛnɔ, “Wur ɛgba yɛn akpɔga ɛsi a nsɔl ɛlɛl.”
# 5 27 Na ji jifɔ ɛlɔ seng, Jisɔs ajog na ɛtegla ayɛn nfora ataksi yɔ akoga wɛ arɛ Lɛfi ajɔl na mfom yi afora ataksi. Jisɔs abong atɔgɛ arɛ, “Tum tɔna mam.”
# 5 28 Lɛfi atum ayema, atum nsɔl fɛb asa atɔna wɛ.
# 5 29 Lɛfi alem ntakpa likag akarɛ Jisɔs na ɛtɛk ɛjɛ, anɛ ba taksi na anɛ ba ngɔ ajɔl li nsɔl na nɛ.
# 5 30 Anɛ ba Farasi na ba teba ajing akuma numi atɔga batɔnanjim abɛ abonga, “Bɛjom ji ɛkera wun ɔliga nsɔl na bafora taksi na anɛ ba abeɔfɛm?”
# 5 31 Jisɔs afanga abɔ, “Nɛ yɔ arenɔ na nsɛrɛ anim jɔga asɛba nɛ ɛte, ndɛg nɛ ɔyam.
# 5 32 Mbalam ndɛ mba kog anɛ ba abarbar, mbal ndɛ mba kog anɛ ba abeɔfɛm agbɔ ndɔn.”
# 5 33 Ɔfo brang anɛ abong atɔg Jisɔs, “Batɔnanjim ba Jɔn ajɔl jɔl njal akaga ɔrɔ, batɔnanjim ba Farasi ajɔl lem anɔ, baba ajɛna aliga awɔga.”
# 5 34 Jisɔs afanga “Wɔ ɔmamal ɔlem ajɛn anɛ ba nfɔna likag ajɔl njal naji akpenɔre na abɔ ɛ?
# 5 35 Ngara ayɔ bak yi ala tab nfɔna likag naji abɔ, na ngara yifɔ abɔ amal ajɔl njal.”
# 5 36 Atob abɔ ligan lifa, Nɛ sang yɔ ala yara nkpakola mbɔma ajum akpa na nfɛ a mbɔma, ɔlɔ lem anɔ ɛla yara nfɛ abɔma ɛja nfɛ a mbɔma ɛnim kɔn na nkpakola.
# 5 37 Ɛtɔb ɛre anɔ nɛ sang ayanga afɛ amum akag na nkokola ɛbam nkpango a nyam, ɔlɔ lem anɔ amum ala buri, amum ajog ɛbam ɛrungi.
# 5 38 Afɛ amum ala yanga akag na nfɛ ɛbam nkpango a nyam.
# 5 39 Nɛ sang yɔ alɔ wɔ akpakola amum yɔ akpɛ sɛb ya afɛ arɛ awɔ ateb wɛ ala bong arɛ, “Akpakola amum ya agalɔ nɔb.”
# 6 1 Na Ɔfo Ɛrɛdɛkɛr Jisɔs ajɔl jɛn na ɛgbɛ ji abimɔ nsɔl yi akoga arɛ nsam, atɔnanjim abɛ akuma mfugi asi a nsam, afore afuli afɛb aliga amug.
# 6 2 Anɛ ba Farasi abibɛ, “Bɛjom ji wun ɔlema litom li ajigi abongɔ arɛ wun ɔdɛlem na Ɔfo Ɛrɛdɛkɛr?”
# 6 3 Jisɔs afanga abɔ, “Wun ɔka kogam ji Defid na anɛ ba ɔta lijɛn abɛ alemɔ ngara yi njal ayamɔ abɔ-ɛ?
# 6 4 Wɛ ayɛl na njo Ɔsɔwɔ aji tab brɛd bi ɛrenɔ ɛkarɛ Ɔsɔwɔ ali, atɔb akarɛ anɛ ba ɔta lijɛn abɛ. Njing atamam arɛ anɛ banga ali ndɛg nemanjɔm Ɔsɔwɔ.”
# 6 5 Jisɔs akur bong atɔg abɔ arɛ, “Mɔn a Nɛnom yɔ arenɔ Tata bi Ɔfo Ɛrɛdɛkɛr.”
# 6 6 Na Ɔfo bingɔ bi Ɛrɛdɛkɛr Jisɔs ajil na ɛkpasega aji kuma nteba. Nɛnom wurang yɔ ɔbɔ bilom ɛlɔ jog ajɔl fɔ.
# 6 7 Anɛ ba Farasi na ba Teba ajing ajɔl sɛb mba yi akone Jisɔs mfɛm na ɛsi, ajɔl babɛ arɛ ayɛn mɔng alagɔ wɛ lem anɔb na Ɔfo Ɛrɛdɛkɛr.
# 6 8 Jisɔs akukun ji abɔ ajɔl kɛrɛ. Abong atɔg nɛ yɔ ɔbɔ ɛlɔ jog arɛ, “Tum yema wɔ ɔjɛn ɔba na ɔsi.” Wɛ atum ayema fɔ.
# 6 9 Jisɔs atɔg abɔ arɛ, “Nag wun bib mbiba. Bɛjom ji njing adalɔ wur abɔ arɛ wur ɛlem na Ɔfo Ɛrɛdɛkɛr. Bilom bi afi nɔba? Ɔnyangɛ likpen afi ɔrungi likpen?”
# 6 10 Wɛ abri abɔ fɛb, abong atɔg, nɛnom ɔfɔ, “Tini ɔbɔ ɛba.” Wɛ atini ɔbɔ ɛtore ɛnɔb.
# 6 11 Abɔ arag ntem akuma mbonga atɔga atɛm ɛjom ji ala lem Jisɔs.
# 6 12 Ɔfo brang, Jisɔs ayur na ɛwɔng arɛ aji kag ɔrɔ, ajɔl alagtu kpukpul akaga ɔrɔ akarɛ Ɔsɔwɔ.
# 6 13 Na ji ɔforanfo ɛlɔ kparɛ, akog batɔnanjim abɛ atu ɛlɛ arang anɛ woba na abal akog abɔ Arɔb:
# 6 14 Sayimɔn (yɔ agorɔ wɛ mbeng Pita), na mɔnyɛn ɔwɛ Andru; na Jemsi, na Jɔn, na Filip, na Batilɔmi,
# 6 15 na Matiyu, na Tɔmasi, na Jemsi mɔn a Alfɛyus, na Sayimɔn yɔ ajɔlɔ wɛ kog arɛ Silɔt
# 6 16 na Judas mɔn a Jemsi, na Judas Isikariyɔt, yɔ ayubɔ Jisɔs na ata.
# 6 17 Naji Jisɔs na Arɔb ayɛ abudɔ na ɛwɔng, ɛbɔngɛ Batɔnanjim abɛ aba yema na mfom yi arenɔ sɛl, ɛbɔngɛ anɛ ba ajogɔ Judiya, Jɛrusɛlɛm bandɛga ajog na nkɛ ɛgbok aya Taya na Sayidɔn.
# 6 18 Abal arɛ aba yogɛ afɛngɛ anɔb ayam, anɛ ba abe atugi afege abɔ ayɔ alem abɔ anɔb.
# 6 19 Anɛ kpakpa ajɔl sɛb mba arɛ alagɛ abɔ ateb ɛkɔ ji ɛjɔlɔ wɛ jog ɛjɔl lem abɔ fɛb anɔb.
# 6 20 Jisɔs abri batɔnanjim abɛ abong, “Lifola na akpak, Ɔtol Ɔsɔwɔ ɛre ɛkarɛ wun.
# 6 21 Lifola na anɛ ba njal batig; ala wuwuri. Lifola na anɛ ba arera batig; wun ɔla yɔyɔl.
# 6 22 Lifola na na yɔ anɛ ajinga wa, atɛna wa, atoga wa ateb Mɔn a Nɛnom.
# 6 23 “Rang, wɔ ɔbin na ɛyɛbalitem, nsɔl yi fɔ ɛlɔ lem ɛkara ateb ntore ɛya afafang na Ɔtol Ɔsɔwɔ. Anɔ yɔ anɛ abɔ ba ɛmini alemɔ ba yɛn amir.
# 6 24 “Ligbo na nina afang anɛ batig, ateb arɛ wun ɔgba bɛl nyɛba likpen.
# 6 25 Ligbo nana yɔ ɔlɔ wuri batig, wɔ ɔla jɔl njal. Ligbo ɛjɔl nana yɔ ɔyɔla batig, wɔ ɔla kar liku ɔjɔ fɛngɛ ɔrer.
# 6 26 Ligbo ɛjɔl na na yɔ anɛ abonga atenga nsɔl abangɛ wa, anɔ yɔ anɛ abɔ ba ɛmini alemɔ bayɛn amir ba akemakem.
# 6 27 “Wun ba ɔyoga mam: Ba bɛl likɔrɔ na anɛ ba ɔjing abina, wun ɔlem ateng a nsɔl ɔkarɛ anɛ ba ɔraga abɔ.
# 6 28 Tɔg Ɔsɔwɔ akarɛ anɛ ba atoga wa lifola. Wɔ ɔkag ɔrɔ ɔkarɛ anɛ ba akaga wa ɛriga.
# 6 29 Nɛ awiawi yɔ aromɔ wa na ɛja ɔkpɔga, sibi ɛja jingɔ wɔ ɔkarɛ akpɛ rom. Nɛ awiawi yɔ atabɔ wa nkot, nɔngɛ wɛ akur kɔ ɛlimi.
# 6 30 Karɛ nɛ awiawi yɔ alɛmɔ wa, nɛ awiawi yɔ atabɔ ɛjom ɛja ɔtɔbɛ tɔg arɛ afɛra wa.
# 6 31 Lem karɛ anɛ ji ɔsɛbɔ arɛ alem akara.
# 6 32 “Ɔlɔ bɛl likɔrɔ na anɛ ba ɔkɔra abɔ baba, ba nseng yi ɔla bɛl? Ɛjɔl anɛ ba abeɔfɛm akpe likɔrɔ na anɛ ba ateba abɔ likɔrɔ.
# 6 33 Ɔlɔ lem ateng a nsɔl ɔkarɛ anɛ ba alema ateng nsɔl akarɛ wa, ba nseng yi ɔla bɛl? Ɛjɔl anɛ ba abeɔfɛm anɔnga alema anɔ.
# 6 34 Ɔlɔ bɔ anɛ akpuga ba ɔkɛrɛ arɛ ala tore atu akara, ba nseng yi ɔla bɛl? Ɛjɔl anɛ ba abeɔfɛm abɔga atɛm akpuga asega arɛ akpe abɔ ngara mɔng abɔ akarɔ.
# 6 35 “Bɛl likɔrɔ na anɛ ba ajing aba, ɔlem nɔba ɔkarɛ abɔ, ɔlɔ bɔ nɛ akpuga ɔdɛ bɛl ɛkɛkɛrɛ arɛ atore atu akara. Wɔ ɔla bɛl ntakpa ntore, wɔ ɔla jɔl Mɔn a Ɔsɔwɔ bi Ɛyurɔyura, ateb wɛ anɔb litem na anɛ ba adɛgɛ kag sam na abe anɛ.
# 6 36 Nɔb litem na anɛ mɔng Nsɔja anɔbɔ litem.
# 6 37 “Ɔtɔb lam anɛ adɛ tɔb alama. Ɔdɛ rungi anɛ, anim tɔb arungi wa. Tum karɛ anɛ ateg atum akara.
# 6 38 Karɛ anɛ, ala kakarɛ. Ɛyarɛ ɛja alɔ atore afɛngɛ njim akara ɛla ror ɛwuri na nde, ji ɔgarɔ ɔkarɛ jiji ala tɔb akɔ agara akara.”
# 6 39 Jisɔs atob abɔ ligan li fa. “Naga amir amamal ateb ntɛm naga amir mba ɛ? abɔ anim gbɔ ayɛl na libe ɛ?
# 6 40 Nkpekpele anim ma jɔg aseng nteteba, nkpekpele yɔ atorɔ wɛ ala jɔl mɔng nteteba yɔ atebɔ wɛ.
# 6 41 Bɛjom ji ɔbri lisan na limir mɔnyɛn ɔwa, ɔdɛk yɛn ɛbɛg ɔte na limir ɛla?
# 6 42 Ɛla lem nan ɔtɔg mɔnyɛn ɔwa arɛ, ‘mɔnyɛn ɔma, ɛtiti nɔng mɛ nyege wa lisan na limir ɛla,’ na ji wɔ ɔdɛk yɛn ɛbɛg ɔte na limir ɛla? Wɔ nɛ a nbri ɛbal! Gbɔ mba yege ɛbɛg ɔte na limir ɛla, na ji ɔla ɔmal ɔyɛn ɛnɔbnɔbɛ ɔyege lisan na limir mɔnyɛn ɔwa.
# 6 43 “Ɛteng ɔte ɛnim teg ɛkab abe akab, nig ɛbe ɔte ɛkab ateng akab.
# 6 44 Ɔte abiabi ɔrenge na akab ayɛ, ɔnim ma bɔng akab ɔjuju na ɔte ajɔnga, ɔnim ma bɔng amuruku na ɔtenyam akoma.
# 6 45 Ɛteng nɛ abaga na ateng a nsɔl ya ayɔbɔ wɛ na litem, ɛbe nɛ titi abaga na abe nsɔl ya ayɔbɔ wɛ na litem, nyɔ bi ɛbonga nsɔl yi ɛlɔ ror na litem.
# 6 46 “Bɛjom ji wun ɔkoga mam, ‘Tata, Tata’ ɔdɛg lem ji mɛ ntɔga wun?
# 6 47 Nɛ awiawi yɔ abalɔ na agama ayog alom ama alem anɔ mɔng nbongɔ, mɛ na teb mɔng wɛ arenɔ.
# 6 48 Are mɔng nɛ yɔ arimɔ alub atana adul asil ɛtɛk ɛjɛ akone na atal, nyɛl alɔ ba akud abole ɛtɛk ji fɔ ɛnim teg ɛnyɛngɛ ateba arɛ asil na nsɛrɛ.
# 6 49 Yɔ nɛ awiawi yɔ ayogɔ alom ama adɛ kɔ akag na nema, are mɔng nɛ yɔ asilɔ ɛtɛk adɛ rim aluba atana adul, nyɛl alɔ ba akud ɛtɛk ji fɔ ɛgbɔgbɔ ɛrungi fɛb.”
# 7 1 Na ji Jisɔs alɔ mal mbonga kpakpa nsɔl atɔg anɛ ba ajɔl wɛ yog, atum ajɛn na Kapanum.
# 7 2 Ntol a nɛ nsɔja yɔ ajɔlɔ Rom abɛl ndɔgalitom yɔ ajɔl wɛ kɔr, ayayam arir na mboga liku.
# 7 3 Naji ntakpa nɛ a nsɔja yɔfɔ ayogɔ abangɛ Jisɔs, atom abakol ba Ju atu wɛ arɛ aji gɔrɛ wɛ aba lem ndɔgalitom ɔwɛ anɔb.
# 7 4 Naji abalɔ na ji Jisɔs, agɔrɛ wɛ arɛ ɛtiti o abong, “Nɛnom yɔfa afofoma arɛ wɔ ɔnyangɛ wɛ.
# 7 5 Ateb arɛ akpe likɔrɔ na nfam ɛyira afɛngɛ asi ɛkpasega akarɛ wur.”
# 7 6 Jisɔs ajil na abɔ na ɛtɛk, naji abɔ alɔ rir kpekpede ntakpa nɛ a nsɔja atom atɛm arɛ aji bong atɔgɛ, “Tata, ɔtɔb fege ɛla ayɔ mɛ nfomam yɔ wɔ ɔla ba na agama ɛtɛk.
# 7 7 Yiyi mɛ nyɛnɔ ɛlama mɔng nɛ yɔ adɛnɔ foma arɛ mɛ mba na aga. Lob bong lilom lili ndɔgalitom ɔma anɔbnɔb.
# 7 8 Mɛ nde na liyɔ nɛ, na ɔsɔja bi ɛyɔbɔ na liyɔ ɛlama, na tɔg wurang, ‘Sɔng!’ wɛ asɔng, na tɔg wurang ‘Ba!’ wɛ aba. Mɛ nɔ bong ntɔg ndɔgalitom ɔma lem ji fa wɛ alem.”
# 7 9 Naji Jisɔs ayogɔ alom yafɔ ɛkpɔl wɛ ɛsi asibi abong atɔg ɛbɔngɛ ji ɛjɔl wɛ tɔna, “Mɛ ntɔga wun, mɛ nkakpɛam yɛn ligan ntakpa ntamɛ ɛjɔl na Isrɛl”
# 7 10 Atɛm ba atomɔ nɔ akuri na ɛtɛk aba yɛn ndɔgalitom na ji alɔ nɔb.
# 7 11 Ɛjɔl ngara arungam, Jisɔs ajil na ɛjiba ji akoga arɛ Nen, batɔnanjim abɛ na ɛbɔngɛ anɛ ajil na nɛ.
# 7 12 Na ji alɔ rir alagɛ nyɔ mbo ɛjiba, ajɔl seng na nkuanɛ ajoga na nɛ ajɔl mɔn ɔlom wurang wuranga yɔ nɛnkal ɔfɔ agbɛlɔ. Ɛbɔngɛ anɛ na ɛjiba jifɔ ɛjɔl tɔna Nkal a nkpɔkpɔga.
# 7 13 Na ji Tata alɔ wɛ yɛn, ndɔn afele wɛ abong, “Ɔtɔb kpɛ rer.”
# 7 14 Fɔ yɔ ajɛnɔ aji lag amag ya asimɔ nɔ wɛ anɛ ba asimɔnɔ asa ayema wɛ abong, “Njangkon, mbong ntɔga tum yema.”
# 7 15 Nɛ yɔ akpɔlɔ atum ajɔl akuma ntɔga mbonga, Jisɔs atabɛ akarɛ nyɛn.
# 7 16 Abɔ abɛl ɛkokob ajɔ kuma Ɔsɔwɔ njege abonga, “Ntakpa nyɛna amir aliba nagira, Ɔsɔwɔ agba ba arɛ aba tɔb anɛ abɛ.”
# 7 17 Ɛka abangɛ Jisɔs ɛnyada na Judiya na bijiba bi ɛtobɔ ɛsibi.
# 7 18 Batɔnanjim ba Jɔn atɔg wɛ nsɔl kpakpa yi ɛlɔ lem. Akog batɔnanjim abɛ abal,
# 7 19 atom abɔ arɛ aji bib Tata arɛ, “Wɔ yɔ ɔrenɔ nɛ yɔ ɔbaga afi wur ɛseg nɛ yɔndɛga?”
# 7 20 Naji abalom bafɔ abalɔ naji Jisɔs abɔ abong, “Jɔn nwura anɛ alib atom wur atuwa arɛ wur ɛbiba, ‘Wɔ yɔ ɔrenɔ nɛ yɔ ɔbaga afi wur ɛseg nɛ yɔndɛga?’ ”
# 7 21 Na ngara yi fɔ Jisɔs agba lem agbem anɛ anɔb ayam bangɔ ayege abɔ abe atugi afɛnga alem alaga amir ayɛn.
# 7 22 Jisɔs afanga batebɔ ɔteb, “Ba sɔng wun ɔji tɔg Jɔn ji wun ɔlɔ yɛn ɔfɛngɛ ɔyog: Alaga amir ali yɛn mba, abuni atum ajɛng, anɛ ba akpenɔ abele anɔb, ba laga atong ali yog, akuanɛ anyimi, akpak ayoga ɛteng ɔteb.
# 7 23 Lifola ɛjɔl na nɛ awiawi yɔ adɛnɔ bɛl mfab ateb ɛsi ɛjama.”
# 7 24 Naji ba tebɔ ɔteb ba Jɔn alɔ fɛngɛ njim ajɛn, Jisɔs akuma mbonga atɔga ɛbɔngɛ anɛ abangɛ Jɔn. “Bɛjom ji ɔjilɔ na ɛkpelele arɛ wɔ ɔji yɛn? Araba agbɛlɛ ya nfɛb anɛrɔ ɛ?”
# 7 25 Ɛdɛnɔ jɔl anɔ! ɔjil jɛn nyɛna? Nɛnom yɔ alebɔ ɛteng ɛleba ɛ? Ii! Anɛ ba aleba ateng a bileba akpena ɛteng likpen ajɔla na bitɛk atol.
# 7 26 Bɛjom ji ɔjilɔ nyɛna? nyɛn amir ɛ? I Mɛ ntɔga wa ji wɔ ɔyɛnɔ ɛjɔg ɛseng nyɛna amir.
# 7 27 Jɔn arenɔ nɛ yɔ alom abonga jifa abangɛ wɛ, “Mɛ na tom nteb ɔteb ɔma agbɔ wun mba Yɔ ala tore mba ɛya akara.”
# 7 28 “Mɛ ntɔga wun, na anɛ ba nɛnkal agbɛlɔ, nɛ sang yɔ ajɔgɔ mɔng Jɔn. Titi nɛ yɔ aredɔ na Ɔtol Ɔsɔwɔ ajɔg aseng Jɔn.”
# 7 29 Kpakpa anɛ banga na bafora ataksi na ji ayogɔ alom a Jisɔs atamɛ arɛ mba Ɔsɔwɔ yi arenɔ ɛtete mba, ateb arɛ Jɔn awurɔ abɔ alib.
# 7 30 Anɛ ba Farasi na ba teba Ajing atɛn ji Ɔsɔwɔ agarɔ akarɛ abɔ, ateb atɛn arɛ Jɔn adɛ wuri abɔ alib.
# 7 31 Jisɔs abonga asɔnga, “Bɛjom ji mɛ na kɔ ngara anɛ ba batig? abɔ are nan?
# 7 32 Abɔ are mɔng abɔn ba ajigɔ na ɛtegla ɛgor ɛbɔngɛ jingɔ akoga atɛm: “Wur ɛtoma bisɛ mbal ɛkaga wun, wun ɔtɛn mbina; ɛtoma bisɛ liku wun, ɔtɛn ndera.”
# 7 33 Jɔn nwura alib aba ategam ali nsɔl yi nga mɔng brɛd nig afɛnga awɔ amum, Wun ba ɔbonga arɛ, “Akpe ɛbe ɛtugi.”
# 7 34 Mɔn a Nɛnom abal aliga awɔga, wun arɛ, Wɛ niga lili na nwɔga amum, wɛ ntɛm anɛ ba ataksi na anɛ ba abeɔfɛm.
# 7 35 Ɛkukuna ɛgba teb ɛlɛ arɛ are ɛtete na likpen li anɛ ba atɔnɔ.
# 7 36 Nɛ a Farasi akog Jisɔs nsɔl lili, Wɛ ajil na ɛtɛk nɛ Farasi aji jɔl arɛ ali nsɔl.
# 7 37 Ɛbɛl nɛnkal wurang na ɛjiba ji fɔ, yɔ akpenɔ ɛbe likpen, ayoga arɛ Jisɔs aliga nsɔl na ɛtɛk nɛ a Farasi, abal na aku ɛlu ya akagɔ na ɛkpoma ya akɔlɔ anɔba atal alem ya akoga arɛ alabasta.
# 7 38 Akuma Jisɔs na njim na ata ayɛ alula, ayege abibi asoge wɛ araba aja, akɔga nyu ɛyɛ afola wɛ araba aja. Akuga wɛ nyɔ na araba aja awuri wɛ aku ɛlu.
# 7 39 Naji nɛ a Farasi yɔ akogɔ Jisɔs nsɔl lili ayɛnɔ, wɛ abong atɔg ɛlɛ, “Arenɔ nɛnom ɔfa arenɔ nyɛna amir kin ala kukun ligan nɛnkal yɔ alaga wɛ abɔ kin a kukun arɛ nɛ abeɔfɛm yɔ.”
# 7 40 Jisɔs afanga wɛ, “Sayimɔn mɛ nkpe ɛjom ji na tɔg.” Sayimɔn abong, “Tɔgam nteteba.”
# 7 41 Anɛ abal abal nɛ wurang mbɔ, nɛ wurang akpe wɛ mbɔ akpuga rom ɛgɔr bibal na atil arɔn, nɛ ɔngɔ akpe wɛ mbɔ dinarɔs atil abal na woba.
# 7 42 Abɔ anɛ abalabal amalam akpe wɛ adabɔ, na anɛ ba fa, abal na nɛ yɔ ala ga bɛl likɔrɔ na nɛ?
# 7 43 Sayimɔn afanga, nkɛrɛ ndɛ nɛ yɔfɔ mbɔ ɛyɛ agalɔ fang, Jisɔs atɔgɛ, “Wɔ ɔgba fanga na nsɛrɛ.”
# 7 44 Asibi abri nɛnkal yɔfɔ abong atɔg Sayimɔn, Ɔgba yɛn nɛnkal yɔfa? Mɛ mbal na ɛtɛk ɛja, wɔ mam ɔkaram alib arɛ nwuri na ata ama, nɛnkal yɔfa akɔl abibi ayɛ asoge arabaja ama afɛngɛ akɔ nyu ɛyɛ afol arabaja ama.
# 7 45 Wɔ mam ɔkagam nyɔ bi ɛkuga nyɔ, tatab ji nyɛlɔ fa nɛnkal ɔfa akpere akuga mam nyɔ na arabaja ama.
# 7 46 Wɔ mam ɔwuram aku na ɛsi ɛjama, wɛ yɔ awurɔ mam aku ɛlu na ata.
# 7 47 Mɛ ntɔga wa, akpe ntakpa likɔrɔ ateb ali tum akarɛ na ɛgbem abeɔfɛm ayɛ, nɛ awiawi yɔ alɔ tum akarɛ na asusuga abeɔfɛm ala bɛl nsusuga likɔrɔ.
# 7 48 Jisɔs abong atɔg nɛnkal yɔfɔ, “Ngba tum nkara na abeɔfɛm aya.”
# 7 49 Anɛ bangɔ ba ajɔl li nsɔl na Jisɔs akuma mbonga na atɛm, “Fa ba nɛ yɔ amal a tum akarɛ abeɔfɛm?”
# 7 50 Jisɔs abong atɔg nɛnkal yɔfɔ, ntamɛ ɛya agba wa nyangɛ; sɔng na likɔna.
# 8 1 Naji ngara akpɛlɔ ji, Jisɔs atum lijɛn aseng na bijiba na akpagbɛ, abonga anɔba alom abangɛ Ɔtol Ɔsɔwɔ. Batɔnanjim abɛ woba na abal ajil na nɛ.
# 8 2 Abakal ba alemɔ nɔ abɔ anɔb ayege abɔ abe atugi, na ayam atɔb atɔna wɛ, Meri yɔ ajɔl wɛ kog arɛ Magdalen yɔ ayegɔ wɛ abe ɛtugi arima.
# 8 3 Jowana nkal a Kusa, yɔ ababɛ ɛtɛk Hɛrɔd, Susana, na agbem abakal bangɔ. Abakal ba fa akɔl nsɔl yi abɔ akpenɔ ajɔ nyangɛ Jisɔs na Atɔnanjim ayɛ.
# 8 4 Anɛ ajɔl jog na ɛgbem bijiba abaga naji Jisɔs, naji ɛbɔngɛ ɛlɔ gba Jisɔs atob abɔ ligan lifa.
# 8 5 “Mbima ɛgbɛ ajil abim amug a nsɔl ayɛ. Naji awuri amug yafɔ, amuga nsɔl yandɛga awuri na mba, anɛ anyɛdɛ anyamfor ali.
# 8 6 Yandɛga awuri na atal naji akumɔ mɛra, atore akpɔ ateb alib ajɔlam fɔ.
# 8 7 Yandɛga agbɔl ayɛl na ajɔnga amɛr ajɔnga ajumi abɔ
# 8 8 yangɔ agbɔ na ɛteng nde abenga ɛnɔbnɔbɛ, mug ayiayi akab nkab atil arɔn.” Jisɔs akur bong, arigi abɔ, “Nɛ awiawi yɔ akpenɔ atong nɔng ayog!”
# 8 9 Batɔnanjim abɛ abibɛ ji ligan lifɔ ɛjogɔ.
# 8 10 Jisɔs abong arɛ, “Ɔsɔwɔ agba wun lem ɔmɛngɛ nsɔl yi abirɔ abangɛ Ɔtol Ɔsɔwɔ.” Anɛ bangɔ ntoba abɔ ligan. Na ngara yi ala bri anim yɛn, ayonge atong ɛnim sar abɔ.
# 8 11 Yog lisara li ligan lifa: Mug yi arenɔ lilom Ɔsɔwɔ.
# 8 12 Amug ya agbɔlɔ na mba are anɛ ba alɔ yog nim aba yege alom yafɔ na ntem abɔ, na ngara yi adɛmal atamɛ abɛl ɔnyangɛ
# 8 13 Ya agbɔlɔ na atal are anɛ ba ayoga alom Ɔsɔwɔ akɔ na ɛyɛbalitem titi abɛl am arug. Ala tamɛ nana ngara sed, ngara yi ligara ɛlɔ ba abɔ agbɔ.
# 8 14 Amug ya agbɔlɔ ayɛl na ajɔnga are anɛ ba ayogɔ alom Ɔsɔwɔ naji abɔ ajɛna ajiga na likpen abɔ, ɛfegayɔ ayɔ abangɛ nsɔl likpen, afang, anɔba nsɔl ya likpen, ala bole ntem abɔ ɛtɔna fɔ anim lem ɛnɔbnɔbɛ.
# 8 15 Amug ya agbɔlɔ na ɛteng nde are akarɛ anɛ ba ɛtete na nɔba litem, ba ayoga alom Ɔsɔwɔ, abɔb abom na ntem, akak asig akab ateng akab.
# 8 16 “Nɛ sang yɔ ala wɔnlɛ ɛnwɔlɛ abir na ndɛl afi akɔ akag na nub a ɛgbenga. Anwɔlɛ akone na ɛkone ɛnwɔlɛ ngara yi nɛ alɔ yɛl na njo ala yɛn liro lifɔ.
# 8 17 Sang ji abirɔ ji ɛdɛ jog na ɛtegla. Sang ji abolɔ ji ɛdɛ rebi na ɛwerang.
# 8 18 Ɛlɔ jɔl anɔ kone ɛkpo ngara yi mɔng ɔyoga, nɛ awiawi yɔ akpenɔ alɛ kpɛkpɛlɛ, nɛ yɔ adɛnɔ bɛl ji akɛrɔ arɛ akpenɔ alɛ tatabɛ.”
# 8 19 Nyɛn Jisɔs na Abɔnyɛn abal wɛ nyɛna, wɛ amal am arir na biji ateb ɛbɔngɛ anɛ.
# 8 20 Nɛ wurang atɔgɛ arɛ, “Nija na Abɔnyɛn aba ayem na ɛtegla asɛba arɛ ayɛna.”
# 8 21 Jisɔs afanga abɔ, “Nijama na abɔnyɛn abama are anɛ ba ayoga alom Ɔsɔwɔ akɔ akag na nema.”
# 8 22 Ɔfo brang Jisɔs atɔg atɔnanjim abɛ arɛ, “Ba ba wur ɛkod na nkon aya.” Ayɛl na ɛgba atum lijɛn.
# 8 23 Na ji afiga ajiga, Jisɔs agbɔ lilɔ. Ntakpa nfɛb aba na aya alib ayɛl na ɛgba, abɔ ajɔl na ntakpa ɛfen.
# 8 24 Batɔnanjim abɛ aji nyimi wɛ abonga, “Nsɔjira njo, ɛlag kpɔ o!” Jisɔs anyimi, anyam mfɛb yi fɔ na ɛbog alib, mfɛb adɛ mfom anar.
# 8 25 Jisɔs abib batɔnanjim abɛ, “Ntamɛ ɛyina mɛn?” ɛpkɔl abɔ ɛsi na ɛkokob abong atɔg atɛm. “Fa ba nɛ yɔ anyama nfɛb ayoga wɛ.”
# 8 26 Abɔ afi aji rir na mfom yi akoga arɛ Jɛrasɛn, ji ɛreanɔ na nkone ngɔ yi aya Galili.
# 8 27 Na ji Jisɔs ajigɔ ata na ɛgbok, nɛnom yɔ akpenɔ ɛbe ɛtugi akɔn wɛ. Mba agba rab yi nɛnom yɔfɔ ajɔl jɛn ɛbonjoga nig afɛng ajɔl na ɛtɛk ajɔl na mfom alim.
# 8 28 Na ji ayɛnɔ Jisɔs, agbɔ wɛ na ata akɔn gbogbo, “Ɔsɛba jɛn na agama, Jisɔs Mɔn a Ɔsɔwɔ bi Ɛyurɔyura? ɛtiti ɔtɔbam kag ɛriga.”
# 8 29 Abong anɔ ateb Jisɔs agba nyam abe atugi yafɔ arɛ ajog na biji ɛbɛ. Na ɛgbem ngara atugi abɔb wɛ. Ɛjɔl ji agbadɛ wɛ agbakɔbɔ na ata na abɔ, anɛ ajɔ wɛ babɛ ɛbe ɛtugi ɛjɔl wɛ kam ɛkaga na ɛkpelele.
# 8 30 Jisɔs abibɛ, “Wɔ ɔnyina nan?” Wɛ afanga “Lejɔn” ateb ɛgbem abe atugi agba wɛ yɛl.
# 8 31 Abe atugi yafɔ agɔrɛ Jisɔs nkpɛlɛkpɛlɛ arɛ adɛ nɔngɛ abɔ ayɛl na ndula libe li ɛdɛnɔ bɛl nkulsi.
# 8 32 Ɛbɔngɛ akog ɛjɔl li nsɔl ɛlagɛ ɛtang, abe atugi ya fɔ agɔrɛ Jisɔs arɛ anɔngɛ abɔ aji yɛl akog ya afɔ, akarɛ abɔ ɛkɔ.
# 8 33 Fɔyɔ abe atugi yafɔ alɔ jog na biji nɛnom yɔfɔ ajil ayɛl akog ya fɔ, ɛbɔngɛ akog ya fɔ abɛna abudi ayɛl na aya yafɔ atan.
# 8 34 Naji balɛga akog afɔ ayɛnɔ ji ɛlɔ lem, abɔ abɛna aji tɔra na ɛjiba na afom yangɔ ya arenɔ alagɛ fɔ.
# 8 35 Anɛ abal arɛ aba yɛn ji ɛlɔ lem. Naji alɔ yɛn Jisɔs ayɛn nɛnom yɔfɔ yɔ abe atugi agbalɔ wɛ jog na biji ajigɔ na ata Jisɔs, agbalɔ leba na arɔn ayɛ na nsɛrɛ, abɔ abɛl ɛkokob.
# 8 36 Anɛ ba agbalɔ yɛn atab atɔga anɛ ngara mɔn nɛnom abe atugi yɔfɔ agbalɔ nɔb.
# 8 37 Fɔyɔ anɛ kpakpa ba bijiba bi Jɛrasɛn atɔg Jisɔs arɛ atum abɔ asa, ateb abɛl ɛkokob. Wɛ atum ayɛl na ɛgba ajɛn.
# 8 38 Nɛnom yɔ abe atugi ajogɔ wɛ na biji agɔrɛ wɛ arɛ alagɛ tɔna, wɛ atɛn arɛ,
# 8 39 “Sɔng na ɛtɛk, ɔbong ɔtɔg anɛ ji Ɔsɔwɔ alɔ lem akara.” Nɛnom ɔfɔ afɛngɛ njim na bijiba aji tɔra atɔg anɛ ji Jisɔs alɔ lem akarɛ.
# 8 40 Naji Jisɔs afɛngɔ ɛbɔngɛ ɛbal ɛkpera wɛ ateb ajɔl wɛ seg.
# 8 41 Ɛbɛl nɛnom wurang yɔ ajɔl wɛ kog are Jayirus, ntobɛsi na ɛkpasega abal aba jumi ndung na ata Jisɔs agɔrɛ wɛ arɛ aba na ɛtɛk ɛjɛ.
# 8 42 Ateb mɔn ɔwɛ yɔ ɔkal wurang wuranga mɔn yɔ nya woba na ɛbal alag kpɔ. Naji Jisɔs ajɛna ajiga ɛbɔngɛ anɛ ɛgba wɛ ɛkag.
# 8 43 Na ɛbɔngɛ jifɔ ɛbɛl Nɛnkal wurang yɔ along ajɔlɛ jog na nya woba na ɛbal nɛ sang yɔ amalɔ alemɛ anɔb.
# 8 44 Ajog wɛ na njim abal afele wɛ na ntong ɛwuri, fɔtutu along akeme.
# 8 45 Jisɔs abib, “Ba nɛ yɔ akɔmɔ mam?” Naji abɔ fɛb atɛnɔ, Pita abong, “Nsɔjama njo ɛbɔngɛ ɛgba wa nyɛdɛ.”
# 8 46 Jisɔs abong, “Nɛ akɔma mam, mɛ nkukun ɛkɔ ɛgba mam jog.”
# 8 47 Fɔyɔ nɛnkal yɔ fɔ ayɛna arɛ agba wɛ renge, akuma ntigi aba gbɔ wɛ na ata. Na libri anɛ, atɔra ji ɛkerɔ wɛ akɔma wɛ na ngara yifɔ anɔb fɔ tutu.
# 8 48 Wɛ abong atɔgɛ, “Mɔn ɔkal ntamɛ ɛya agba wa lem ɔnɔb. Sɔng na likɔna.”
# 8 49 Naji Jisɔs akpenɔre abonga ntɔga, nɛ wurang ajog na ɛtɛk Jayirus ntobɛsi a ɛkpasega. Aba tɔgɛ arɛ, “Mɔn ɔwa yɔ kal agba kpɔ, ɔtɔb kpɛ fege nteteba ayɔ.”
# 8 50 Naji Jisɔs ayogɔ abong atɔg Jayirus arɛ, “Ɔtɔb bɛ, bɛl ntamɛ, ala nɔnɔb.”
# 8 51 Naji Jisɔs arirɔ na ɛtɛk Jayirus atamam nɛ atɔna wɛ ayɛl ndɛg Pita, Jɔn na Jemsi na ndɛ na nyɛn mɔn yɔ fɔ.
# 8 52 Na ngara yifɔ. Anɛ kpakpa akuma wɛ ndera akara liku ateb liku mɔn yɔfɔ. Jisɔs abong arɛ, “Balɔ arer wɛ aka kpɔ am alalal.”
# 8 53 Abɔ ayɔlɛ ateb anyinyi arɛ wɛ agba kpɔ.
# 8 54 Jisɔs afele wɛ na ɔbɔ abong, “Mɔn ɔma, tum yema!”
# 8 55 Ɛtugi ɛjɛ ɛfɛngɛ, fɔ tutu atum ayema. Fɔ yɔ Jisɔs atɔgɔ nɔ abɔ arɛ akarɛ ɛjom lili ali.
# 8 56 Ɛkokob ɛjɔl na anɛ abɛ, arigi abɔ arɛ adɛ tɔg nɛ awiawi ji ɛlɔ lem.
# 9 1 Jisɔs akog Arɔb ayɛ woba na abal atu mfom yirang, akarɛ abɔ ɛkɔ na nsim arɛ akam abe atugi atɔb alem anɛ ayam.
# 9 2 Atom abɔ arɛ asɔng aji tebe ɔteb bi ɛjiba ɔtol Ɔsɔwɔ afɛngɛ alem anɛ ayam.
# 9 3 Arigi abɔ arɛ, “Ɔtɔb tab ɛjom ajiaji na lijɛn li fɔ. Ɔtɔb tab bite lijɛn, ɔtɔb tab ɛbam, ɔtɔb tab nsɔl lili, ɔtɔb tab akpuga, ɛjɔl ɛlimi.
# 9 4 Ɛtɛk ajiaji ji wun ɔyɛlɔ ba jɔl na ɛtɛk jifɔ jirang tɛtɛ wun ɔtum ɛjiba jifɔ.
# 9 5 Anɛ adɛnɔ wun kpera, ba tum ɛjiba abɔ wun ɔkom ɛbubu ji ɛgbɛlɔ wun na ata ji ɛla jɔl mɔng ɛjom ɛrigi ɛkarɛ abɔ.”
# 9 6 Arɔb ayɛ atum ajɛn bijiba na bijiba atebe ɛteng ɔteb alema anɛ ayam na kpakpa afom.
# 9 7 Naji Hɛrɔd ntol a Galili ayogɔ abangɛ nsɔl kpakpa yi ɛlɔ lem, abɛl ntakpa buburi, ateb arɛ anɛ bangɔ ajɔl bong arɛ Jɔn nwura alib agba nyimi na liku.
# 9 8 Bangɔ arɛ Ɛlayija yɔ alɔ teb ɛlɛ, anɛ bangɔ arɛ nyɛna amir wurang yɔ ɔkubingɔ wɛ alɔ fɛngɛ njim na likpen.
# 9 9 Hɛrɔd abong arɛ, “Mɛ yɔ nkemɔ Jɔn ɛsi. Ba nɛ yɔ nkpɛg yog nsɔl yi fa mbangɛ?” Ajɔl gara arɛ ayɛn Jisɔs.
# 9 10 Naji Arɔb ayɛ akurɔ atɔra ji abɔ alemɔ atɔg Jisɔs. Fɔyɔ atabɔ nɔ abɔ na wɛ nfɔnɛ atum na ɛjiba ji akoga arɛ Bɛtsayida.
# 9 11 Naji ɛbɔngɛ anɛ ayogɔ abangɛ mfom yi afenɔ atɔna wɛ. Akpera abɔ abong atɔg abɔ abangɛ ɛjiba ɔtol Ɔsɔwɔ, alema anɛ anɔb ba asɛba arɛ anɔb.
# 9 12 Na ngara ligoligo Arɔb ayɛ woba na abal, abal atɔgɛ arɛ. “Tom ɛbongɛ anɛ ji fa tu na bijiba na bigbɛ bi ɛreanɔ ɛlagɛ aji sɛb nsɔl lili na mfom yi abɔ ala nɔnga alagtu afa, ateb arɛ mfom yifa arena ɔnwɔlɛ.”
# 9 13 Jisɔs afanga, “Wun bafɔnɛ ba karɛ abɔ nsɔl ali.” Abɔ afanga, “Wur ɛkpe ngba brɛd ɛrɔng na nyam alib ɛbal afi ɔsɛb arɛ wur ɛji gona nsɔl lili ɛba karɛ ɛbɔngɛ anɛ ji fa?”
# 9 14 Abalom ɛgɔr litil na bɛrɔn ba ajɔlɔ fɔ. Jisɔs abong atɔg Arɔb ayɛ, “Tɔg abɔ ajɔl na nde na ɛkun ɛkun mɔng anɛ atil abal na woba.”
# 9 15 Batɔnanjim abɛ alem anɔ mɔng wɛ abongɔ anɛ kpakpa ajɔl na nde.
# 9 16 Atab ngba brɛd ɛrɔng na nyam alib ɛbal abri na libonta, akag Ɔsɔwɔ sam abɛg, atab akarɛ Batɔnanjim abɛ arɛ akarɛ anɛ.
# 9 17 Abɔ fɛb ali awuri. Batɔnanjim abɛ afugi nkpal woba na ɛbal na ya asalɔ.
# 9 18 Ɔfo brang Jisɔs ajɔl kag ɔrɔ na nara mfom. Batɔnanjim abɛ ajɔl na nɛ, abib abɔ, “Baligan nɛ yɔ anɛ abonga arɛ mɛ ndenɔ?”
# 9 19 Abɔ afanga, “Anɛ bangɔ arɛ wɔ Jɔn nwura alib, bangɔ arɛ wɔ Ɛlayija, bangɔ arɛ wɔ nyɛna amir yɔ ɔkubingɔ yɔ alɔ tore afɛngɛ njim aba na likpen.”
# 9 20 Wɛ abib, “Wun mɛn? Wun arɛ mɛ ba nɛ yɔ?” Pita afanga, “Wɔ Krayis yɔ Ɔsɔwɔ.”
# 9 21 Jisɔs arigi batɔnanjim abɛ arɛ adɛ tɔg nɛ awiawi nɛ yɔ wɛ arenɔ.
# 9 22 Jisɔs atɔg batɔnanjim abɛ arɛ, “Mɔn a Nɛnom ala yɛn ɛriga na ɛgbem nsɔl, atobɛsi, atol a balemanjɔm na ba teba ajing ya Mosis ala wɛ tɛn ayolɛ, na mfo ɛra ala nyimi na liku.”
# 9 23 Jisɔs abong atɔg abɔ kpakpa: “Nɛ awiawi yɔ alagɔ jɔl ntɔnanjim ɔma ateg atɛn ɛlɛ atab krɔs ɛjɛ ɔfo abiabi atɔna mam.
# 9 24 Nɛ awiawi yɔ ala gɔ nyangɛ likpen ɛlɛ, ɛlɛ tatan, nɛ awiawi yɔ alɔ tanɛ likpen ɛlɛ na ɛsi ɛjama ala totore.
# 9 25 Ba nɔba yi arenɔ akarɛ nɛ arɛ ali nseng ɛyeng atanɛ likpen ɛlɛ?
# 9 26 Nɛ awiawi yɔ alɔ bɛl ndɔn na nama na alom ama, Mɔn a Nɛnom atɔb abɛl ndɔn na nɛ naji wɛ alɔ ba na liloba ɛlɛ na liloba Tata na li bateb ɔteb Ɔsɔwɔ.”
# 9 27 “Mɛ ntɔga wun ɛtete, bandɛga ba ayemɔ fa anim teg ayonge liku tɛtɛ ayɛn Ɔtol Ɔsɔwɔ.”
# 9 28 Na mfo ɛnigni naji alɔ bong ɔtɔga bifa, Jisɔs, atab Pita, Jɔn na Jemsi akod ɛwɔng aji ɔrɔ nkaga.
# 9 29 Naji ajɔl kag ɔrɔ, libri ɛlɛ ɛyanga abɔma ayɛ ajɔ ya mɔng nwangdo.
# 9 30 Fɔ tutu abalom abal, Mosis na Ɛlayija ajog na liloba li libo akuma mbonga na Jisɔs.
# 9 31 abɔ abonga abangɛ liku ɛlɛ li ɛla lem na Jɛrusɛlɛm naji nkanter Ɔsɔwɔ ala jɔl na ɛtete.
# 9 32 Pita na anɛ ba lijɛn abɛ ajɔl lalal, naji abɔ anyimɔ, ayɛn liloba li Jisɔs na abalom abal ayemɔ na nɛ.
# 9 33 Naji Mosis na Ɛlayija alagɔ tum Jisɔs asa, Pita abong atɔgɛ. “Nsɔjama njo, ɛgba nɔb arɛ wur ɛre fa. nɔng wur ɛsi ɛkpa bɛra, jirang ɛja, jirang ji Mosis jingɔ ji Ɛlayija.” (Wɛ akunam ji ajɔl bong).
# 9 34 Naji Pita ajɔl bong mfom abumi abole abɔ fɛb, ɛkokob ɛbɔb abɔ naji mfom abumɔ abole abɔ.
# 9 35 Lilom ɛjog na mfom yi abumɔ ɛbong, “Fa Mɔn ɔma yɔ ɔlom, yɔ mɛ nɔ yege. Yonge atong karɛ.”
# 9 36 Naji lilom ɛlɔ bong ɛlɔ, Jisɔs ajɔl nanting. Batɔnanjim abole anyɔ ategam atɔg nɛ awiawi na ngara yifɔ ji abɔ yɛn.
# 9 37 Na ɛtɔna ɔfo na ji alɔ budi na ɛwɔng, ɛbɔngɛ anɛ ɛba ɛkɔn Jisɔs
# 9 38 Nɛnom na lirɔng abɔ ajog akɔn gbogbo, “Nteteba, mɛ ngɔrɛ wa ndɛ wɔ ɔyɛn mɔn ɔma yɔ lom, ateb fa mɔn ɔma wurang wuranga.
# 9 39 Ɛbe ɛtugi ɛbɔb wɛ ɛlemɛ akuma nkɔna; ɛlema wɛ agbɔga ɛtitik aful ajoga wɛ na nyɔ. Ɛnim jɔga ɛdaga wɛ abɔ ɛrungi wɛ ɛjiga.
# 9 40 Mɛ ngɔrɛ batɔnanjim aba ndɛ akam ɛbe ɛtugi jifɔ ayege, amalam.”
# 9 41 Jisɔs afanga, “Wun anɛ ba ɔdɛnɔ bɛl ntamɛ na ba lema abeɔfɛm! Na jɔl nan na nina nfɛng nkar nan na nina?” Afɛng abong atɔg nɛnom yɔfɔ arɛ, “Bafa na mɔn ɔwa.”
# 9 42 Naji mɔn yɔ lom ajɔlɔ ba ɛbe ɛtugi ɛromɛ ɛtob na nde na ngbɔbɔga. Jisɔs atob ɛbe ɛtugi ɛgan, alem mɔn ɔfɔ anɔb, atu wɛ akarɛ ndɛ.
# 9 43 Ɛkpɔl anɛ kpakpa ɛsi ateb ntakpa ɛkɔ Ɔsɔwɔ. Ɛkpɔl anɛ ɛsi na nsɔl yi Jisɔs alɔ lem, abong atɔg batɔnanjim abɛ
# 9 44 “Ba yonge atong ɛnɔb nɔbɛ ji mɛ nagɔ wun tɔg: ala da mɔn a nɛnom akag na abɔ ya ba ayola anɛ.”
# 9 45 Ntɔga yifa asaram batɔnanjim abɛ mɔng ɛjogɔ. Ɛjɔl ɛbobo ntɔga ategam akun, ajɔl bɛ amir ayɛ amalam abibɛ.
# 9 46 Batɔnanjim abɛ akuma nfabɛ na atɛm nɛ yɔ ala jɔl ntobɛsi abɔ.
# 9 47 Jisɔs akukun ji abɔ ajɔl kɛrɛ, atur na mɔnsɛ ayeme alag ɛlɛ.
# 9 48 Abong atɔg abɔ, “Nɛ awiawi yɔ akperɔ mɔn sɛ yɔfa na mbeng ɛma akpera mam; nɛ awiawi yɔ akperɔ mam akpera nɛ yɔ atomɔ mam. Nɛ yɔ agalɔ rɛda na ɛbɔngɛ ɛjina kpakpa wɛ yɔ ala jɔl ntobɛsi.”
# 9 49 Jɔn abong arɛ. “Nsɔjama njo Wur ɛyɛn nɛyɔ akɔga mbeng ɛya ayege abe atugi wur ɛnɔk arɛ ɛsidi wɛ ateb wɛ ayɔbam lirɔn ɛlira.”
# ...
# 22 14 Naji ngara arirɔ Jisɔs na arɔb ayɛ ajɔl na ɛkpokoro.
# 22 15 Abong atɔg abɔ arɛ, “Mɛ njɔl nsɛb ndɛ mɛ ni likag li ɛlɔ seng na nina nig mɛ nyɛn ɛriga.
# 22 16 Mɛ ntɔga wun, Mɛ nim kpɛ teg ni ndɛg nkanter ɛyɛ ali bɛl ribi na Ɔtol Ɔsɔwɔ.”
# 22 17 Fɔyɔ atabɔ mig akag Ɔsɔwɔ sam abong arɛ, “Bakɔ wun ɔbak ɔkarɛ ɛlina.
# 22 18 Mɛ ntɔga wun mɛ nim kpɛ teg nwɔ amum ya akaba nte tɛtɛ Ɔtol Ɔsɔwɔ ɛba.”
# 22 19 Atab brɛd, akag Ɔsɔwɔ sam, abɛg atab akarɛ abɔ abong arɛ, “Fa ngoabiji ɛma yi mɛ nkarɛ wun. Ba lem anɔ wun ɔgbɔ mam nter.”
# 22 20 Na mba yifɔ titi, naji nsɔl lili ɛlɔ mal, atab mig abong arɛ, “Mig yifa nfɛ a ɛnwɔngɛ yi along ama, ala fa akarɛ wun.
# 22 21 Ɔbɔ nɛ yɔ alam gore ajig fa na ɛkpokoro na nama.
# 22 22 Mɔn a nɛnom ala kpɔ mɔng Ɔsɔwɔ abongɔ, ligbo ɛla jɔl na nɛ yɔ ala wɛ gore.”
# 22 23 Batɔnanjim abɛ akuma atɛm mbiba ba nɛ yɔna ɛbɔngɛ ɛjira yɔ ala lem ligan ɛjom ji fa.
# 22 24 Nfab ajog na ɛbɔngɛ batɔnanjim abɛ abangɛ nɛ yɔ agalɔ jɔg na ɛbɔngɛ abɔ.
# 22 25 Jisɔs abong atɔg abɔ, “Atol a anɛ ba ɛyeng jifa alema batɔnanjim abɔ atamɛ atuga abɔ; anɛ ba akpenɔ ɛkɔ aseng anɛ bangɔ, asɛba arɛ ajɔ kog abɔ arɛ atɛm anɛ.
# 22 26 Wun ɔtɔb jɔl anɔ, nɔngɛ nɛ yɔ agalɔ jɔg na ɛbɔngɛ ɛjina ajɔl mɔng mɔnsɛ, nɛ yɔ arenɔ ntobɛsi ajɔl mɔng ndɔgalitom.
# 22 27 Ba nɛ yɔ agalɔ jɔg nɛ yɔ akonɔ na ɛkpokoro aliga nsɔl afi nɛ yɔ arɔgɛ litom? Nɛ yɔ akonɔ na ɛkpokoro arig ɛ? Mɛ nde na ɛbongɛ ɛjina mɔng ndɔgalitom.
# 22 28 Wun ɔjɔl anɛ ba ɔyemɔ na nama na ngara ɛfegayɔ.
# 22 29 Mɛ ngba wun karɛ ɛkɔ ndɛ wun ɔlem ɔtol mɔng nsɔjama akarɔ mam.
# 22 30 Na ngara yi wun ɔmal ɔli ɔfɛnɡɛ ɔwɔ na ɛkpokoro ɛjama na ɛjiba Ɔtol ɔjɔl na nji ɔtol ɛbama nub woba ɛbal ji Isrɛl.
# 22 31 “Jisɔs abong atɔg Sayimɔn Pita arɛ, Sayimɔn, Sayimɔn nim agba gɔrɛ Ɔsɔwɔ arɛ akarɛ nsim wɛ afɛb wun mɔng nsang.
# 22 32 Mɛ ngba kag ɔrɔ nkara, Samiyɔn, ndɛ ntamɛ ɛya adɛ gbɔ. Naji ɔlɔ fɛngɛ njim ɔba, lem abɔnyɛn aba akore ba atɔna mam.”
# 22 33 Pita afanga arɛ, “Tata, mɛ ngba tore biji ndɛ mɛ ntɔna wa nji na ngbakɔbɔ, nfɛng nkpɔ nana.”
# 22 34 Jisɔs afanga arɛ, “Mɛ ntɔga wa, Pita, nig nkɔk akog ɛlɛl, wɔ ɔlam tɛn nkpɛlɛ ɛra arɛ wɔ mam ɔnyim.”
# 22 35 Jisɔs abib batɔnanjim abɛ arɛ, “Naji mɛ ntomɔ wun na ngara yifɔ, nsusuga ɛbam na akpagata wun ɔfelam wun ɔkiking ɛjom ɛ?” Abɔ afanga, “ii.”
# 22 36 Abong atɔg abɔ, “Batig ɔlɔ bɛl ɛbam tab, ɔlɔ bɛl nsusuga ɛbam tab, ɔdɛgɔ fɛngɛ ɔbɛl ɔkankang, gore ɛlimi ɛja wɔ ɔgona brang.
# 22 37 Agba yɛlɛ na Nwɛr Ɔsɔwɔ: ‘Afal wɛ akpɛlɛ na ba lema abeɔfɛm.’ Mɛ ntɔga wun ɛtete ndɛ jifa ɛla ɛteg ɛjɔl anɔ na biji ɛbama, nsɔl yi ayɛlɔ abangɛ mam ɛlag ba njɔla ɛtete.”
# 22 38 Batɔnanjim abɛ abong arɛ, “Tata, yɛn, wur ɛkpe ɔkankang abal.” Wɛ afanga arɛ, “Ɛli fang!”
# 22 39 Jisɔs atum aji na ɛwɔng ɔlif ngara mɔng yi ajɔga jiga batɔnanjim abɛ atɔna wɛ.
# 22 40 Naji arirɔ ngɔ, abong atɔg abɔ arɛ, “Ba kag ɔrɔ naji wun ɔdɛ gbɔ ɔyɛl na ligara.”
# 22 41 Fɔyɔ ajɛnɔ aji na ɔsi sed mɔng nɛ amal arɔ lital ɛrir, aji jumi ndung akak ɔrɔ.
# 22 42 “Nsɔjama, ɛlɔ kɔra tabɛ mam mig ɛriga yifa; lem mɔng ɛkɔrɔ wa ɛkɔ ɛjama arig nɔng nter ɛya alem.”
# 22 43 Nteb ɔteb na libo abudi aba karɛ ɛkɔ.
# 22 44 Na ntakpa liyama akak ɔrɔ na ɛkora biji; liyobe ɛlɛ ɛjɔl mɔng along ya ajɔl tɔng awuri na nde.
# 22 45 Naji alɔ tum na ɔrɔ, afɛngɛ njim naji batɔnanjim abɛ, aji yɛn abɔ naji alɔlal, agba kɛr ateb agbɔl awuma.
# 22 46 Jisɔs abib abɔ arɛ, “Bejom ji wun ɔlala? Ba tum ba yema wun ɔkag ɔrɔ na ngara yi wun ɔdɛ gbɔ ɔyɛl na ligara.”
# 22 47 Naji Jisɔs akpenɔre abonga ɛbɔngɛ anɛ ɛba na nɛnom yɔ ajɔl wɛ kog arɛ Judas nɛ wurang na anɛ woba abal na ɛbɔngɛ batɔnanjim abɛ. Judas ajɔl teb abɔ mba, ajɛn aba kug Jisɔs nyɔ.
# 22 48 Jisɔs abibɛ arɛ, “Judas, nyɔ kukug bi ɔlagɔ kɔ ɔgore Mɔn a Nɛnom?”
# 22 49 Naji batɔnanjim a Jisɔs ayɛnɔ ji ɛlagɔ nɔ lem, abɔ abib, “Tata Ɛyege ɔkankang ɛbra ɛnɔgɛ?”
# 22 50 Nɛ wurang akem ɔtong ɔbɔ bilom bi njo a ndɔgalitom yɔ ntakpa nemanjɔm.
# 22 51 Jisɔs abong arɛ, “Ɛgba fang!” Alag nɛnom ɔfɔ na ɔtong atore alemɛ anɔb.
# 22 52 Jisɔs abong atɔg atol a balemanjɔm na atakpa anɛ ba ababɛ Njo Ɔsɔwɔ na abakol, ba abalɔ wɛ mbɔba, “Bɛjom ji wun ɔbaga na ɔkankang na akpɔra nte mɔng ndenɔ nwaju?
# 22 53 Kpakpa afo Mɛ njɔl na nina na Njo Ɔsɔwɔ, wun ɔtegam ɔgara arɛ ɔlaga mam abɔ. Fa ngara ɛyinayi yi, naji ɛkɔ ɛjingi ɛlema nsim.”
# 22 54 Abɔb Jisɔs atabɛ aji na ɛtɛk ntakpa nemanjɔm Ɔsɔwɔ, Pita atɔna na ɛkɛbɛ.
# 22 55 Naji akɔrɛ ngon na lika ɛtɛk, Pita atɔb aji jɔl na anɛ ba ajɔlɔ atob ngon asibi.
# 22 56 Naji ndɔgalitom a nɛnkal ayɛnɔ wɛ ajigɔ na nkɛ a ngon, abri wɛ ɛnɔbnɔbɛ abong arɛ, “Nɛnom ɔfa ajɔl na nɛ!”
# 22 57 Pita atɛn abong arɛ, “Nɛnkal, mɛ wɛ nyim!”
# 22 58 Naji ɛlɔ lɛna sed nɛ yɔndɛga akpɛ wɛ yɛn abong arɛ, “Wɔ titi nɛ ɔwɛ yɔ!” Pita afanga arɛ, “Nɛnom mɛ arig!”
# 22 59 Naji ɛlɔ rir ngbɛga yirang, nɛnom yɔndɛga akpɛ bong arɛ, “Na ɛtete nɛnom ɔfa ajɔl na nɛ, ateb wɛ nɛ a Galili yɔ.”
# 22 60 Pita afanga arɛ, “Nɛnom, mɛ nyim ji wɔ ɔbonga ɔbangɛ!” Naji akpenɔre abonga nkɔk akog.
# 22 61 Tata Jisɔs anwek abri Pita jangjang. Fɔ tutu Pita agbɔ nter ji Tata abongɔ atɔgɛ, “Nig nkɔk akog ɛlɛl wɔ ɔlam tɛn nkpɛlɛ ɛra”
# 22 62 Pita ajog na ɛtagla aji lul nkorenkore.
# 22 63 Abalom ba ajɔl babɛ Jisɔs ajɔl wɛ du afɛngɛ ayɔla wɛ.
# 22 64 Abɔ abole wɛ amir abibɛ arɛ, “Gaba! Ba nɛ yɔ aromɔ wa?”
# 22 65 Abɔ atol wɛ ɛgbem ɛgbem.
# 22 66 Naji ɔforanfo ɛlɔ kparɛ abakol na atol a balemanjɔm na ba teba ajing ya Mosis akɔn mfom yirang. Akɔ Jisɔs aba na libri batoramfam.
# 22 67 Abɔ abong arɛ, “Ɛlɔ jɔl arɛ wɔyɔ ɔrenɔ Krayis, tɔg wur.” Jisɔs afanga arɛ, “Mɛ nɔ tɔg wun, wun ɔnim tamɛ ɔtu mam.
# 22 68 Mɛ nɔ bib wun mbiba wun ɔnim ma fanga.
# 22 69 Bɔm batig sɔng, Mɔn a Nɛnom ala jɔl na ɔbɔ bilom bi Ɔsɔwɔ bi ɛgalɔ yura.”
# 22 70 Abɔ fɛb abong arɛ, “Fɔ yɔ Ɛjogɔ arɛ wɔ yɔ ɔrenɔ Mɔn Ɔsɔwɔ?” Wɛ afanga arɛ, “Wun ba ɔlɔ bong anɔ.”
# 22 71 Abɔ abong arɛ, “Jɛnji ɛkpɛ sɛb ntiansɛ yindɛga! Wur ɛgba yog na nyɔ ɛbɛ!”
# 23 1 Batoramfam atum ayema atab Jisɔs aji naji Payilet.
# 23 2 Akuma wɛ nlagɛ arɛ: “Wur ɛbɔb nɛnom ɔfa naji atoba anɛ abe a nlɛ, atɔga abɔ arɛ adɛkpɛ kpe ataksi akarɛ Sisa afɛnga ayɔra nyɔ arɛ wɛ yɔ arenɔ Krayis ntol.”
# 23 3 Payilet abib Jisɔs arɛ, “Wɔ yɔ ɔrenɔ ntol a Ju ɛ?” Jisɔs afanga arɛ, “Wɔ yɔ ɔbongɔ anɔ.”
# 23 4 Fɔyɔ Payilet abong atɔg atol a balemanjɔm na ɛbɔngɛ anɛ arɛ, “Mɛ nkayɛnam ɛjom ji alɔ lem ji mɛ nɛ lam.”
# 23 5 Abɔ atɛn arɛ, “Nteba ɛyɛ abaga na ɛfegayɔ na Judiya kpakpa. Abɔm na Galili batig agba rir fa.”
# 23 6 Naji Payilet ayogɔnɔ abib arɛ, “Nɛnom ɔfa ajog Galili ɛ?”
# 23 7 Naji akunɔ arɛ Jisɔs ajog nkɛr yi Hɛrɔd arenɔ ntol, atomɛ atu Hɛrɔd, yɔ ajɔlɔ na Jɛrusɛlɛm na ngara yifɔ.
# 23 8 Naji Hɛrɔd ayɛnɔ Jisɔs, abɛl ntakpa ɛyɛba litem ateba arɛ na ndaba mba ajɔl sɛb arɛ ayɛnɛ. Ateb nsɔl yi alɔ yog abangɛ wɛ, ajɔl kɛrɛ arɛ ayɛn Jisɔs alema akpɔga ɛsi.
# 23 9 Hɛrɔd abib Jisɔs agbem abiba, Jisɔs ategam afanga.
# 23 10 Atol a balemanjɔm na bateba ajing ya Mosis ayema fɔ, ajɔ kem akem alagɛ wɛ nkorenkore.
# 23 11 Hɛrɔd na ɔsɔja ɛbɛ akuma Jisɔs nsiba, akili wɛ amin. Ayɔbɛ wɛ ɛteng ndaba ɛwuri, atore atomɛ atu Payilet.
# 23 12 Na ɔfo bi fɔ Hɛrɔd na Payilet atore ajɔl ɔtɛm, ateb arɛ abɔ ajɔl na ɔjing.
# 23 13 Payilet akog atol a balemanjɔm, batoramfam na anɛ atu mfom yirang,
# 23 14 abong atɔg abɔ arɛ, “Wun ɔkɔl nɛnom ɔfa ɔbakam arɛ wɛ nsɛba afɛm. Batig mɛ ngbalɛ lam na libri ɛlina nkayɛnam ɛbe ɛjom ɔbangɛ akem ya wun ɔlɔ kem ɔlagɛ wɛ.
# 23 15 Ɛjɔl Hɛrɔd, ayɛnam ɛbe ɛjom na biji ɛbɛ yiyi alɔ wɛ tom atu wur. Mɔng wun ɔlɔ yɛn nɛnom ɔfa aka lemam ɛbe ɛjom ji ɛkerɔ ala kpɔ.
# 23 16 Fɔ yɔ ɛla ker mɛ nkarɛ ɛkɔ adu wɛ ada wɛ abɔ asɔng.”
# 23 17 Na likag li aseng asa Payilet ajɔga ayege nɛnom wurang na ngbakɔbɔ adabɔ akarɛ abɔ.
# 23 18 Ɛbɔngɛ anɛ akuma nkɔna gbogbo abonga, “Yolɛ! wɔ yege Barabas ɔkarɛ wur!”
# 23 19 Barabas arɔr wɛ akak na ngbakɔbɔ ateb asɛb akpadɛ na ɛjiba afɛng ayol anɛ.
# 23 20 Payilet ajɔl sɛb arɛ ada Jisɔs abɔ akpɛ bong atɔg abɔ.
# 23 21 Abɔ atore ajɔ kpɛ kɔn, “Komɛ na krɔs! Komɛ na krɔs!”
# 23 22 Payilet abong atɔg abɔ na nkpɛlɛ ɛra, “Ba ɛbe ɛjom ji wɛ alɔ lem? Nkayɛnam ɛjom ji wɛ alɔ lem ji ɛlaker wɛ akpɔ! Mɛ nɛ du nɔngɛ wɛ asɔng.”
# 23 23 Abɔ fɛb atore ajɔ kɔn na nyura lilom arɛ akom Jisɔs, na nkukura akɔn akɔn abɔ ɛlem ɛkarɛ abɔ.
# 23 24 Fɔyɔ Payilet atamɔ ji abɔ ajɔl bib.
# 23 25 Ayege nɛnom yɔ arɔrɔ wɛ akag na ngbakɔbɔ ateb asɛb akpadɛ na ɛjiba afɛng ayol anɛ, nɛ yɔ abɔ ajɔl bib. Adal Jisɔs abɔ akarɛ abɔ, arɛ aji lem ji ɛkɔrɔ abɔ.
# 23 26 Naji ɔsɔja ɛtabɔ wɛ ɛjɛn, abɔb Sayimɔn yɔ Syrɛn yɔ ajogɔ aba nyɛla na ɛjiba, atab krɔs asi wɛ alemɛ asima, atɔna Jisɔs na njim.
# 23 27 Ntakpa ɛbɔngɛ anɛ ajɔl wɛ tɔna, na abakal ba ajɔl wɛ lul ateba ndɔn.
# 23 28 Jisɔs anwek abri abɔ abong arɛ, “Abakal ba Jɛrusɛlɛm, wun ɔdɛ mam kpɛ rer, ba rer ɛlina na abɔn abina.
# 23 29 Ngara ayɔbak yi wun ɔla bong arɛ, ‘Lifola ɛjɔl na ngom, ala ya adɛdɛ gbɛl na abɛl ya adɛdɛ yab!’
# 23 30 Anɛ ala bong atɔg ɛwɔng, ‘Gbɔ bole wur!’ Atɔg ɛkporogon, ‘Bole wur.’
# 23 31 Anɛ alɔ lem nsɔl yi fa naji akpaba nte akpenɔ re mbernber ɛla jɔl nan naji nkon ɛlɔ yom?”
# 23 32 Abalom abal bangɔ ajɔl awaju, atɔb atab abɔ arɛ aji ayol na Jisɔs.
# 23 33 Naji arirɔ na mfom yi ajɔl kog arɛ ɛkpaga ɛsi nɛ, fɔyɔ akomɔ Jisɔs na awaju yafɔ na krɔs, nɛ yɔngɔ na ɔbɔ bilom, yɔngɔ na ɔbɔ bikal.
# 23 34 Jisɔs abong arɛ, “Nsɔjama tum karɛ abɔ anyim ji abɔ alema.” Abanga abɔma ayɛ atob lifanga.
# 23 35 Anɛ ayema fɔ abri. Atobɛsi ba Ju ajɔ yɔlɛ abonga arɛ “Anyangɛ anɛ; nɔng anyangɛ ɛlɛ ɛlɔjɔl arɛ wɛ Krayis yɔ, yɔ Ɔsɔwɔ alɔ yege!”
# 23 36 Ɔsɔja titi atɔb ajɔ yɔlɛ. abɔ ajɛn aji karɛ aka amum,
# 23 37 abong atɔgɛ arɛ, “Nyangɛ ɛla ɛlɔjɔ arɛ wɔ ntol a Ju.”
# 23 38 Ayɛlɛ arɛ, “FA NTOL A JU.” alagɛ na ɛsi ɛjɛ
# 23 39 Nwaju yirang yɔ atɔb akomɛ na krɔs akuma wɛ ntoga: “Ndɛ wɔ arɛ wɔ Krayis yɔ? Nyangɛ ɛla wɔ ɔtɔb ɔnyangɛ wur!”
# 23 40 Nwaju yingɔ atobɛ ɛgan, abong arɛ, “Wɔ ɔnim bɛga Ɔsɔwɔ ɛ? Wur ɛyɛna ɛriga jangjang?
# 23 41 Ɛfofoma arɛ wur ɛkpɔ na abeɔfɛm ayira ateb arɛ wur ɛlelem. Wɛ jisɔk alemam.”
# 23 42 Abong atɔg Jisɔs arɛ, “Gbɔ mam nter wɔ ɔlɔ ba na ɛjiba ɔtol ɛba!”
# 23 43 Jisɔs afanga wɛ arɛ, “Mɛ ntɔga wa ɛtete ndɛ ɛlɛl wɔ ɔla jɔl nanama na paradayis.”
# 23 44 Ɛjɔl mɔng nkaranka woba ɛbal yi ɛfente, ɛjingi ɛbole nde tɛtɛ ɛrir nkaranka ɛra yi ligoligo,
# 23 45 Njol ajɔlam kpɛ ya, Mbɔma bi njo Ɔsɔwɔ ɛyar ɛja bibal.
# 23 46 Jisɔs akog na nyura lilom arɛ, “Nsɔjama, na abɔ aya ntab ɛtugi ɛjama nkara!” Naji alɔ bong anɔ akur yɔ nkukura liyɔ arida.
# 23 47 Ntakpa nɛ nsɔja yɔ ayɛnɔ ji ɛlemɔ, ajege Ɔsɔwɔ, abong arɛ, “Ɛtete ji arɛ nɛnom ɔfa ajɔl ɛteng nɛ!”
# 23 48 Naji anɛ kpakpa ba agbalɔ fɔ ayɛna, ayɛn akpɔga ɛsi ya alɔ lem awula abɔ afɛngɛ njim akuri ndɔn ndɔn.
# 23 49 Anɛ kpakpa ba anyinɔ Jisɔs kpɛlɛ na abakal ba atɔnɔ wɛ na Galili ayema dagdagɛ abri ji ɛlɔ lem.
# 23 50 Ɛbɛl nɛnom wurang yɔ ajɔl wɛ kog arɛ Josɛf yɔ ayɔma lirɔng batoramfam, ajɔl ɛteng nɛ afɛnga alema nsɔl ɛyɛ ntɔrantɔra.
# 23 51 Wɛ ategam atamɛ atu ɔtɔga na nema yi abɔ ajɔl lem. Ajog na ɛjiba Judiya ji Arimatiya wɛ nfɔnɛ ajɔl seg Ɔtol Ɔsɔwɔ.
# 23 52 Ajil naji Payilet aji bib ɛku Jisɔs.
# 23 53 Atabɛ abudi na nde, akɔ mbara mbɔma afuwɛ, atabɛ akag na ɔlim bi arimɔ na atal, bi adɛdɛ kag nɛ awiawi.
# 23 54 Ɛjɔl ɔfo bi anɛ ajɔl tore biji naji ɔfo bi Ɛrɛdɛkɛr ɛlagɔ bɔm.
# 23 55 Abakal ba ajogɔ Galili na Jisɔs atɔna Jɔsɛf aji yɛn ɔlim na ngara yi abomɔ ɛku Jisɔs.
# 23 56 Abɔ afɛngɛ njim akuri aji tore nsɔl yi ɛkpenɔ ɛteng ɛlu na aku ya biji. Na ɔfo ɛrɛdɛkɛr abɔ arɛdɛkɛr mɔng ajing abongɔ.
# 24 1 Na ngbɔgamba ɔfo na ɛrida, Ɔforanfo bribri abakal ajil na ɔlim, afele nsɔl yi ɛlu ya abɔ alemɔ.
# 24 2 Abɔ asɛb akun arɛ agba bingi lital na nyɔbo ɔlim,
# 24 3 naji abɔ ayɛlɔ ayɛnam ɛku Tata Jisɔs.
# 24 4 Naji abɔ ajɔlɔ kɛrɛ abangɛ,fɔ tutu abalom abal ba ayɔbɔ abɔma ya ajɔl ya mɔng nwangdo aba yema abɔ na nkɛ.
# 24 5 Na ɛkokob, abakal bafɔ akug mbri na nde, abalom bafɔ abonɡ atɔg abɔ arɛ, “Bɛjom ji wun ɔsɛba likpen na ɛbɔngɛ akuanɛ?
# 24 6 Wɛ fa san, wɛ agba nyimi! Gbɔ nter ji atɔgɔ wun naji akpenɔ re nanina na Galili:
# 24 7 ‘Ala dabɔ Mɔn a Nɛnom akarɛ anɛ ba abeɔfɛm, alɛ yol na mfo ɛra anyimi na liku.’ ”
# 24 8 Abɔ agbɔ nter alom ayɛ.
# 24 9 Naji akurɔ na ɔlim abal atɔg batɔnanjim woba wurang na anɛ bangɔ nsɔl yi ɛlɔ lem.
# 24 10 Abakal bafɔ ajɔl Meri Magdalen, Jowana, Meri nyɛn Jemsi na abakal ba ngɔ, ba atɔgɔ Arɔb ayɛ.
# 24 11 Arɔb ayɛ ategam atamɛ ji abakal bafɔ ajɔl bong, ateb alom abɔ ajogam ɛsi na mba.
# 24 12 Pita atum ayima abɛna aji na ɔlim; akuma ayɛn aja abɔma anɔngɔ ntinga ntinga, afɛngɛ ajɛn akɛrɛ ji ɛlɔ lem.
# 24 13 Na ɔfo bi fɔ, batɔnanjim abal ba Jisɔs ajɔl ji na ɛkpa ɛgbɛ ji ajɔl kog arɛ Ɛmayus, ajɔl mal arima bɔm na Jɛrusɛlɛm.
# 24 14 Abɔ ajɔl bong na atɛm abangɛ kpakpa nsɔl yi ɛlɔ lem.
# 24 15 Naji abɔ ajɔl bong afɛngɛ atoba ɛka abangɛ nsɔl yi ɛlɔ lem na atɛm, Jisɔs wɛ nfɔnɛ aba kuma njɛna na abɔ.
# 24 16 Ɔsɔwɔ alem arɛ adɛ wɛ renge.
# 24 17 Jisɔs abib abɔ, “Bɛjom ji wun ɔbonga na atɛm, na ji wun ɔjɛna?” Abɔ ayema, na nbri ndɔn ndɔn.
# 24 18 Nɛ wurang na ɛbɔngɛ abɔ yɔ anyina arɛ Klopas, abibɛ, “Wɔ nanting ɔrenɔ njɛna nɛ na Jɛrusɛlɛm yɔ ɔdɛdɛ yog nsɔl yi ɛlema na abɔn afo fa?”
# 24 19 Wɛ abib arɛ, “Ba nsɔl yi?” Abɔ afanga arɛ, “Nsɔl yi ɛlemɔ Jisɔs yɔ Nasarɛt. Ajɔl nyɛna amir abɛl ɛkɔ na alom na nema na libri Ɔsɔwɔ na anɛ kpakpa.
# 24 20 Atol a balemanjɔm na atobɛ ɛsi ayira adal wɛ abɔ akarɛ akem ɛlam arɛ akpɔ, akomɛ na krɔs.
# 24 21 Wur ɛjɔl kɛrɛ arɛ wɛ yɔ ala jɔl nɛ yɔ ala nyangɛ Isrɛl. Seng fɔ sa, ɛlɛl mfo ɛra bɔm naji ɛlemɔ.
# 24 22 Kpɛlɛ fɔ, ɛrik abakal abra akpɔl wur ɛsi, ajil na ɔlim ɛlɛl ɔforanfo bribri
# 24 23 abɔ ɛku ɛjɛ ayɛnam. abɔ afɛngɛ njim aba tɔg wur arɛ abɔ agba yɛn amir ya bateb ɔteb ba atɔgɔ abɔ arɛ wɛ are na likpen.
# 24 24 Ɛrik anɛ na ɛbɔngɛ ɛjira ajil na ɔlim, naji arirɔ ngɔ ayɛn jangjang mɔng abakal bafɔ abongɔ, abɔ wɛ ayɛnam.”
# 24 25 Jisɔs abong atɔg abɔ arɛ. “Fa ba lidabɛ li na ɛdɛg tamɛ nsɔl yi nyɛna amir abongɔ!
# 24 26 Wun ɔnyim arɛ Krayis ayɛn ɔrem na nsɔl yifa nig ayɛl na liloba ɛlɛ?”
# 24 27 Bɔm na anwɛr ya Mosis ayɛlɔ na bayɛn amir kpakpa, aribi atɔg abɔ ji abongɔ na alom Ɔsɔwɔ abangɛ ɛlɛ.
# 24 28 Naji ajɛnɔ alagɛ ɛkpa ɛgbɛ ji abɔ ajɔlɔ ji, Jisɔs alem mɔng ala kpɛ sɔra asi.
# 24 29 Abɔ agɔrɛ wɛ na ɛkora biji arɛ, “Jɔl na nira ɔfo ɛlag mal alagtu ayɔbak.” Fɔ yɔ atumɔ ayɛl na ɛtɛk aji jɔl na abɔ.
# 24 30 Naji Ajɔlɔ na ɛkpokoro arɛ ali nsɔl na abɔ, atab brɛd, akag Ɔsɔwɔ sam, akem atab akarɛ abɔ.
# 24 31 Fɔ tutu amir abɔ aribi, abɔ arenge wɛ, nig atarɛ na nbri abɔ.
# 24 32 Abɔ abib atɛm, “Ntem ɛyira na ɔnwɔlɛ ɛroram na ɛyɛbalitem naji ajɔl bong na nira afɛngɛ aribi alom Ɔsɔwɔ atɔga wur na mba ɛ?”
# 24 33 Abɔ atum ayema afɛngɛ njim na Jɛrusɛlɛm. Aji yɛn batɔnanjim abɛ woba wurang alɔ gba mfom yirang na anɛ bangɔ.
# 24 34 Batɔnanjim abɛ na anɛ bangɔ abong arɛ, “Ɛtete ji Tata agba nyimi aji ateb ɛlɛ naji Sayimɔn Pita.”
# 24 35 Abɔ anɛ abal atɔg abɔ ji ɛlemɔ na mba, mɔng abɔ alɔ renge Jisɔs ngara yi akemɔ brɛd.
# 24 36 Naji anɛ bafɔ ajɔl tɔg abɔ ji ɛlemɔ, Jisɔs nfɔnɛ abal ayema na ɛbɔngɛ abɔ abong atɔg abɔ arɛ, “Likɔna ɛjɔl na nina.”
# 24 37 Ɛkokob ɛbɔb abɔ, ajɔ kɛrɛ arɛ agba yɛn ɛtugi nkuanɛ.
# 24 38 Abong atɔg abɔ arɛ, “Bɛjom ji wun ɔbɛga, bɛjom ji ɛkerɔ nfab alɔ wun ror na ntem?
# 24 39 Bri abɔ ama na ata ama. Mɛ nfɔnɛ yɔ! lagam wɔ ɔyɛn; ɛtugi anim jɔga abɛla biji na akub mɔng wun ɔlam yɛn nkpenɔ.”
# 24 40 Naji alɔ bong fɛb ateb abɔ, abɔ ayɛ na ata.
# 24 41 Abɔ ategam atamɛ, ateb abɛl ɛyɛbalitem na akpɔga ɛsi. Jisɔs abib abɔ arɛ, “Wun ɔkpekpe ɛjom ji wun ɔla li ɛ?”
# 24 42 Abɔ akarɛ ɛja nkɔbɛ ji alɔ lam,
# 24 43 Atabɛ ali na nbri abɔ.
# 24 44 Abong atɔg abɔ arɛ, “Fa ɛjom ji mɛ ntɔgɔ wun naji nkpenɔ re na nina. Nsɔl kpakpa yi ayɛlɔ abangɛ mam na ajing ya Mosis ba Yɛna Amir na Bisɛ Ntiga ɛla jɔl ɛtete.”
# 24 45 Fɔ yɔ aribɔ ntem abɔ naji alom Ɔsɔwɔ ala sar abɔ.
# 24 46 Abong atɔg abɔ arɛ, “Fa ɛjom ji ayɛlɔ na Nwɛr a Ɔsɔwɔ: Krayis ala yɛn ɔrɛm ala nyimi na liku na mfo ɛra,
# 24 47 na mbeng ɛma, ɔteb abangɛ ɛgbɔga ndɔn na ɔtum ɔkarɛ na abeɔfɛm ala bong na ɛyeng kpakpa bɔm na Jɛrusɛlɛm.
# 24 48 Wun ɔre ntiansɛ na nsɔl yi fɔ.
# 24 49 Mɛ na tom ɛjom ji nsɔjama abongɔ nɔ ntu wun. Bajɔl na ɛjiba Jɛrusɛlɛm tɛtɛ ɛkɔ ji ɛgalɔ yura ɛbudi ɛbole wun.”
# 24 50 Jisɔs atul batɔnanjim abɛ ajog na ɛjiba Jɛrusɛlɛm arir Bɛtani, fɔyɔ atabɔ abɔ ayɛ akarɛ abɔ lifola.
# 24 51 Naji ajɔl fola abɔ, atum abɔ asa atabɛ atum na libonta.
# 24 52 Abɔ ajege wɛ afɛngɛ njim na Jɛrusɛlɛm, na ntakpa ɛyɛbalitem.
# 24 53 Abɔ ajɔl na Njo ɔsɔwɔ ngara kpakpa akaga Ɔsɔwɔ sam.
# 24

# %%
target_verses[0]
# Out:
# {'ch': 1,
#  'v': 1,
#  'text': 'Tiyɔfilɔs agbem anɛ agba nɔg ayɛlɛ nsɔl yi ɛlɔ lem na agira.'}

# %%
# Sample target data from file
with open('target_verses.txt', 'r') as f:
    target_verses = json.loads(f.read())

# %% [markdown]
# ## Get source sentences

# %%
import requests, json, re, os
import pandas as pd

def download_file(url, file_name):
    response = requests.get(url)
    with open(file_name, "wb") as file:
        file.write(response.content)

# file1_url = "https://raw.githubusercontent.com/Clear-Bible/macula-greek/main/Nestle1904/TSV/macula-greek.tsv"
file1_url = "https://github.com/Clear-Bible/macula-greek/raw/feature/add-sentence-id-to-tsv/Nestle1904/TSV/macula-greek.tsv" # PR version with sentence IDs
file1_name = "macula-greek.tsv"

if file1_name not in os.listdir():
    download_file(file1_url, file1_name)

# %%
# Import Macula Greek data
mg = pd.read_csv(
    "macula-greek.tsv", index_col="xml:id", sep="\t", header=0, converters={"*": str}
).fillna("missing")
# add an 'id' column
mg["id"] = mg.index

# mg['domain'] = mg['domain'].astype(str).fillna('missing')

# Extract book, chapter, and verse into separate columns
mg[["book", "chapter", "verse"]] = mg["ref"].str.extract(r"(\d?[A-Z]+)\s(\d+):(\d+)")

# Add columns for book + chapter, and book + chapter + verse for easier grouping
mg["book_chapter"] = mg["book"] + " " + mg["chapter"].astype(str)
mg["book_chapter_verse"] = mg["book_chapter"] + ":" + mg["verse"].astype(str)

# note that 'Luke' == 'LUK'

# %%
# Extract sentences from Luke
luke_sentences = mg[mg['book'] == 'LUK']

# %%
luke_sentences
# Out:
#                        ref     role class     type            gloss  \
# xml:id
# n42001001001     LUK 1:1!1  missing  conj  missing      Inasmuch as
# n42001001002     LUK 1:1!2        s   adj  missing             many
# n42001001003     LUK 1:1!3        v  verb  missing  have undertaken
# n42001001004     LUK 1:1!4        v  verb  missing       to draw up
# n42001001005     LUK 1:1!5        o  noun   common      a narration
# ...                    ...      ...   ...      ...              ...
# n42024053006   LUK 24:53!6  missing   det  missing              the
# n42024053007   LUK 24:53!7  missing  noun  missing           temple
# n42024053008   LUK 24:53!8  missing  verb  missing         blessing
# n42024053009   LUK 24:53!9  missing   det  missing                -
# n42024053010  LUK 24:53!10  missing  noun   common              God
#
#                      text after        lemma   normalized  strong  ...  \
# xml:id                                                             ...
# n42001001001    Ἐπειδήπερ          ἐπειδήπερ    Ἐπειδήπερ    1895  ...
# n42001001002       πολλοὶ              πολύς       πολλοί    4183  ...
# n42001001003  ἐπεχείρησαν          ἐπιχειρέω  ἐπεχείρησαν    2021  ...
# n42001001004  ἀνατάξασθαι        ἀνατάσσομαι  ἀνατάξασθαι     392  ...
# n42001001005     διήγησιν           διήγησις     διήγησιν    1335  ...
# ...                   ...   ...          ...          ...     ...  ...
# n42024053006           τῷ                  ὁ           τῷ    3588  ...
# n42024053007         ἱερῷ              ἱερός         ἱερῷ    2411  ...
# n42024053008  εὐλογοῦντες            εὐλογέω  εὐλογοῦντες    2127  ...
# n42024053009          τὸν                  ὁ          τόν    3588  ...
# n42024053010         Θεόν     .         θεός         Θεόν    2316  ...
#
#                   ln                                              frame  \
# xml:id
# n42001001001   89.32                                            missing
# n42001001002    59.1                                            missing
# n42001001003   68.59                    A0:n42001001002 A1:n42001001004
# n42001001004    62.3                    A0:n42001001002 A1:n42001001005
# n42001001005   33.11                                            missing
# ...              ...                                                ...
# n42024053006   92.24                                            missing
# n42024053007    7.16                                            missing
# n42024053008  33.356  A0:n42024033013;n42024033015;n42024013003 A1:n...
# n42024053009   92.24                                            missing
# n42024053010    12.1                                            missing
#
#                                              subjref referent            id  \
# xml:id
# n42001001001                                 missing  missing  n42001001001
# n42001001002                                 missing  missing  n42001001002
# n42001001003                                 missing  missing  n42001001003
# n42001001004                            n42001001002  missing  n42001001004
# n42001001005                                 missing  missing  n42001001005
# ...                                              ...      ...           ...
# n42024053006                                 missing  missing  n42024053006
# n42024053007                                 missing  missing  n42024053007
# n42024053008  n42024033013 n42024033015 n42024013003  missing  n42024053008
# n42024053009                                 missing  missing  n42024053009
# n42024053010                                 missing  missing  n42024053010
#
#              book chapter verse book_chapter book_chapter_verse
# xml:id
# n42001001001  LUK       1     1        LUK 1            LUK 1:1
# n42001001002  LUK       1     1        LUK 1            LUK 1:1
# n42001001003  LUK       1     1        LUK 1            LUK 1:1
# n42001001004  LUK       1     1        LUK 1            LUK 1:1
# n42001001005  LUK       1     1        LUK 1            LUK 1:1
# ...           ...     ...   ...          ...                ...
# n42024053006  LUK      24    53       LUK 24          LUK 24:53
# n42024053007  LUK      24    53       LUK 24          LUK 24:53
# n42024053008  LUK      24    53       LUK 24          LUK 24:53
# n42024053009  LUK      24    53       LUK 24          LUK 24:53
# n42024053010  LUK      24    53       LUK 24          LUK 24:53
#
# [19456 rows x 30 columns]

# %%
### SENTENCE-BASED TEXTS

import pandas as pd
import numpy as np

# Initialize lists
text_list = []
target_verse_list = []
dict_list = []
id_list = []

# Group the DataFrame by 'sentence'
# grouped = mg.groupby('sentence')
grouped = mg.groupby('book_chapter_verse')

for name, group in grouped:
    # Combine the 'text' and 'after' fields into a single string for each group
    greek_text = ''.join(group['text'] + group['after'].replace(np.nan, ' ', regex=True))
    sentence_gloss = ''.join(group['gloss'].replace(np.nan, '[no gloss]', regex=True) + group['after'].replace(np.nan, '', regex=True) + ' ')
    text_list.append(sentence_gloss)
    
    # Extract book, chapter, and verse from the group
    book = group['book'].values[0]
    chapter = group['book_chapter'].str.split().str[1].values[0]
    verse = group['book_chapter_verse'].str.split(':').str[1].values[0]
    b_c_v = group['book_chapter_verse'].values[0]
    # id_entry = group['sentence'].values[0]
    id_entry = '|'.join(group['id'].tolist())
    
    target_verse = None
    
    # Find the target text for the verse if scraped
    # for verse_list in target_verses:
    #     for verse_dict in verse_list:
    #         print(verse_dict)
    #         if verse_dict['ch'] == chapter and verse_dict['v'] == verse:
    #             target_verse = verse_dict['text']
    
    # Find the target text for the verse if loaded from file
    for verse_dict in target_verses:
        if str(verse_dict['ch']) == chapter and str(verse_dict['v']) == verse:
            target_verse = verse_dict['text']
    
    
    
    # dict_entry = {'book': book, 'chapter': chapter, 'verse': verse, 'greek': greek_text}
    dict_entry = {'source': b_c_v, 'book': book, 'chapter': chapter, 'verse': verse, 'ids': id_entry, 'greek': greek_text}
    if target_verse:
        dict_entry['target'] = target_verse
    dict_list.append(dict_entry)
    
    
    # Use the 'xml:id' field to create an ID for the verse
    id_entry = group['id'].tolist()
    id_list.append(id_entry)

# Print the lists for testing
print(text_list[:5])
print(dict_list[:5])
print(id_list[:5])
# Out:
# ['Not  I want  for  you  to be ignorant, brothers, that  the  fathers  of us  all  under  the  cloud  were  and  all  through  the  sea  passed, ', 'Neither  are you to grumble, as  some  of them  grumbled, and  perished  by  the  Destroyer. ', 'These things  now  [as] types  happened  to them, were written  then  for  admonition  of us, to  whom  the  ends  of the  ages  are arrived. ', 'Therefore  the [one]  thinking  to stand  let him take heed  lest  he fall, ', 'Temptation  you  not  has seized  if  not  what is common to man· faithful  now  -  [is] God, who  not  will allow  you  to be tempted  beyond  what  you are able, but  will provide  with  the  temptation  also  the  escape  -  to be able  to endure [it]. ']
# [{'source': '1CO 10:1', 'book': '1CO', 'chapter': '10', 'verse': '1', 'ids': 'n46010001001|n46010001002|n46010001003|n46010001004|n46010001005|n46010001006|n46010001007|n46010001008|n46010001009|n46010001010|n46010001011|n46010001012|n46010001013|n46010001014|n46010001015|n46010001016|n46010001017|n46010001018|n46010001019|n46010001020|n46010001021', 'greek': 'Οὐ θέλω γὰρ ὑμᾶς ἀγνοεῖν,ἀδελφοί,ὅτι οἱ πατέρες ἡμῶν πάντες ὑπὸ τὴν νεφέλην ἦσαν καὶ πάντες διὰ τῆς θαλάσσης διῆλθον,', 'target': 'Naji jifɔ ɛlɔ seng Tata arang anɛ atil ara na woba na abal atom abɔ na ɛtegla anɛ abal abal. Arɛ agbɔmba asɔng na bijiba na afom ya wɛ akɛrɛnɔ arɛ wɛ aji.'}, {'source': '1CO 10:10', 'book': '1CO', 'chapter': '10', 'verse': '10', 'ids': 'n46010010001|n46010010002|n46010010003|n46010010004|n46010010005|n46010010006|n46010010007|n46010010008|n46010010009|n46010010010|n46010010011', 'greek': 'μηδὲ γογγύζετε,καθάπερ τινὲς αὐτῶν ἐγόγγυσαν,καὶ ἀπώλοντο ὑπὸ τοῦ ὀλοθρευτοῦ.', 'target': 'Wun ɔlɔ fɛngɛ ɔyɛl na ɛjiba ji adɛnɔ wun kpera, ba sɔng na aba ɛjiba wun ɔbong arɛ,'}, {'source': '1CO 10:11', 'book': '1CO', 'chapter': '10', 'verse': '11', 'ids': 'n46010011001|n46010011002|n46010011003|n46010011004|n46010011005|n46010011006|n46010011007|n46010011008|n46010011009|n46010011010|n46010011011|n46010011012|n46010011013|n46010011014|n46010011015|n46010011016|n46010011017', 'greek': 'ταῦτα δὲ τυπικῶς συνέβαινεν ἐκείνοις,ἐγράφη δὲ πρὸς νουθεσίαν ἡμῶν,εἰς οὓς τὰ τέλη τῶν αἰώνων κατήντηκεν.', 'target': '‘Ɛbubu ji ɛjiba ɛjina ji ɛlagɔ wur na ata ɛgba kom mɔng ndenge afɛm. Ba gbɔ nter arɛ, Ɔtol Ɔsɔwɔ ɛgba kped.’'}, {'source': '1CO 10:12', 'book': '1CO', 'chapter': '10', 'verse': '12', 'ids': 'n46010012001|n46010012002|n46010012003|n46010012004|n46010012005|n46010012006|n46010012007', 'greek': 'Ὥστε ὁ δοκῶν ἑστάναι βλεπέτω μὴ πέσῃ,', 'target': 'Mɛ ntɔga wa ndɛ ɔfo bilam, Ɔsɔwɔ ala teb ntakpa ndɔn na Sodɔm aseng ɛjiba ji fɔ.”'}, {'source': '1CO 10:13', 'book': '1CO', 'chapter': '10', 'verse': '13', 'ids': 'n46010013001|n46010013002|n46010013003|n46010013004|n46010013005|n46010013006|n46010013007|n46010013008|n46010013009|n46010013010|n46010013011|n46010013012|n46010013013|n46010013014|n46010013015|n46010013016|n46010013017|n46010013018|n46010013019|n46010013020|n46010013021|n46010013022|n46010013023|n46010013024|n46010013025|n46010013026|n46010013027|n46010013028|n46010013029|n46010013030', 'greek': 'πειρασμὸς ὑμᾶς οὐκ εἴληφεν εἰ μὴ ἀνθρώπινος·πιστὸς δὲ ὁ Θεός,ὃς οὐκ ἐάσει ὑμᾶς πειρασθῆναι ὑπὲρ ὃ δύνασθε,ἀλλὰ ποιήσει σὺν τῷ πειρασμῷ καὶ τὴν ἔκβασιν τοῦ δύνασθαι ὑπενεγκεῖν.', 'target': '“Ɛla jɔl nkpɔgɛsi ɛjom ɛkara, Korasin! Ɛla jɔl nkpɔgɛsi ɛjom ɛkara Bɛtsayida! Arenɔ arɛ akpɔga ɛsi nsɔl ya alemɔ wa alemɔ na Taya na Sayidɔn, anɛ ba fɔ kin ateg ajɔl na nde, ayɔbɛ ajaga abɔma, awuri li bɔ atɔng, ateb arɛ ali gbɔ ndɔn na abe ɔfɛm abɔ.'}]
# [['n46010001001', 'n46010001002', 'n46010001003', 'n46010001004', 'n46010001005', 'n46010001006', 'n46010001007', 'n46010001008', 'n46010001009', 'n46010001010', 'n46010001011', 'n46010001012', 'n46010001013', 'n46010001014', 'n46010001015', 'n46010001016', 'n46010001017', 'n46010001018', 'n46010001019', 'n46010001020', 'n46010001021'], ['n46010010001', 'n46010010002', 'n46010010003', 'n46010010004', 'n46010010005', 'n46010010006', 'n46010010007', 'n46010010008', 'n46010010009', 'n46010010010', 'n46010010011'], ['n46010011001', 'n46010011002', 'n46010011003', 'n46010011004', 'n46010011005', 'n46010011006', 'n46010011007', 'n46010011008', 'n46010011009', 'n46010011010', 'n46010011011', 'n46010011012', 'n46010011013', 'n46010011014', 'n46010011015', 'n46010011016', 'n46010011017'], ['n46010012001', 'n46010012002', 'n46010012003', 'n46010012004', 'n46010012005', 'n46010012006', 'n46010012007'], ['n46010013001', 'n46010013002', 'n46010013003', 'n46010013004', 'n46010013005', 'n46010013006', 'n46010013007', 'n46010013008', 'n46010013009', 'n46010013010', 'n46010013011', 'n46010013012', 'n46010013013', 'n46010013014', 'n46010013015', 'n46010013016', 'n46010013017', 'n46010013018', 'n46010013019', 'n46010013020', 'n46010013021', 'n46010013022', 'n46010013023', 'n46010013024', 'n46010013025', 'n46010013026', 'n46010013027', 'n46010013028', 'n46010013029', 'n46010013030']]

# %%
# Filter out any text, dict, ids, that are not in Luke

# zip all three together
zipped = zip(text_list, dict_list, id_list)

luke_sentences = [v for v in zipped if v[1]['book'] == 'LUK']

# %%
with open('sentence_sets.txt', 'w', encoding='utf8') as f:
    f.write(json.dumps(luke_sentences, ensure_ascii=False, indent=2))

# %%
len(luke_sentences)
# Out:
# 1149

# %%
luke_sentences[0][1]['source']
# Out:
# 'LUK 10:1'

# %%
print(luke_sentences[0][1]['source'])
print(luke_sentences[0][0])
print(luke_sentences[0][1]['greek'])
print(luke_sentences[0][1]['target'])

# Make an array of objects like this
triples_list = []
for sentence in luke_sentences:
    triples_list.append({'source': sentence[1]['source'], 'greek': luke_sentences[0][1]['greek'], 'gloss': sentence[0], 'target': sentence[1]['target']})
    
triples_list[0:5]
# Out:
# LUK 10:1
# After  now  these things  appointed  the  Lord  others  seventy, and  sent  them  in  two [by]  before  [the] face  of Himself  into  every  city  and  place  where  was about  He Himself  to go.
# Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.
# Naji jifɔ ɛlɔ seng Tata arang anɛ atil ara na woba na abal atom abɔ na ɛtegla anɛ abal abal. Arɛ agbɔmba asɔng na bijiba na afom ya wɛ akɛrɛnɔ arɛ wɛ aji.
# [{'source': 'LUK 10:1',
#   'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.',
#   'gloss': 'After  now  these things  appointed  the  Lord  others  seventy, and  sent  them  in  two [by]  before  [the] face  of Himself  into  every  city  and  place  where  was about  He Himself  to go. ',
#   'target': 'Naji jifɔ ɛlɔ seng Tata arang anɛ atil ara na woba na abal atom abɔ na ɛtegla anɛ abal abal. Arɛ agbɔmba asɔng na bijiba na afom ya wɛ akɛrɛnɔ arɛ wɛ aji.'},
#  {'source': 'LUK 10:10',
#   'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.',
#   'gloss': 'Into  whatever  now  -  city  you might enter  and  not  they receive  you, having gone out  into  the  streets  of it  say  ',
#   'target': 'Wun ɔlɔ fɛngɛ ɔyɛl na ɛjiba ji adɛnɔ wun kpera, ba sɔng na aba ɛjiba wun ɔbong arɛ,'},
#  {'source': 'LUK 10:11',
#   'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.',
#   'gloss': 'Even  the  dust  -  having clung  to us  out of  the  city  of you  to  the  feet  we wipe off  against you· yet  this  know, that  has drawn near  the  kingdom  -  of God. ',
#   'target': '‘Ɛbubu ji ɛjiba ɛjina ji ɛlagɔ wur na ata ɛgba kom mɔng ndenge afɛm. Ba gbɔ nter arɛ, Ɔtol Ɔsɔwɔ ɛgba kped.’'},
#  {'source': 'LUK 10:12',
#   'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.',
#   'gloss': 'I say  to you  that  for Sodom  in  the  day  that  more tolerable  it will be  than  the  city  for that. ',
#   'target': 'Mɛ ntɔga wa ndɛ ɔfo bilam, Ɔsɔwɔ ala teb ntakpa ndɔn na Sodɔm aseng ɛjiba ji fɔ.”'},
#  {'source': 'LUK 10:13',
#   'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.',
#   'gloss': 'Woe  to you, Chorazin, Woe  to you, Bethsaida· For  if  in  Tyre  and  Sidon  had taken place  the  miracles  -  having taken place  in  you, long ago  -  in  sackcloth  and  ashes  sitting  they would have repented. ',
#   'target': '“Ɛla jɔl nkpɔgɛsi ɛjom ɛkara, Korasin! Ɛla jɔl nkpɔgɛsi ɛjom ɛkara Bɛtsayida! Arenɔ arɛ akpɔga ɛsi nsɔl ya alemɔ wa alemɔ na Taya na Sayidɔn, anɛ ba fɔ kin ateg ajɔl na nde, ayɔbɛ ajaga abɔma, awuri li bɔ atɔng, ateb arɛ ali gbɔ ndɔn na abe ɔfɛm abɔ.'}]

# %% [markdown]
# ## Process data

# %%
# Us
data = triples_list

# Split the data into train and test sets
train_data, test_data = train_test_split(data, test_size=0.2)

# %%
persist_directory = '/Users/ryderwishart/biblical-machine-learning/ai-translation'

from langchain.embeddings import HuggingFaceEmbeddings, SentenceTransformerEmbeddings
embeddings = HuggingFaceEmbeddings()

collection = Chroma("translation-db", embeddings, persist_directory=persist_directory)
# Out:
# Using embedded DuckDB with persistence: data will be stored in: /Users/ryderwishart/biblical-machine-learning/ai-translation

# %%
# Add greek texts with metadata
"""
[{'source': 'LUK 10:1',
  'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.',
  'gloss': 'After  now  these things  appointed  the  Lord  others  seventy, and  sent  them  in  two [by]  before  [the] face  of Himself  into  every  city  and  place  where  was about  He Himself  to go. ',
  'target': 'Naji jifɔ ɛlɔ seng Tata arang anɛ atil ara na woba na abal atom abɔ na ɛtegla anɛ abal abal. Arɛ agbɔmba asɔng na bijiba na afom ya wɛ akɛrɛnɔ arɛ wɛ aji.'},
 
"""

collection.add_texts(
    texts=[sentence['target'] for sentence in train_data],
    metadatas=[{'source': sentence['source'], 'greek': sentence['greek'], 'gloss': sentence['gloss'], 'target': sentence['target']} for sentence in train_data],
    ids=[sentence['source'] for sentence in train_data],
)
collection.persist()

# %%
# Load the persisted database from disk and use it as normal
collection_from_disk = Chroma(persist_directory=persist_directory, embedding_function=embeddings, collection_name="prosaic_contexts")

# %% [markdown]
# # Set up translation and back-translation chains

# %%
import copy

# Initialize the ChatOpenAI model
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo",
    temperature=0,
    max_tokens=2000,
    frequency_penalty=0,
    presence_penalty=0,
    top_p=1.0,
)

# Define the schema for the translation task
schema = Object(
    id="translation",
    description="Translate the source sentence to the target language.",
    attributes=[
        Text(
            id="source_sentence",
            description="The sentence in the source language",
            examples=[],
            many=False,
        ),
        Text(
            id="target_sentence",
            description="The translated sentence in the target language",
            examples=[],
            many=False,
        ),
    ],
    many=False,
)

# Create an extraction chain with the model and schema
translate_chain = create_extraction_chain(llm, schema, encoder_or_encoder_class='json')

# Make a copy (not just a reference) to the schema for backtranslation
backtranslation_schema = copy.deepcopy(schema)
backtranslation_chain = create_extraction_chain(llm, backtranslation_schema, encoder_or_encoder_class='json')
# Out:
# WARNING! frequency_penalty is not default parameter.
#                     frequency_penalty was transferred to model_kwargs.
#                     Please confirm that frequency_penalty is what you intended.
# WARNING! presence_penalty is not default parameter.
#                     presence_penalty was transferred to model_kwargs.
#                     Please confirm that presence_penalty is what you intended.
# WARNING! top_p is not default parameter.
#                     top_p was transferred to model_kwargs.
#                     Please confirm that top_p is what you intended.

# %%
# Example of how to find similar verses based on target language text
collection.search(test_data[0]['target'], search_type='similarity', k=5)
# Out:
# [Document(page_content='“Ndɛ abong atɔg barɔgantom abɛ arɛ, ‘Baba kakab! Na ɛteng ɛleba wun ɔba yɔbɛ wɛ. Ɔkagɛ ɛbel na nyig ɔbɔ na akpagata na ata ayɛ.', metadata={'source': 'LUK 15:22', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'Said  then  the  father  to  the  servants  of him  Quickly  bring out  robe  the  best  and  clothe  him, and  give  a ring  for  the  hand  of him  and  sandals  for  his  feet, ', 'target': '“Ndɛ abong atɔg barɔgantom abɛ arɛ, ‘Baba kakab! Na ɛteng ɛleba wun ɔba yɔbɛ wɛ. Ɔkagɛ ɛbel na nyig ɔbɔ na akpagata na ata ayɛ.'}),
#  Document(page_content='Na ji bateb ɔteb Ɔsɔwɔ alɔ tum abɔ asa afɛngɛ njim ajɛn na libonta, ba babe ɔjɔra akuma mbonga atɔga atɛm, “Ɛjɛn na Bɛtlɛm ɛji yɛn nsɔl yi ɛlɔ lem ji Tata alɔ wur tɔg.”', metadata={'source': 'LUK 2:15', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'And  it came to pass  as  were departing  from  them  into  the  heaven  the  angels, the  shepherds  were saying  to  one another  Let us go through  indeed  as far as  Bethlehem  and  let us see  the  word  this  that  has come to pass  which  the  Lord  has made known  to us. ', 'target': 'Na ji bateb ɔteb Ɔsɔwɔ alɔ tum abɔ asa afɛngɛ njim ajɛn na libonta, ba babe ɔjɔra akuma mbonga atɔga atɛm, “Ɛjɛn na Bɛtlɛm ɛji yɛn nsɔl yi ɛlɔ lem ji Tata alɔ wur tɔg.”'}),
#  Document(page_content='“Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl.', metadata={'source': 'LUK 16:16', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'The  law  and  the  prophets [were]  until  John· from  that time  the  kingdom  -  of God  is proclaimed  and  everyone  into  it  forces his way. ', 'target': '“Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl.'}),
#  Document(page_content='Jɔn atɔg lirɔng anɛ ba abalɔ alib nwuri arɛ, “Wun abɔn ɛgbɔda! Wun ɔkɛrɛ arɛ ɔmamal ɔrɛm ɛyama litem ji Ɔsɔwɔ ji ɛla ba ɛ?', metadata={'source': 'LUK 3:7', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'He was saying  therefore  to the  coming out  crowds  to be baptized  by  him  Offspring  of vipers, who  forewarned  you  to flee  from  the  coming  wrath; ', 'target': 'Jɔn atɔg lirɔng anɛ ba abalɔ alib nwuri arɛ, “Wun abɔn ɛgbɔda! Wun ɔkɛrɛ arɛ ɔmamal ɔrɛm ɛyama litem ji Ɔsɔwɔ ji ɛla ba ɛ?'}),
#  Document(page_content='Atab brɛd, akag Ɔsɔwɔ sam, abɛg atab akarɛ abɔ abong arɛ, “Fa ngoabiji ɛma yi mɛ nkarɛ wun. Ba lem anɔ wun ɔgbɔ mam nter.”', metadata={'source': 'LUK 22:19', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'And  having taken  [the] bread  having given thanks  He broke [it]  and  gave  to them  saying  This  is  the  body  of Me  which  for  you  is given· this  do  in  the  of Me  remembrance. ', 'target': 'Atab brɛd, akag Ɔsɔwɔ sam, abɛg atab akarɛ abɔ abong arɛ, “Fa ngoabiji ɛma yi mɛ nkarɛ wun. Ba lem anɔ wun ɔgbɔ mam nter.”'})]

# %%
# Move through the test sentences one at a time
for sentence_dict in test_data:
    # Use Kor to dynamically feed similar examples to the current sentence on the fly
    similar_sentences = collection.search(sentence_dict['target'], search_type='similarity', k=10)
    print(similar_sentences)
    print(dir(similar_sentences[0]))
    # examples = [(source_sentence, target_sentence) for source_sentence, target_sentence in similar_sentences] # use similar sentences
    examples = [(sentence.metadata['gloss'], sentence.page_content) for sentence in similar_sentences if sentence != sentence_dict['target']] # use similar sentences

    # Build some examples for back translation which put the gloss second and the target language first
    backtranslation_examples = [(sentence.page_content, sentence.metadata['gloss']) for sentence in similar_sentences if sentence != sentence_dict['target']] # use similar sentences

    # Update the examples in the schema
    schema.attributes[0].examples = examples
    
    # Update the examples in the backtranslation schema
    backtranslation_schema.attributes[0].examples = backtranslation_examples
    
    print(sentence_dict['source'], '-->', examples)

    # Use OpenAI's completion endpoint for annotating new translations on the test sentences using the examples
    prediction = translate_chain.predict_and_parse(text=sentence_dict['gloss'])

    print('prediction', prediction)
    translated_sentence = prediction['data']['translation']['source_sentence']
    
    # TODO: Backtranslate the results to the source language without seeing the original translations
    # This requires an additional translation model or API that can translate from the target language back to the source language.
    reverse_prediction = backtranslation_chain.predict_and_parse(text=translated_sentence)
    print('reverse_prediction', reverse_prediction)
    backtranslated_target_sentence = reverse_prediction['data']['translation']['source_sentence']
    
    # Backtranslate the original, gold-standard translation for a comparative basis
    original_backtranslation_prediction = backtranslation_chain.predict_and_parse(text=sentence_dict['target'])
    backtranslated_original_target_sentence = original_backtranslation_prediction['data']['translation']['source_sentence']
    
    # TODO: Compare the resulting target translation and back-translated source to the original sentence pair
    # This requires a suitable metric for comparison, such as the BLEU score for translation tasks.
    
    # For now, just print the results and compare to the original
    print('Original:', sentence_dict['target'])
    print('Predicted:', prediction['data']['source_sentence'])
    print('Backtranslated version of the model\'s prediction:', backtranslated_target_sentence)
    print('Backtranslated version of the gold-standard sentence:', backtranslated_original_target_sentence)
    break
# Out:
# [Document(page_content='“Ndɛ abong atɔg barɔgantom abɛ arɛ, ‘Baba kakab! Na ɛteng ɛleba wun ɔba yɔbɛ wɛ. Ɔkagɛ ɛbel na nyig ɔbɔ na akpagata na ata ayɛ.', metadata={'source': 'LUK 15:22', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'Said  then  the  father  to  the  servants  of him  Quickly  bring out  robe  the  best  and  clothe  him, and  give  a ring  for  the  hand  of him  and  sandals  for  his  feet, ', 'target': '“Ndɛ abong atɔg barɔgantom abɛ arɛ, ‘Baba kakab! Na ɛteng ɛleba wun ɔba yɔbɛ wɛ. Ɔkagɛ ɛbel na nyig ɔbɔ na akpagata na ata ayɛ.'}), Document(page_content='Na ji bateb ɔteb Ɔsɔwɔ alɔ tum abɔ asa afɛngɛ njim ajɛn na libonta, ba babe ɔjɔra akuma mbonga atɔga atɛm, “Ɛjɛn na Bɛtlɛm ɛji yɛn nsɔl yi ɛlɔ lem ji Tata alɔ wur tɔg.”', metadata={'source': 'LUK 2:15', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'And  it came to pass  as  were departing  from  them  into  the  heaven  the  angels, the  shepherds  were saying  to  one another  Let us go through  indeed  as far as  Bethlehem  and  let us see  the  word  this  that  has come to pass  which  the  Lord  has made known  to us. ', 'target': 'Na ji bateb ɔteb Ɔsɔwɔ alɔ tum abɔ asa afɛngɛ njim ajɛn na libonta, ba babe ɔjɔra akuma mbonga atɔga atɛm, “Ɛjɛn na Bɛtlɛm ɛji yɛn nsɔl yi ɛlɔ lem ji Tata alɔ wur tɔg.”'}), Document(page_content='“Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl.', metadata={'source': 'LUK 16:16', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'The  law  and  the  prophets [were]  until  John· from  that time  the  kingdom  -  of God  is proclaimed  and  everyone  into  it  forces his way. ', 'target': '“Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl.'}), Document(page_content='Jɔn atɔg lirɔng anɛ ba abalɔ alib nwuri arɛ, “Wun abɔn ɛgbɔda! Wun ɔkɛrɛ arɛ ɔmamal ɔrɛm ɛyama litem ji Ɔsɔwɔ ji ɛla ba ɛ?', metadata={'source': 'LUK 3:7', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'He was saying  therefore  to the  coming out  crowds  to be baptized  by  him  Offspring  of vipers, who  forewarned  you  to flee  from  the  coming  wrath; ', 'target': 'Jɔn atɔg lirɔng anɛ ba abalɔ alib nwuri arɛ, “Wun abɔn ɛgbɔda! Wun ɔkɛrɛ arɛ ɔmamal ɔrɛm ɛyama litem ji Ɔsɔwɔ ji ɛla ba ɛ?'}), Document(page_content='Atab brɛd, akag Ɔsɔwɔ sam, abɛg atab akarɛ abɔ abong arɛ, “Fa ngoabiji ɛma yi mɛ nkarɛ wun. Ba lem anɔ wun ɔgbɔ mam nter.”', metadata={'source': 'LUK 22:19', 'greek': 'Μετὰ δὲ ταῦτα ἀνέδειξεν ὁ Κύριος ἑτέρους ἑβδομήκοντα,καὶ ἀπέστειλεν αὐτοὺς ἀνὰ δύο πρὸ προσώπου αὐτοῦ εἰς πᾶσαν πόλιν καὶ τόπον οὗ ἤμελλεν αὐτὸς ἔρχεσθαι.', 'gloss': 'And  having taken  [the] bread  having given thanks  He broke [it]  and  gave  to them  saying  This  is  the  body  of Me  which  for  you  is given· this  do  in  the  of Me  remembrance. ', 'target': 'Atab brɛd, akag Ɔsɔwɔ sam, abɛg atab akarɛ abɔ abong arɛ, “Fa ngoabiji ɛma yi mɛ nkarɛ wun. Ba lem anɔ wun ɔgbɔ mam nter.”'})]
# ['Config', '__abstractmethods__', '__annotations__', '__class__', '__class_vars__', '__config__', '__custom_root_type__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__exclude_fields__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_validators__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__include_fields__', '__init__', '__init_subclass__', '__iter__', '__json_encoder__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__post_root_validators__', '__pre_root_validators__', '__pretty__', '__private_attributes__', '__reduce__', '__reduce_ex__', '__repr__', '__repr_args__', '__repr_name__', '__repr_str__', '__rich_repr__', '__schema_cache__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__try_update_forward_refs__', '__validators__', '_abc_impl', '_calculate_keys', '_copy_and_set_values', '_decompose_class', '_enforce_dict_if_root', '_get_value', '_init_private_attributes', '_iter', 'construct', 'copy', 'dict', 'from_orm', 'json', 'metadata', 'page_content', 'parse_file', 'parse_obj', 'parse_raw', 'schema', 'schema_json', 'update_forward_refs', 'validate']
# LUK 1:68 --> [('Said  then  the  father  to  the  servants  of him  Quickly  bring out  robe  the  best  and  clothe  him, and  give  a ring  for  the  hand  of him  and  sandals  for  his  feet, ', '“Ndɛ abong atɔg barɔgantom abɛ arɛ, ‘Baba kakab! Na ɛteng ɛleba wun ɔba yɔbɛ wɛ. Ɔkagɛ ɛbel na nyig ɔbɔ na akpagata na ata ayɛ.'), ('And  it came to pass  as  were departing  from  them  into  the  heaven  the  angels, the  shepherds  were saying  to  one another  Let us go through  indeed  as far as  Bethlehem  and  let us see  the  word  this  that  has come to pass  which  the  Lord  has made known  to us. ', 'Na ji bateb ɔteb Ɔsɔwɔ alɔ tum abɔ asa afɛngɛ njim ajɛn na libonta, ba babe ɔjɔra akuma mbonga atɔga atɛm, “Ɛjɛn na Bɛtlɛm ɛji yɛn nsɔl yi ɛlɔ lem ji Tata alɔ wur tɔg.”'), ('The  law  and  the  prophets [were]  until  John· from  that time  the  kingdom  -  of God  is proclaimed  and  everyone  into  it  forces his way. ', '“Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl.'), ('He was saying  therefore  to the  coming out  crowds  to be baptized  by  him  Offspring  of vipers, who  forewarned  you  to flee  from  the  coming  wrath; ', 'Jɔn atɔg lirɔng anɛ ba abalɔ alib nwuri arɛ, “Wun abɔn ɛgbɔda! Wun ɔkɛrɛ arɛ ɔmamal ɔrɛm ɛyama litem ji Ɔsɔwɔ ji ɛla ba ɛ?'), ('And  having taken  [the] bread  having given thanks  He broke [it]  and  gave  to them  saying  This  is  the  body  of Me  which  for  you  is given· this  do  in  the  of Me  remembrance. ', 'Atab brɛd, akag Ɔsɔwɔ sam, abɛg atab akarɛ abɔ abong arɛ, “Fa ngoabiji ɛma yi mɛ nkarɛ wun. Ba lem anɔ wun ɔgbɔ mam nter.”')]
# prediction {'data': {'translation': {'source_sentence': '“Ɔtɔŋŋɛ Ɔsɔwɔ, Tata alɔ Isirayel, ɛlɛ mɛnɛŋ mɛnɛŋ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ.'}}, 'raw': '<json>{"translation": {"source_sentence": "“Ɔtɔŋŋɛ Ɔsɔwɔ, Tata alɔ Isirayel, ɛlɛ mɛnɛŋ mɛnɛŋ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ."}}</json>', 'errors': [], 'validated_data': {}}
# reverse_prediction {'data': {'translation': {'source_sentence': 'And  having taken  bread  having given thanks  He broke [it]  and  gave  to them  saying  This  is  My  body  which  for  you  is given· this  do  in  the  of Me  remembrance. '}}, 'raw': '<json>{"translation": {"source_sentence": "And  having taken  bread  having given thanks  He broke [it]  and  gave  to them  saying  This  is  My  body  which  for  you  is given· this  do  in  the  of Me  remembrance. "}}</json>', 'errors': [], 'validated_data': {}}
# Original: “Baba wur ɛtig Tata Ɔsɔwɔ bi Isrɛl! ateb wɛ agba ba naji anɛ abɛ arɛ aba nyangɛ abɔ.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 42
#      37 # TODO: Compare the resulting target translation and back-translated source to the original sentence pair
#      38 # This requires a suitable metric for comparison, such as the BLEU score for translation tasks.
#      39
#      40 # For now, just print the results and compare to the original
#      41 print('Original:', sentence_dict['target'])
# ---> 42 print('Predicted:', prediction['data']['target_sentence'])
#      43 print('Backtranslated version of the model\'s prediction:', backtranslated_target_sentence)
#      44 print('Backtranslated version of the gold-standard sentence:', backtranslated_original_target_sentence)
#
# KeyError: 'target_sentence'

# %%
print('Original:\n', sentence_dict['target'])
print('Original gloss:\n', sentence_dict['gloss'])
print('Backtranslated version of the gold-standard sentence:\n', backtranslated_original_target_sentence)

print('\nPredicted:\n', prediction['data']['translation']['source_sentence'])
print('Backtranslated version of the model\'s prediction:\n', backtranslated_target_sentence)
# Out:
# Original:
#  “Baba wur ɛtig Tata Ɔsɔwɔ bi Isrɛl! ateb wɛ agba ba naji anɛ abɛ arɛ aba nyangɛ abɔ.
# Original gloss:
#  Blessed be  [the] Lord  the  God  -  of Israel, because  He has visited  and  has performed  redemption  [on] the  people  of Him,
# Backtranslated version of the gold-standard sentence:
#  Blessed  [be]  the  Lord  the  God  of Israel, because  He has visited  and  made  redemption  for  His  people,
#
# Predicted:
#  “Ɔtɔŋŋɛ Ɔsɔwɔ, Tata alɔ Isirayel, ɛlɛ mɛnɛŋ mɛnɛŋ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ, ɛlɛ mɛnɛŋ ɛtɛm ji ɛla ba ɛ.
# Backtranslated version of the model's prediction:
#  And  having taken  bread  having given thanks  He broke [it]  and  gave  to them  saying  This  is  My  body  which  for  you  is given· this  do  in  the  of Me  remembrance.

# %%
print(translate_chain.prompt.format_prompt(text="[user input]").to_string())
print('>>>>>>>>>')
print(backtranslation_chain.prompt.format_prompt(text="[user input]").to_string())
# Out:
# Your goal is to extract structured information from the user's input that matches the form described below. When extracting information please make sure it matches the type information exactly. Do not add any attributes that do not appear in the schema shown below.
#
# ```TypeScript
#
# translation: { // Translate the source sentence to the target language.
#  source_sentence: string // The sentence in the source language
#  target_sentence: string // The translated sentence in the target language
# }
# ```
#
#
# Please output the extracted information in JSON format. Do not output anything except for the extracted information. Do not add any clarifying information. Do not add any fields that are not in the schema. If the text contains attributes that do not appear in the schema, please ignore them. All output must be in JSON format and follow the schema specified above. Wrap the JSON in <json> tags.
#
#
#
# Input: Said  then  the  father  to  the  servants  of him  Quickly  bring out  robe  the  best  and  clothe  him, and  give  a ring  for  the  hand  of him  and  sandals  for  his  feet,
# Output: <json>{"translation": {"source_sentence": "“Ndɛ abong atɔg barɔgantom abɛ arɛ, ‘Baba kakab! Na ɛteng ɛleba wun ɔba yɔbɛ wɛ. Ɔkagɛ ɛbel na nyig ɔbɔ na akpagata na ata ayɛ."}}</json>
# Input: And  it came to pass  as  were departing  from  them  into  the  heaven  the  angels, the  shepherds  were saying  to  one another  Let us go through  indeed  as far as  Bethlehem  and  let us see  the  word  this  that  has come to pass  which  the  Lord  has made known  to us.
# Output: <json>{"translation": {"source_sentence": "Na ji bateb ɔteb Ɔsɔwɔ alɔ tum abɔ asa afɛngɛ njim ajɛn na libonta, ba babe ɔjɔra akuma mbonga atɔga atɛm, “Ɛjɛn na Bɛtlɛm ɛji yɛn nsɔl yi ɛlɔ lem ji Tata alɔ wur tɔg.”"}}</json>
# Input: The  law  and  the  prophets [were]  until  John· from  that time  the  kingdom  -  of God  is proclaimed  and  everyone  into  it  forces his way.
# Output: <json>{"translation": {"source_sentence": "“Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl."}}</json>
# Input: He was saying  therefore  to the  coming out  crowds  to be baptized  by  him  Offspring  of vipers, who  forewarned  you  to flee  from  the  coming  wrath;
# Output: <json>{"translation": {"source_sentence": "Jɔn atɔg lirɔng anɛ ba abalɔ alib nwuri arɛ, “Wun abɔn ɛgbɔda! Wun ɔkɛrɛ arɛ ɔmamal ɔrɛm ɛyama litem ji Ɔsɔwɔ ji ɛla ba ɛ?"}}</json>
# Input: And  having taken  [the] bread  having given thanks  He broke [it]  and  gave  to them  saying  This  is  the  body  of Me  which  for  you  is given· this  do  in  the  of Me  remembrance.
# Output: <json>{"translation": {"source_sentence": "Atab brɛd, akag Ɔsɔwɔ sam, abɛg atab akarɛ abɔ abong arɛ, “Fa ngoabiji ɛma yi mɛ nkarɛ wun. Ba lem anɔ wun ɔgbɔ mam nter.”"}}</json>
# Input: [user input]
# Output:
# >>>>>>>>>
# Your goal is to extract structured information from the user's input that matches the form described below. When extracting information please make sure it matches the type information exactly. Do not add any attributes that do not appear in the schema shown below.
#
# ```TypeScript
#
# translation: { // Translate the source sentence to the target language.
#  source_sentence: string // The sentence in the source language
#  target_sentence: string // The translated sentence in the target language
# }
# ```
#
#
# Please output the extracted information in JSON format. Do not output anything except for the extracted information. Do not add any clarifying information. Do not add any fields that are not in the schema. If the text contains attributes that do not appear in the schema, please ignore them. All output must be in JSON format and follow the schema specified above. Wrap the JSON in <json> tags.
#
#
#
# Input: “Ndɛ abong atɔg barɔgantom abɛ arɛ, ‘Baba kakab! Na ɛteng ɛleba wun ɔba yɔbɛ wɛ. Ɔkagɛ ɛbel na nyig ɔbɔ na akpagata na ata ayɛ.
# Output: <json>{"translation": {"source_sentence": "Said  then  the  father  to  the  servants  of him  Quickly  bring out  robe  the  best  and  clothe  him, and  give  a ring  for  the  hand  of him  and  sandals  for  his  feet, "}}</json>
# Input: Na ji bateb ɔteb Ɔsɔwɔ alɔ tum abɔ asa afɛngɛ njim ajɛn na libonta, ba babe ɔjɔra akuma mbonga atɔga atɛm, “Ɛjɛn na Bɛtlɛm ɛji yɛn nsɔl yi ɛlɔ lem ji Tata alɔ wur tɔg.”
# Output: <json>{"translation": {"source_sentence": "And  it came to pass  as  were departing  from  them  into  the  heaven  the  angels, the  shepherds  were saying  to  one another  Let us go through  indeed  as far as  Bethlehem  and  let us see  the  word  this  that  has come to pass  which  the  Lord  has made known  to us. "}}</json>
# Input: “Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl.
# Output: <json>{"translation": {"source_sentence": "The  law  and  the  prophets [were]  until  John· from  that time  the  kingdom  -  of God  is proclaimed  and  everyone  into  it  forces his way. "}}</json>
# Input: Jɔn atɔg lirɔng anɛ ba abalɔ alib nwuri arɛ, “Wun abɔn ɛgbɔda! Wun ɔkɛrɛ arɛ ɔmamal ɔrɛm ɛyama litem ji Ɔsɔwɔ ji ɛla ba ɛ?
# Output: <json>{"translation": {"source_sentence": "He was saying  therefore  to the  coming out  crowds  to be baptized  by  him  Offspring  of vipers, who  forewarned  you  to flee  from  the  coming  wrath; "}}</json>
# Input: Atab brɛd, akag Ɔsɔwɔ sam, abɛg atab akarɛ abɔ abong arɛ, “Fa ngoabiji ɛma yi mɛ nkarɛ wun. Ba lem anɔ wun ɔgbɔ mam nter.”
# Output: <json>{"translation": {"source_sentence": "And  having taken  [the] bread  having given thanks  He broke [it]  and  gave  to them  saying  This  is  the  body  of Me  which  for  you  is given· this  do  in  the  of Me  remembrance. "}}</json>
# Input: [user input]
# Output:

# %% [markdown]
# # Define translation functions

# %%
# TODO: implement several ways of breaking down the Greek text, including:
# 1. syntactic - either clauses or word groups? Similar examples would be lexical...?
# 2. semantic - broken down by semantic roles? Similar examples would be semantic role based, and lexical?
# 3. discourse - broken down by speech acts? Similar examples would be act plus same core lexeme?

def split_verse_by_chunk_type(verse_ref, chunk_type="speech act"):
    """Splits a verse based on speech acts or other chunk types.
    
    Possible types:
    - "speech act": leverages OpenText syntax
    - "word group": leverages OpenText syntax
    - "token": leverages MACULA tokens
    - "clause": leverages OpenText syntax
    - "verse": leverages MACULA syntax (gets sentence that contains verse)
    """
    
    return ['this is an array', 'of chunks of the specified type']
    # TODO: figure out how best to get chunks by type from a verse ref...
    # I think what I need to do is create a database for each type of chunk.
    # TODO: use oxygen to create the basic transforms

def build_few_shot_prompt(source_text, chroma_database, backtranslate=False):
    # TODO: use prompt template instead of kor extraction chain, since it's not really structured data...
    # e.g., 'translate this text, using only data from the examples...
    # perhaps I should tokenize the input string and make sure every
    # token is represented in the examples. That way... there is at least
    # a good chance the model can figure out some way to associate source 
    # and target sequences
    
    examples = [] # TODO: provision examples for each token in source_text (see note above)
    # NOTE: I think for the examples I need some kind of example validation function
    # e.g., check for tfidf token coverage (or reverse?? since infrequent tokens can
    # be transliterated and frequent ones will help secure collocations/colligations?)
    
    # FIXME: get similar examples based on chunks in source text... each chunk's core/head needs to be represented
    # chunk_type = 'speech act'
    # chunks = split_verse_by_chunk_type(verse_ref, chunk_type)
    # for chunk in chunks:
    #     verse_with_chunk = chroma_database.search(chunk, search_type='similarity', k=1) # FIXME: query a db of the chunk type
    similar_sentences = chroma_database.search(source_text, search_type='similarity', k=10)
    
    if backtranslate:
        examples = [f"Source: {sentence.metadata['gloss']}\nTarget: {sentence.page_content}" for sentence in similar_sentences if sentence != source_text]
    else:
        examples = [f"Source: {sentence.page_content}\nTarget: {sentence.metadata['gloss']}" for sentence in similar_sentences if sentence != source_text]

    examples = '\n'.join(examples)
    
    # Validate examples
    unaccounted_tokens = []
    for token in source_text.split(): # TODO: remove punctuation as well
        if token.lower() not in examples.lower():
            unaccounted_tokens.append(token)
            
    unaccounted_tokens = ','.join(unaccounted_tokens)
        
    output_instructions = (
        "Translate the source text below using only the data from the "
        "supplied example pairs. Do not fill in any gaps in the sense if the "
        "examples do not provide adequate coverage of the source text. "
        "Rather, retain any untranslated source text content in [square brackets]. "
        "As this will help identify where new example pairs are needed. "
    )
    
    if len(unaccounted_tokens) > 0:
        output_instructions += (
            "The following tokens are not accounted for, so don't bother trying to "
            "translate them: {unaccounted_tokens}"
            ).format(unaccounted_tokens=unaccounted_tokens)
    
    prompt_template = (
        "You are LowResourceLanguageTranslationBot. With minimal input "
        "data, you can identify covariance patterns between source and "
        "target texts. Your aim is to draft translations. Given a source "
        "text, you require only some examples of the source tokens being "
        "used in other translation pairs."
        "\n"
        "{output_instructions}\n\n"
        "Example pairs:\n{examples}\n\n"
        "Source: {source_text}\nTarget:"
    ).format(output_instructions=output_instructions, source_text=source_text, examples=examples)
    
    prompt = prompt_template
    
    return prompt
    
    # Use OpenAI's completion endpoint for annotating new translations on the test sentences using the examples
    # prediction = translate_chain.predict_and_parse(text=sentence_dict['gloss'])
    

    # print('prediction', prediction)
    # translated_sentence = prediction['data']['translation']['source_sentence']
    
    # # TODO: Backtranslate the results to the source language without seeing the original translations
    # # This requires an additional translation model or API that can translate from the target language back to the source language.
    # reverse_prediction = backtranslation_chain.predict_and_parse(text=translated_sentence)
    # print('reverse_prediction', reverse_prediction)
    # backtranslated_target_sentence = reverse_prediction['data']['translation']['source_sentence']
    
    # # Backtranslate the original, gold-standard translation for a comparative basis
    # original_backtranslation_prediction = backtranslation_chain.predict_and_parse(text=sentence_dict['target'])
    # backtranslated_original_target_sentence = original_backtranslation_prediction['data']['translation']['source_sentence']
    
    # # TODO: Compare the resulting target translation and back-translated source to the original sentence pair
    # # This requires a suitable metric for comparison, such as the BLEU score for translation tasks.
    
    # # For now, just print the results and compare to the original
    # print('Original:', sentence_dict['target'])
    # print('Predicted:', prediction['data']['source_sentence'])
    # print('Backtranslated version of the model\'s prediction:', backtranslated_target_sentence)
    # print('Backtranslated version of the gold-standard sentence:', backtranslated_original_target_sentence)

# %%
test_sentence = 'Blessed be  [the] Lord  the  God  -  of Israel, because  He has visited  and  has performed  redemption  [on] the  people  of Him,'

prompt = build_few_shot_prompt(test_sentence, collection)
print(prompt)
# Out:
# You are LowResourceLanguageTranslationBot. With minimal input data, you can identify covariance patterns between source and target texts. Your aim is to draft translations. Given a source text, you require only some examples of the source tokens being used in other translation pairs.
# Translate the source text below using only the data from the supplied example pairs. Do not fill in any gaps in the sense if the examples do not provide adequate coverage of the source text. Rather, retain any untranslated source text content in [square brackets]. As this will help identify where new example pairs are needed. The following tokens are not accounted for, so don't bother trying to translate them: Blessed,[the],Lord,Israel,,because,visited,performed,redemption,[on]
#
# Example pairs:
# Source: Mɛ ngɔrɛ batɔnanjim aba ndɛ akam ɛbe ɛtugi jifɔ ayege, amalam.”
# Target: And  I begged  the  disciples  of You  that  they might cast out  it, and  not  they were able.
# Source: “Mbima ɛgbɛ ajil abim amug a nsɔl ayɛ. Naji awuri amug yafɔ, amuga nsɔl yandɛga awuri na mba, anɛ anyɛdɛ anyamfor ali.
# Target: Went out  the [one]  sowing  -  to sow  the  seed  of him. And  in  the  sowing  of him  some  indeed  fell  along  the  road, and  it was trampled upon, and  the  birds  of the  air  devoured  it.
# Source: “Ba kone ɛkpo na ba teba ajing. Ba asɛba arɛ ajɔ jɛn atoba asibi na araba buwuri. Asɛba arɛ ajɔ kag abɔ nyɔ na ɔkponi na mfom arɛ, titi asɛba arɛ ajɔl na mfom yi ɔkponi na ɛkpasega na mfom likag.
# Target: Beware  of  the  scribes  -  desiring  to walk  in  long robes  and  loving  greetings  in  the  marketplaces  and  first seats  in  the  synagogues  and  first places  in  the  banquets,
# Source: Abɔ atɛn arɛ, “Nteba ɛyɛ abaga na ɛfegayɔ na Judiya kpakpa. Abɔm na Galili batig agba rir fa.”
# Target: -  But  they kept insisting  saying  -  He stirs up  the  people, teaching  throughout  all  -  of Judea, and  He has begun  from  -  Galilee  even to  here.
# Source: “Na ɛjiba jirang ɛbɛl namabilam yɔ adɛnɔ jɔ abɛ Ɔsɔwɔ nig akɛrɛ anɛ.
# Target: saying  A judge  certain  there was  in  a certain  city  -  God  not  fearing  and  man  not  respecting.
# Source: Fɔyɔ atumɔ ayema afɛngɛ naji ndɛ. “Naji akpenɔ re na ndabamba, nsɔjɛ ayɛnɛ ndɔn afele wɛ nanɛ; abɛna aji kɔn mɔn ɔwɛ akpera wɛ akugɛ nyɔ.
# Target: And  having risen up  he went  to  the  father  of himself. Still  now  he  far  being distant  saw  him  the  father  of him  and  was moved with compassion, and  having run  fell  upon  the  neck  of him  and  kissed  him.
# Source: “Na ɛkɛbɛ ngara namabilam yɔfɔ ajɔl tɛtɛn, na nkulsi abong atɔg ɛlɛ, ‘Ɛjɔl mɛ ndɛ bɛ Ɔsɔwɔ nig ndɛ mbri anɛ,
# Target: And  not  he would  for  a time· afterward  he  however  said  within  himself  If  even  -  God  not  I fear  nor  man  respect,
# Source: Ɛgbem anɛ ajɔjɔl na Isrɛl ba abɛlɔ abele na ngara nyɛn amir a Ɛlayisa, ɛjɔl wurang anɔbam ndɛg Naman yɔ arunɔ Siriya.”
# Target: And  many  lepers  were  in  -  Israel  in the time  of Elisha  the  prophet, and  none  of them  was cleansed  if  not  Naaman  the  Syrian.
# Source: “Ajɔlam kɔr anɛ abɛ, fɔyɔ atomɔ nteb ɔteb arɛ aji tɔgɛ arɛ ‘wur wɛ ɛkpɛlam sɛb mɔng ntol ɔwura.’
# Target: -  But  the citizens  of him  hated  him, and  sent  a delegation  after  him  saying  Not  we are willing [for]  this [man]  to reign  over  us.
# Source: Jisɔs afanga, “Abrambi akpe abe, anyamfor akpe bijo, mɔn a nɛnom akpem mfom yi ala nɔnga arɛdɛ ɛkɛr.”
# Target: And  said  to him  -  Jesus  The  foxes  holes  have  and  the  birds  of the  air  nests, -  but  the Son  -  of Man  not  has  where  the  head  He might lay.
#
# Source: Blessed be  [the] Lord  the  God  -  of Israel, because  He has visited  and  has performed  redemption  [on] the  people  of Him,
# Target:

# %%
# Use OpenAI completion endpoint (davinci 003) to complete the prompt from template
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate

llm = OpenAI(temperature=0.1)
# prompt = PromptTemplate(
#     input_variables=["product"],
#     template="What is a good name for a company that makes {product}?",
# )
# Use my prompt expansion function to build the prompt
prompt = build_few_shot_prompt(test_sentence, collection)

# Reformat into the langchain PromptTemplate to avoid this error: ValidationError: 1 validation error for LLMChain\nprompt\n value is not a valid dict (type=type_error.dict)
prompt = PromptTemplate(
    input_variables=["source_text"],
    template=prompt,
)

from langchain.chains import LLMChain
chain = LLMChain(
    llm=llm, 
    prompt=prompt)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[31], line 14
#      11 prompt = build_few_shot_prompt(test_sentence, collection)
#      13 # Reformat into the langchain PromptTemplate to avoid this error: ValidationError: 1 validation error for LLMChain\nprompt\n value is not a valid dict (type=type_error.dict)
# ---> 14 prompt = PromptTemplate(
#      15     input_variables=["source_text"],
#      16     template=prompt,
#      17 )
#      19 from langchain.chains import LLMChain
#      20 chain = LLMChain(
#      21     llm=llm,
#      22     prompt=prompt)
#
# File /opt/homebrew/lib/python3.10/site-packages/pydantic/main.py:341, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for PromptTemplate
# __root__
#   Invalid prompt schema; check for mismatched or missing input parameters. {'source_text'} (type=value_error)

# %%
chain.run("colorful socks")

# %% [markdown]
# ## Move functionality into langchain ecosystem

# %%
from langchain.prompts.few_shot import FewShotPromptTemplate
from langchain.prompts.example_selector import SemanticSimilarityExampleSelector
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
from langchain.chains.base import Chain
from langchain.chains import LLMChain
from langchain.prompts.prompt import PromptTemplate
from langchain.chains import TransformChain, SimpleSequentialChain
from langchain.llms import OpenAI

# %%
class TranslatePromptBuilder(LLMChain):
    class Config:
        extra = "allow"

    def __init__(self, chroma_database, backtranslate=False, **kwargs):
        super().__init__(**kwargs)
        self.chroma_database = chroma_database
        self.backtranslate = backtranslate

    @property
    def input_keys(self):
        return ["source_text"]

    @property
    def output_keys(self):
        return ["prompt"]

    def _call(self, inputs, run_manager=None):
        source_text = inputs["source_text"]
        examples = self.chroma_database.search(source_text, search_type='similarity', k=8)
        if self.backtranslate:
            examples = [f"Source: {sentence.page_content}\nTarget: {sentence.metadata['gloss']}" for sentence in examples if sentence != source_text]
        else:
            examples = [f"Source: {sentence.metadata['gloss']}\nTarget: {sentence.page_content}" for sentence in examples if sentence != source_text]
        examples = '\n'.join(examples)
        unaccounted_tokens = [token for token in source_text.split() if token.lower() not in examples.lower()]
        unaccounted_tokens = ','.join(unaccounted_tokens)
        output_instructions = (
            "Translate the source text below using only the data from the "
            "supplied example pairs. Do not fill in any gaps in the sense if the "
            "examples do not provide adequate coverage of the source text. "
            "Rather, retain any untranslated source text content in [square brackets]. "
            "As this will help identify where new example pairs are needed. "
        )
        
        if self.backtranslate:
            output_instructions += (
                "Your job is to back-translate a draft translation for QA purposes. "
                "Please translate the translation text back into the source language. "
            )
        
        if len(unaccounted_tokens) > 0:
            output_instructions += (
                "The following tokens are not accounted for, so don't bother trying to "
                "translate them: {unaccounted_tokens}"
                ).format(unaccounted_tokens=unaccounted_tokens)
        
        prompt_template = ( # FIXME: extract this logic so it can be used in the backtranslation prompt builder too
            "You are LowResourceLanguageTranslationBot. With minimal input "
            "data, you can identify covariance patterns between source and "
            "target texts. Your aim is to draft translations. Given a source "
            "text, you require only some examples of the source tokens being "
            "used in other translation pairs."
            "\n"
            "{output_instructions}\n\n"
            "Example pairs:\n{examples}\n\n"
            "Source: {source_text}\nTarget:"
        ).format(output_instructions=output_instructions, source_text=source_text, examples=examples)
        return {"prompt": prompt_template}

# %%
# Create your example selector
example_selector = SemanticSimilarityExampleSelector(
    vectorstore=collection,
    k=10
)

# %%
# Create your prompt template
prompt_template = FewShotPromptTemplate(
    example_selector=example_selector, 
    example_prompt=PromptTemplate(input_variables=["source", "target"], template="Source: {source}\nTarget: {target}"), 
    suffix="Source: {input}\nTarget:", 
    input_variables=["input"]
)

# Create your translate chain
translate_prompt = TranslatePromptBuilder(
    chroma_database=collection,
    prompt=prompt_template, #FIXME: I should not be passing this in, or else I should not be building this within the class
    llm=OpenAI()
)

# Create your back translate chain
back_translate_chain = TranslatePromptBuilder(
    chroma_database=collection,
    backtranslate=True,
    prompt=prompt_template,
    llm=OpenAI()
)

# %%
# Your test sentence
test_sentence = "Blessed be  [the] Lord  the  God  -  of Israel, because  He has visited  and  has performed  redemption  [on] the  people  of Him,"

# Use the translate chain
translation_prompt = translate_chain.run(test_sentence)
# print("## Translation:\n\n", translation_prompt)

# %%
result = openai.Completion.create(
    engine="davinci",
    prompt=translation_prompt,
    max_tokens=200,
    temperature=0.9,
    # top_p=1,
    # frequency_penalty=0,
    # presence_penalty=0,
    stop=["\n"]
)

# %%
completed = ' '.join([translation_prompt, result.choices[0].text])

print("## Translation:\n\n", completed)
# Out:
# ## Translation:
#
#  You are LowResourceLanguageTranslationBot. With minimal input data, you can identify covariance patterns between source and target texts. Your aim is to draft translations. Given a source text, you require only some examples of the source tokens being used in other translation pairs.
# Translate the source text below using only the data from the supplied example pairs. Do not fill in any gaps in the sense if the examples do not provide adequate coverage of the source text. Rather, retain any untranslated source text content in [square brackets]. As this will help identify where new example pairs are needed. The following tokens are not accounted for, so don't bother trying to translate them: Blessed,[the],Lord,Israel,,because,visited,performed,redemption,[on]
#
# Example pairs:
# Source: And  I begged  the  disciples  of You  that  they might cast out  it, and  not  they were able.
# Target: Mɛ ngɔrɛ batɔnanjim aba ndɛ akam ɛbe ɛtugi jifɔ ayege, amalam.”
# Source: Went out  the [one]  sowing  -  to sow  the  seed  of him. And  in  the  sowing  of him  some  indeed  fell  along  the  road, and  it was trampled upon, and  the  birds  of the  air  devoured  it.
# Target: “Mbima ɛgbɛ ajil abim amug a nsɔl ayɛ. Naji awuri amug yafɔ, amuga nsɔl yandɛga awuri na mba, anɛ anyɛdɛ anyamfor ali.
# Source: Beware  of  the  scribes  -  desiring  to walk  in  long robes  and  loving  greetings  in  the  marketplaces  and  first seats  in  the  synagogues  and  first places  in  the  banquets,
# Target: “Ba kone ɛkpo na ba teba ajing. Ba asɛba arɛ ajɔ jɛn atoba asibi na araba buwuri. Asɛba arɛ ajɔ kag abɔ nyɔ na ɔkponi na mfom arɛ, titi asɛba arɛ ajɔl na mfom yi ɔkponi na ɛkpasega na mfom likag.
# Source: -  But  they kept insisting  saying  -  He stirs up  the  people, teaching  throughout  all  -  of Judea, and  He has begun  from  -  Galilee  even to  here.
# Target: Abɔ atɛn arɛ, “Nteba ɛyɛ abaga na ɛfegayɔ na Judiya kpakpa. Abɔm na Galili batig agba rir fa.”
# Source: saying  A judge  certain  there was  in  a certain  city  -  God  not  fearing  and  man  not  respecting.
# Target: “Na ɛjiba jirang ɛbɛl namabilam yɔ adɛnɔ jɔ abɛ Ɔsɔwɔ nig akɛrɛ anɛ.
# Source: And  having risen up  he went  to  the  father  of himself. Still  now  he  far  being distant  saw  him  the  father  of him  and  was moved with compassion, and  having run  fell  upon  the  neck  of him  and  kissed  him.
# Target: Fɔyɔ atumɔ ayema afɛngɛ naji ndɛ. “Naji akpenɔ re na ndabamba, nsɔjɛ ayɛnɛ ndɔn afele wɛ nanɛ; abɛna aji kɔn mɔn ɔwɛ akpera wɛ akugɛ nyɔ.
# Source: And  not  he would  for  a time· afterward  he  however  said  within  himself  If  even  -  God  not  I fear  nor  man  respect,
# Target: “Na ɛkɛbɛ ngara namabilam yɔfɔ ajɔl tɛtɛn, na nkulsi abong atɔg ɛlɛ, ‘Ɛjɔl mɛ ndɛ bɛ Ɔsɔwɔ nig ndɛ mbri anɛ,
# Source: And  many  lepers  were  in  -  Israel  in the time  of Elisha  the  prophet, and  none  of them  was cleansed  if  not  Naaman  the  Syrian.
# Target: Ɛgbem anɛ ajɔjɔl na Isrɛl ba abɛlɔ abele na ngara nyɛn amir a Ɛlayisa, ɛjɔl wurang anɔbam ndɛg Naman yɔ arunɔ Siriya.”
# Source: -  But  the citizens  of him  hated  him, and  sent  a delegation  after  him  saying  Not  we are willing [for]  this [man]  to reign  over  us.
# Target: “Ajɔlam kɔr anɛ abɛ, fɔyɔ atomɔ nteb ɔteb arɛ aji tɔgɛ arɛ ‘wur wɛ ɛkpɛlam sɛb mɔng ntol ɔwura.’
# Source: And  said  to him  -  Jesus  The  foxes  holes  have  and  the  birds  of the  air  nests, -  but  the Son  -  of Man  not  has  where  the  head  He might lay.
# Target: Jisɔs afanga, “Abrambi akpe abe, anyamfor akpe bijo, mɔn a nɛnom akpem mfom yi ala nɔnga arɛdɛ ɛkɛr.”
#
# Source: Blessed be  [the] Lord  the  God  -  of Israel, because  He has visited  and  has performed  redemption  [on] the  people  of Him,
# Target:  “Abɔbat Ɔrɔja aba - Ɔsɔwɔ niyi aji abɔ. Ana yi je Ɔsɔwɔ kɔn ndɛ nyɛ arɛfɛl abɔ nyɛ ndɛ nɛmɛ Ɔsɔwɔ arɛ Ɔsɔwɔ niyi Ɔsɔwɔ ndɛ nyɛ yɛ ni yi.

# %%
# Use the back translate chain
# Note: The back translate chain expects the input to be in the format "source\ntarget".
back_translation_prompt = back_translate_chain.run(result.choices[0].text)

# %%
back_translation_prompt
# Out:
# "You are LowResourceLanguageTranslationBot. With minimal input data, you can identify covariance patterns between source and target texts. Your aim is to draft translations. Given a source text, you require only some examples of the source tokens being used in other translation pairs.\nTranslate the source text below using only the data from the supplied example pairs. Do not fill in any gaps in the sense if the examples do not provide adequate coverage of the source text. Rather, retain any untranslated source text content in [square brackets]. As this will help identify where new example pairs are needed. Your job is to back-translate a draft translation for QA purposes. Please translate the translation text back into the source language. The following tokens are not accounted for, so don't bother trying to translate them: “Abɔbat,Ɔrɔja,niyi,abɔ.,Ana,kɔn,arɛfɛl,nɛmɛ,niyi,yi.\n\nExample pairs:\nSource: “Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl.\nTarget: The  law  and  the  prophets [were]  until  John· from  that time  the  kingdom  -  of God  is proclaimed  and  everyone  into  it  forces his way. \nSource: “Rang, wɔ ɔbin na ɛyɛbalitem, nsɔl yi fɔ ɛlɔ lem ɛkara ateb ntore ɛya afafang na Ɔtol Ɔsɔwɔ. Anɔ yɔ anɛ abɔ ba ɛmini alemɔ ba yɛn amir.\nTarget: Rejoice  in  that  -  day  and  leap for joy· behold  for  the  reward  of you  [is] great  in  -  heaven· According to  these things  of them  for  used to treat  the  prophets  the  fathers  likewise. \nSource: Naji Hɛrɔd ayɛnɔ Jisɔs, abɛl ntakpa ɛyɛba litem ateba arɛ na ndaba mba ajɔl sɛb arɛ ayɛnɛ. Ateb nsɔl yi alɔ yog abangɛ wɛ, ajɔl kɛrɛ arɛ ayɛn Jisɔs alema akpɔga ɛsi.\nTarget: -  And  Herod  having seen  -  Jesus  [was] glad  exceedingly· he was  for  of  a long  time  wishing  to see  Him  because of  -  hearing  concerning  Him, and  he was hoping  some  sign  to see  by  Him  done. \nSource: Anɛ ba ajɔl wɛ babɛ abong atɔgɛ arɛ, “Nteteba, wur ɛnyinyi arɛ wɔ ɔteba ɔfɛngɛ ɔbonga ji ɛrenɔ na nsɛrɛ, wɔ ɔnim jɔga ɔteba ɛkomanjim, ɔjɔga ɔteba mba yi Ɔsɔwɔ yi arenɔ ɛtete.\nTarget: And  they questioned  Him  saying  Teacher, we know  that  rightly  You speak  and  teach  and  not  receive  [any] person, but  on the basis of  truth  the  way  -  of God  teach· \nSource: Naji arirɔ alagɛ Jɛrusɛlɛm na mfom yi mba ajɔlɔ ji ɛwɔng Ɔlif, batɔnanjim abɛ akuma njege Ɔsɔwɔ na ɛyɛbalitem na nyura lilom ateb akpɔga ɛsi a nsɔl kpakpa ya abɔ alɔ yɛn.\nTarget: Drawing near  then  of Him  already  at  the  descent  of the  Mount  -  of Olives  began  all  the  multitude  of the  disciples  rejoicing  to praise  -  God  in a voice  loud  for  all  which  they had seen  [the] mighty works, \nSource: Wɛ abib arɛ, “Ba nsɔl yi?” Abɔ afanga arɛ, “Nsɔl yi ɛlemɔ Jisɔs yɔ Nasarɛt. Ajɔl nyɛna amir abɛl ɛkɔ na alom na nema na libri Ɔsɔwɔ na anɛ kpakpa.\nTarget: And  He said  to them  What things; -  And  they said  to Him  The things  concerning  Jesus  of  Nazareth, who  was  a man  a prophet  mighty  in  deed  and  word  before  -  God  and  all  the  people, \nSource: Jisɔs abong atɔga abɔ, “Wun ɔlema mɔng wun ɔrenɔ ja na nbri anɛ, Ɔsɔwɔ anyinɔ ntem ɛyina. Nsɔl yi ɛloba anɛ na amir ɛream ɛjom ajiaji na libri Ɔsɔwɔ.\nTarget: And  He said  to them  You  are  those  justifying  themselves  before  -  men, -  but  God  knows  the  hearts  of you· for  that which  among  men  [is] exalted  [is] an abomination  before  -  God. \nSource: “Nɛ awiawi yɔ alagɔ jɔl ntɔnanjim ɔma ateg atɛn ndɛ na nyɛn, nkal na abɔn, na abɔnyɛn abɛ ba lom na ba kal ɛjɔl likpen ɛlɛ. Anɔ arig wɛ anim ma jɔl ntɔnanjim ɔma.\nTarget: If  anyone  comes  to  Me  and  not  hates  the  father  of himself  and  the  mother  and  the  wife  and  the  children  and  the  brothers  and  the  sisters, yes  and  even  the  life  of him, not  he is able  to be  of Me  disciple. \n\nSource:  “Abɔbat Ɔrɔja aba - Ɔsɔwɔ niyi aji abɔ. ...

# %%
back_result = openai.Completion.create(
    engine="davinci",
    prompt=back_translation_prompt,
    max_tokens=150,
    temperature=0.9,
    # top_p=1,
    # frequency_penalty=0,
    # presence_penalty=0,
    stop=["\n"]
)

# %%
back_completed = ' '.join([back_translation_prompt, back_result.choices[0].text])
print("## Back Translation:\n\n", back_completed)
# Out:
# ## Back Translation:
#
#  You are LowResourceLanguageTranslationBot. With minimal input data, you can identify covariance patterns between source and target texts. Your aim is to draft translations. Given a source text, you require only some examples of the source tokens being used in other translation pairs.
# Translate the source text below using only the data from the supplied example pairs. Do not fill in any gaps in the sense if the examples do not provide adequate coverage of the source text. Rather, retain any untranslated source text content in [square brackets]. As this will help identify where new example pairs are needed. Your job is to back-translate a draft translation for QA purposes. Please translate the translation text back into the source language. The following tokens are not accounted for, so don't bother trying to translate them: “Abɔbat,Ɔrɔja,niyi,abɔ.,Ana,kɔn,arɛfɛl,nɛmɛ,niyi,yi.
#
# Example pairs:
# Source: “Ajing ya Mosis na ɔteb bi ba yɛna amir atetebe tɛtɛ na ngara Jɔn nwura anɛ alib. Bɔm na ngara yifɔ ɛteng ɔteb bi Ɔtol Ɔsɔwɔ agba tebe anɛ kpakpa anɔga arɛ ayɛl.
# Target: The  law  and  the  prophets [were]  until  John· from  that time  the  kingdom  -  of God  is proclaimed  and  everyone  into  it  forces his way.
# Source: “Rang, wɔ ɔbin na ɛyɛbalitem, nsɔl yi fɔ ɛlɔ lem ɛkara ateb ntore ɛya afafang na Ɔtol Ɔsɔwɔ. Anɔ yɔ anɛ abɔ ba ɛmini alemɔ ba yɛn amir.
# Target: Rejoice  in  that  -  day  and  leap for joy· behold  for  the  reward  of you  [is] great  in  -  heaven· According to  these things  of them  for  used to treat  the  prophets  the  fathers  likewise.
# Source: Naji Hɛrɔd ayɛnɔ Jisɔs, abɛl ntakpa ɛyɛba litem ateba arɛ na ndaba mba ajɔl sɛb arɛ ayɛnɛ. Ateb nsɔl yi alɔ yog abangɛ wɛ, ajɔl kɛrɛ arɛ ayɛn Jisɔs alema akpɔga ɛsi.
# Target: -  And  Herod  having seen  -  Jesus  [was] glad  exceedingly· he was  for  of  a long  time  wishing  to see  Him  because of  -  hearing  concerning  Him, and  he was hoping  some  sign  to see  by  Him  done.
# Source: Anɛ ba ajɔl wɛ babɛ abong atɔgɛ arɛ, “Nteteba, wur ɛnyinyi arɛ wɔ ɔteba ɔfɛngɛ ɔbonga ji ɛrenɔ na nsɛrɛ, wɔ ɔnim jɔga ɔteba ɛkomanjim, ɔjɔga ɔteba mba yi Ɔsɔwɔ yi arenɔ ɛtete.
# Target: And  they questioned  Him  saying  Teacher, we know  that  rightly  You speak  and  teach  and  not  receive  [any] person, but  on the basis of  truth  the  way  -  of God  teach·
# Source: Naji arirɔ alagɛ Jɛrusɛlɛm na mfom yi mba ajɔlɔ ji ɛwɔng Ɔlif, batɔnanjim abɛ akuma njege Ɔsɔwɔ na ɛyɛbalitem na nyura lilom ateb akpɔga ɛsi a nsɔl kpakpa ya abɔ alɔ yɛn.
# Target: Drawing near  then  of Him  already  at  the  descent  of the  Mount  -  of Olives  began  all  the  multitude  of the  disciples  rejoicing  to praise  -  God  in a voice  loud  for  all  which  they had seen  [the] mighty works,
# Source: Wɛ abib arɛ, “Ba nsɔl yi?” Abɔ afanga arɛ, “Nsɔl yi ɛlemɔ Jisɔs yɔ Nasarɛt. Ajɔl nyɛna amir abɛl ɛkɔ na alom na nema na libri Ɔsɔwɔ na anɛ kpakpa.
# Target: And  He said  to them  What things; -  And  they said  to Him  The things  concerning  Jesus  of  Nazareth, who  was  a man  a prophet  mighty  in  deed  and  word  before  -  God  and  all  the  people,
# Source: Jisɔs abong atɔga abɔ, “Wun ɔlema mɔng wun ɔrenɔ ja na nbri anɛ, Ɔsɔwɔ anyinɔ ntem ɛyina. Nsɔl yi ɛloba anɛ na amir ɛream ɛjom ajiaji na libri Ɔsɔwɔ.
# Target: And  He said  to them  You  are  those  justifying  themselves  before  -  men, -  but  God  knows  the  hearts  of you· for  that which  among  men  [is] exalted  [is] an abomination  before  -  God.
# Source: “Nɛ awiawi yɔ alagɔ jɔl ntɔnanjim ɔma ateg atɛn ndɛ na nyɛn, nkal na abɔn, na abɔnyɛn abɛ ba lom na ba kal ɛjɔl likpen ɛlɛ. Anɔ arig wɛ anim ma jɔl ntɔnanjim ɔma.
# Target: If  anyone  comes  to  Me  and  not  hates  the  father  of himself  and  the  mother  and  the  wife  and  the  children  and  the  brothers  and  the  sisters, yes  and  even  the  life  of him, not  he is able  to be  of Me  disciple.
#
# Source:  “Abɔbat Ɔrɔja aba - Ɔsɔwɔ niyi aji abɔ. Ana yi je Ɔsɔwɔ kɔn ndɛ nyɛ arɛfɛl abɔ nyɛ ndɛ nɛmɛ Ɔsɔwɔ arɛ Ɔsɔwɔ niyi Ɔsɔwɔ ndɛ nyɛ yɛ ni yi.
# Target:  A son  [of] father -  God  [is] a [son] of a father. [But] a father  God  [is a] [son] of a father. A father  God  [is] a [son] of a father.

# %% [markdown]
# ## Use Alignment to improve utility of examples

# %%
alignment_prompt_template = f"""
Please give your best guess as to the optimal aligning of token ngrams \
(i.e., phrases—so don't get too caught up in having one token match one \
other token; rather, you should recognize that, e.g., 'Jisɔs yɔ Nasarɛt' \
likely aligns with 'Jesus of Nazareth', etc. ) in these two strings \
(which are a translation pair). Please attempt a semantic alignment, not \
simply paying attention to whitespace, but also reordering the English/target \
words wherever necessary to match the source text as best as possible, and \
you should take phonetic similarity into account for content words. That is, \
you can tell from the English which words are content words, so try to find \
matching content words such as proper nouns using phonetic similarities \
('Nasar-' sounds like 'Nazar-', for example):

Here's an example of a good alignment:
## Input:
Source: Wɛ abib arɛ, “Ba nsɔl yi?” Abɔ afanga arɛ, “Nsɔl yi ɛlemɔ Jisɔs yɔ Nasarɛt. Ajɔl nyɛna amir abɛl ɛkɔ na alom na nema na libri Ɔsɔwɔ na anɛ kpakpa.
Target: And  He said  to them  What things; -  And  they said  to Him  The things  concerning  Jesus  of  Nazareth, who  was  a man  a prophet  mighty  in  deed  and  word  before  -  God  and  all  the  people, 

## Alignment:
Source token(s)	Target token(s)	Notes
Wɛ abib arɛ,	And He said to them	Phrasal alignment. Likely a common way to say "He said to them"
“Ba nsɔl yi?”	What things;	Orthographic (question mark and quotations marks following a speech verb)
Abɔ afanga arɛ,	And they said to Him	Phrasal and phonological; to 'Wɛ abib arɛ' above
“Nsɔl yi ɛlemɔ Jisɔs yɔ Nasarɛt.	The things concerning Jesus of Nazareth,	Phonological matches; 'yɔ' seems to align with 'of'
Ajɔl nyɛna amir abɛl	who was a man a prophet mighty	Semantic; 'abɛl' ~ 'mighty/able'
ɛkɔ na alom na nema na libri	in deed and word before	Semantic; 'na' seems to be a correlative connective
Ɔsɔwɔ na anɛ kpakpa.	God and all the people,	Semantic; 'na' ~ 'and', 'anɛ' ~ 'all', 'Ɔsɔwɔ' ~ 'God', 'kpakpa' ~ 'people'

Here are some example translation pairs for additional context to aid you in pattern matching:
{examples}

```
For example, I would expect that 'Nasarɛt' aligns with 'Nazareth', and 'libri' aligns with 'word'. Please format the output as a markdown table (| Source token | Target token | Notes [concise comments or notes or rationale as to why you aligned these tokens] |).
# Out:
#   Cell In[1], line 1
#     alignment_prompt_template = f"""
#                                 ^
# SyntaxError: incomplete input
