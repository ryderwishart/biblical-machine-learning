# %%
import os
import numpy as np
from scipy.special import softmax
from scipy.spatial.distance import cdist
from sklearn.cluster import DBSCAN
from collections import defaultdict
from gensim.models import FastText
import random

# Set up constants
model_path = "/Users/ryderwishart/w2v/ancient-greek-word2vec/models/ft_papyri&corpus_cbow_hs_2_to_5_size300_window5_mincount2.model"
lemmas_path = "/Users/ryderwishart/biblical-machine-learning/data/lemmas"
texts_path = "/Users/ryderwishart/biblical-machine-learning/data/texts"
eps = 0.5
base_min_samples = 2
scaling_factor = 0.1
num_examples = 3
num_lexemes = 10

# %%
# Load FastText model
model = FastText.load(model_path)

# %%
class MySentences(object):
    def __init__(self, lemmas_path, texts_path):
        self.lemmas_path = lemmas_path
        self.texts_path = texts_path
        self.lemmas_files = self._get_txt_files(self.lemmas_path)
        self.texts_files = self._get_txt_files(self.texts_path)

    def __iter__(self):
        for lemmas_file, texts_file in zip(self.lemmas_files, self.texts_files):
            with open(lemmas_file, 'r', encoding='utf-8') as lemmas_f, open(texts_file, 'r', encoding='utf-8') as texts_f:
                for lemmas_line, texts_line in zip(lemmas_f, texts_f):
                    lemmas = lemmas_line.rstrip().split()
                    yield lemmas

    def _get_txt_files(self, path):
        txt_files = []
        for file in os.listdir(path):
            if file.endswith(".txt"):
                txt_files.append(os.path.join(path, file))
        return txt_files

    def get_sentence_by_index(self, index):
        i = 0
        for lemmas_file, texts_file in zip(self.lemmas_files, self.texts_files):
            with open(lemmas_file, 'r', encoding='utf-8') as lemmas_f, open(texts_file, 'r', encoding='utf-8') as texts_f:
                for line_number, (lemmas_line, texts_line) in enumerate(zip(lemmas_f, texts_f)):
                    lemmas = lemmas_line.rstrip().split()
                    texts = texts_line.rstrip().split()
                    if i == index:
                        if len(lemmas) != len(texts):
                            texts.append('[LENGTH_MISMATCH]')
                        return lemmas
                    i += 1

# Instantiate corpus reader
corpus = MySentences(lemmas_path, texts_path)

# Function to read and preprocess the corpus
# def preprocess_corpus(corpus_path):
#     with open(corpus_path, 'r', encoding='utf-8') as f:
#         lines = f.read().splitlines()
#         sentences = [line.split() for line in lines]
#         return sentences

# corpus = preprocess_corpus(corpus_path)

# Select random lexemes
N = 100  # or some other reasonable number
sentences = [sentence for _, sentence in zip(range(N), corpus)]
unique_lexemes = list(set([token for sentence in sentences for token in sentence]))
random_lexemes = random.sample(unique_lexemes, num_lexemes)

# %%
# Function to get word embeddings
def get_word_embedding(token, model):
    if token in model.wv:
        return model.wv[token]
    else:
        return np.zeros(model.vector_size)

# Function to calculate contextual vectors
def calculate_contextual_vectors(sentence, model, window_size=5):
    contextual_vectors = []
    for i, token in enumerate(sentence):
        token_embedding = get_word_embedding(token, model)
        contextual_vector = np.zeros(model.vector_size)
        for j in range(max(0, i - window_size), min(len(sentence), i + window_size + 1)):
            if j != i:
                neighbor_token = sentence[j]
                neighbor_embedding = get_word_embedding(neighbor_token, model)
                if neighbor_token != "[PAD]":
                    distance = cdist(token_embedding.reshape(1, -1), neighbor_embedding.reshape(1, -1), metric='cosine')
                    attention_score = softmax(-distance)
                    contextual_vector += attention_score.reshape(-1) * neighbor_embedding
        contextual_vector = contextual_vector / np.linalg.norm(contextual_vector)
        contextual_vectors.append(contextual_vector)
    return np.array(contextual_vectors)

token_context_vectors = defaultdict(list)
for sentence_idx, sentence in enumerate(corpus):
    if any(lexeme in sentence for lexeme in random_lexemes):
        contextual_vectors = calculate_contextual_vectors(sentence, model)
        for token_idx, (token, context_vector) in enumerate(zip(sentence, contextual_vectors)):
            if token in random_lexemes:
                token_context_vectors[token].append((context_vector, sentence_idx, token_idx))


def calculate_clusters_and_generalized_vectors(corpus, lexemes):
    token_context_vectors = defaultdict(list)
    for sentence_idx, sentence in enumerate(corpus):
        if any(lexeme in sentence for lexeme in lexemes):
            contextual_vectors = calculate_contextual_vectors(sentence, model)
            for token_idx, (token, context_vector) in enumerate(zip(sentence, contextual_vectors)):
                if token in lexemes:
                    token_context_vectors[token].append((context_vector, sentence_idx, token_idx))

    token_clusters = {}
    for token, context_vector_data in token_context_vectors.items():
        context_vectors = [data[0] for data in context_vector_data]

        # Filter out context vectors containing NaN values
        context_vectors = [vec for vec in context_vectors if not np.isnan(vec).any()]
        
        if len(context_vectors) == 0:
            continue
            
        token_frequency = len(context_vector_data)
        min_samples_scaled = int(base_min_samples + (scaling_factor * (token_frequency ** 0.5)))
        clustering = DBSCAN(eps=eps, min_samples=min_samples_scaled).fit(context_vectors)
        token_clusters[token] = clustering.labels_

    token_generalized_vectors = {}
    for token, context_vector_data in token_context_vectors.items():
        context_vectors = [data[0] for data in context_vector_data]
        if token not in token_clusters:
            token_generalized_vectors[token] = context_vectors
            continue

        labels = token_clusters[token]
        num_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        generalized_vectors = []
        for cluster_idx in range(num_clusters):
            cluster_vectors = [vec for vec, label in zip(context_vectors, labels) if label == cluster_idx]
            centroid = np.mean(cluster_vectors, axis=0)
            generalized_vectors.append(centroid)
        token_generalized_vectors[token] = generalized_vectors
    return token_clusters, token_generalized_vectors

token_clusters, token_generalized_vectors = calculate_clusters_and_generalized_vectors(corpus, random_lexemes)

# Function to select example sentences
def select_example_sentences(corpus, lexemes, token_clusters, token_generalized_vectors, token_context_vectors):
    token_examples = defaultdict(lambda: defaultdict(list))
    for token, context_vector_data in token_context_vectors.items():
        context_vectors = [data[0] for data in context_vector_data]
        if token not in token_clusters:
            for context_vector, vector_data in zip(context_vectors, context_vector_data):
                sentence_idx, token_idx = vector_data[1:]
                token_examples[token][-1].append((0, sentence_idx, token_idx))
            token_examples[token][-1] = token_examples[token][-1][:num_examples]
            continue

        labels = token_clusters[token]
        generalized_vectors = token_generalized_vectors[token]
        for context_vector, label, vector_data in zip(context_vectors, labels, context_vector_data):
            sentence_idx, token_idx = vector_data[1:]
            if label != -1:
                centroid = generalized_vectors[label]
                distance = cdist(context_vector.reshape(1, -1), centroid.reshape(1, -1), metric='cosine')
                token_examples[token][label].append((distance, sentence_idx, token_idx))
                token_examples[token][label].sort(key=lambda x: x[0])
                token_examples[token][label] = token_examples[token][label][:num_examples]
    return token_examples

token_examples = select_example_sentences(corpus, random_lexemes, token_clusters, token_generalized_vectors, token_context_vectors)
# Out:
# /var/folders/hz/6rspy0v17q7b21wllgrjbn040000gn/T/ipykernel_4063/1173814057.py:22: RuntimeWarning: invalid value encountered in divide
#   contextual_vector = contextual_vector / np.linalg.norm(contextual_vector)

# %%
# Display output
for token, context_examples in token_examples.items():
    number_of_clusters_for_token = len(context_examples)
    print(f"{token} ({number_of_clusters_for_token} cluster/s):")
    for context_label, examples in context_examples.items():
        print(f"\tgeneralized_context_vector_{context_label}:")
        for example in examples:
            distance, sentence_idx, token_idx = example
            sentence = corpus.get_sentence_by_index(sentence_idx)
            print(
                f"\t\tExample sentence {sentence_idx} including '{token}' in typical context {context_label}:")
            print(f"\t\t\tTokens: {' '.join(sentence)}")
        print("\t...")
    print("\n")
# Out:
# φθάνω (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 124346 including 'φθάνω' in typical context 0:
# 			Tokens: ὁ φθάνω
# 		Example sentence 270841 including 'φθάνω' in typical context 0:
# 			Tokens: ὁ γάρ ἀχαριστέω ὁ φθάνω καί ὁ ἀπό ὁ αὖθις ἀκούω ἔχω κατάγνωσις
# 		Example sentence 35202 including 'φθάνω' in typical context 0:
# 			Tokens: οὐ οἶδα ὅτι2 πρός ὁ πρέσβυς βλέπω ὁ δεύτερος κρίνω ἄνθρωπος καί διδαχή γίγνομαι ὁ ὁ φθάνω
# 	...
#
#
# μέγας (3 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 8 including 'μέγας' in typical context 0:
# 			Tokens: ἐπεί γάρ ὁ ἐλπίς αὐτός καί οὐ ἀφίημι πρός ὁ πάρειμι καί καθά ἄγκυρα ἀποκόπτω ὁ διάβολος ἐπεί οὐ ἰσχύω ὅτι2 ψευδής ὁ μέλλω ἕτερος ἔρχομαι ὁδός καί ἄνθρωπος λυμεών ἐπιχειρέω ὁ μένος ὅτι2 ὁ μέγας ἐκεῖνος ὁ πέρας
# 		Example sentence 63 including 'μέγας' in typical context 0:
# 			Tokens: μέγας μέν οὖν καί ὁ καί ὑπό ὁ λογισμός μή παραφέρω
# 		Example sentence 91 including 'μέγας' in typical context 0:
# 			Tokens: ἀλλά ὁράω διά ὁ ἑξῆς πῶς δείκνυμι σφοδρός εἰμί καί ὁ ἄνεσις πολύς μέγας
# 	...
# 	generalized_context_vector_1:
# 		Example sentence 101169 including 'μέγας' in typical context 1:
# 			Tokens: ὅτι2 δέ καί ὁ ὁ τιμωρία εἰς οὐδείς μέγας ὁ ὦ ἀνήρ ὅσος καί ὅπως ὁ ἐξαμαρτάνω ὁ νομοθέτης
# 		Example sentence 34253 including 'μέγας' in typical context 1:
# 			Tokens: κτύπος δέω ὁ ὦ δαιμόνιος μέγας ὅς ὁ τε ὁ χορός πρός ὁ χρεία καί ὁ εἰς εὐρυθμία
# 		Example sentence 85599 including 'μέγας' in typical context 1:
# 			Tokens: πολύς τοίνυν γε καί ἡμέρα ὁ ἀπόκρισις ἐπεί μᾶλλον ἐκκαίω αὐτός πρός ὁ δέησις γίγνομαι πρῶτος μέν αὐτός ἐξορκίζω καταγορεύω ὁ τέχνη ἔπειτα συνάγω ὁ ὀφρῦς καί τρίβω ὁ χείρ ὁ μέγας φημί ὁ πρᾶγμα ὦ γυνή μέγας ἐπίνοια κατορθόω
# 	...
# 	generalized_context_vector_2:
# 		Example sentence 13865 including 'μέγας' in typical context 2:
# 			Tokens: εἰμί οὔτε ὁ μέγας ἵππος γάρ ἄνθρωπος οὔτε ὁ μικρός γάρ ὁ πολύς ὁ οὔτε ὁ φυτόν ὅλος ὁ ζῷον γάρ ἔνιοι ὁ φυτόν οὔτε ὁ ἔναιμος γάρ πολυχρόνιος ἔνιοι ἔναιμος οὔτε ὁ ἄναιμος ὁ γάρ ἐπέτειος μέν ἄναιμος δέ οὔτε ὁ ἐν ὁ γῆ καί γάρ εἰμί καί ζῷον πεζός οὔτε ὁ ἐν ὁ θάλασσα
# 		Example sentence 34843 including 'μέγας' in typical context 2:
# 			Tokens: πᾶς ὁ πολεμέω πρός μέν ἀλλήλων ἔγκλημα ἔχω καί διαφορά ὁ μέν ἐπί μικρός ὁ ἐπί μέγας ὁ δέ οὔτε μικρός οὔτε μέγας ἔχω
# 		Example sentence 33765 including 'μέγας' in typical context 2:
# 			Tokens: ὁ δέ ὁ συνοικέω οὔτε μικρός οὔτε μέγας ὁ ἔνδον οὔτε ἀδικέω φιλία θεραπεύω δεύτερος
# 	...
#
#
# ἰσχύω (5 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 309991 including 'ἰσχύω' in typical context 0:
# 			Tokens: εἰ μέν τοίνυν οὐ παραπλήσιος ἔνειμι ὁ θεός τυγχάνω οὐδέ τοιοῦτος ὁποῖος ἐάν ἐγώ αὐτός παρέχω ἀλλά εἰμί μέν ἀδικέω ὁ ἐκεῖνος πρόνοια εἰμί δέ ὁ δίκαιος προαιρέω ἀμείνων ὁ πονηρός πράσσω καθαιρετέος μέν ἀμελέω δέ παροράω δέ πανήγυρις ἐν δέ μέρος ὁ θεῖον ἔχω τε νομίζω καί εἰκῇ φέρω ὁ καί ὁ ἰσχύω ὁ δέ ὁ τάξις εἰμί ὁ κέρδος ὁ οὕτως ζήω ἐθέλω
# 		Example sentence 80200 including 'ἰσχύω' in typical context 0:
# 			Tokens: καί ὁ μέν σοφιστής ὁ περί ὁ στάσις αὐτός τε βασιλεύς καί ὁ γερουσία λόγος λέγω ἰσχύω ὁ βασιλεύς μεθίστημι ὁ κατά Ἀντιοχεύς ὀργή ὥστε ἀμέλει οὗτος καί ὁ περί ὁ ἐπιτίθημι τέλειος ὁ βασιλεύς ὁ πρός ὁ πόλις ἔχθος
# 		Example sentence 38171 including 'ἰσχύω' in typical context 0:
# 			Tokens: ὁ μέν γάρ οὐ ὁ κέντημα ὁ καταφορά ἰσχύω πρός ὁ βλάπτω ὁ δέ Γαλατικός μάχαιρα ἔχω χρεία ὁ ἐκ καταφορά καί οὗτος ἐκ ἀπόστασις
# 	...
# 	generalized_context_vector_1:
# 		Example sentence 4137 including 'ἰσχύω' in typical context 1:
# 			Tokens: ἐάν μυριάκις αὐτός σοφός εἰμί λόγος ἔτι ἐν αὐτός ἐπεί πληρόω ὁ κύριος2 ἀπό ὁ ἀπό ὁ ἰσχύω καί ἰσχύω καί ἰσχύω καί ἄνθρωπος πολεμιστής καί δικαστής καί προφήτης καί καί πρέσβυς καί πεντηκόνταρχος καί θαυμαστός σύμβουλος καί σοφός ἀρχιτέκτων καί
# 		Example sentence 4137 including 'ἰσχύω' in typical context 1:
# 			Tokens: ἐάν μυριάκις αὐτός σοφός εἰμί λόγος ἔτι ἐν αὐτός ἐπεί πληρόω ὁ κύριος2 ἀπό ὁ ἀπό ὁ ἰσχύω καί ἰσχύω καί ἰσχύω καί ἄνθρωπος πολεμιστής καί δικαστής καί προφήτης καί καί πρέσβυς καί πεντηκόνταρχος καί θαυμαστός σύμβουλος καί σοφός ἀρχιτέκτων καί
# 		Example sentence 160042 including 'ἰσχύω' in typical context 1:
# 			Tokens: δή ὁ δεσπότης κύριος2 ἀπό ὁ Ἰουδαία καί ἀπό ἰσχύω καί ἰσχύω ἰσχύς ἄρτος καί ἰσχύς ὕδωρ καί ἰσχύω καί ἄνθρωπος πολεμιστής καί δικαστής καί προφήτης καί καί πρέσβυς καί πεντηκόνταρχος καί θαυμαστός σύμβουλος καί σοφός ἀρχιτέκτων καί
# 	...
# 	generalized_context_vector_2:
# 		Example sentence 258809 including 'ἰσχύω' in typical context 2:
# 			Tokens: καί ἀκούω ὁ Ἰησοῦς λέγω αὐτός ὅτι2 οὐ χρεία ἔχω ὁ ἰσχύω ἰατρός ὁ κακός ἔχω
# 		Example sentence 49595 including 'ἰσχύω' in typical context 2:
# 			Tokens: ὁ δέ ἀκούω λέγω οὐ χρεία ἔχω ὁ ἰσχύω ἰατρός ἀλλά ὁ κακός ἔχω
# 		Example sentence 308402 including 'ἰσχύω' in typical context 2:
# 			Tokens: οὐ χρεία φημί ἔχω ὁ ἰσχύω ἰατρός ἀλλά ὁ κακός
# 	...
# 	generalized_context_vector_3:
# 		Example sentence 189585 including 'ἰσχύω' in typical context 3:
# 			Tokens: ἄλλος τε ὁ ὑγιαίνω φύσις ἔχω μήτε παντάπασι ἀσθενής αὖ ἰσχυρός ἐσθίω τις ὅς βοῦς ἤ ἵππος ἐσθίω τε καί ἰσχύω ὄροβος τίη ἤ ἄλλος τις ὁ μή πολύς ἀλλά πολύς τίη δύναμαι
# 		Example sentence 186108 including 'ἰσχύω' in typical context 3:
# 			Tokens: ὡς γάρ ἐπί ἐκεῖνος οὐ ἀεί ὅμοιος δέω καί ἐν χρεία ὁ ἀλλότριος εἰμί οὕτως οὐδέ ὁ νόμισμα ἀεί ἴσος δύναμαι ἀλλά μεταπίπτω καί ὁ πρότερος πλέως ὕστερον τίη οὐδείς ἤ ἰσχύω
# 		Example sentence 265554 including 'ἰσχύω' in typical context 3:
# 			Tokens: ἐν γάρ ὁ ὁ καί τῷ βίος τῷ καθά ἡμέρα καί ὁ ἐπιτήδευμα ἐάν παρά αὐτός ὁ ἰσότης καί ὁ ὁμοιότης μᾶλλον ἤ παρά ὁ ἄλλος ἰσχύω
# 	...
# 	generalized_context_vector_4:
# 		Example sentence 264558 including 'ἰσχύω' in typical context 4:
# 			Tokens: ὁ δέ ἰσχύω ἐπί ὁ γῆ
# 		Example sentence 262986 including 'ἰσχύω' in typical context 4:
# 			Tokens: καί καταβαίνω παροικέω ἐκεῖ ὅτι2 ἰσχύω ὁ ἐπί ὁ γῆ
# 		Example sentence 232653 including 'ἰσχύω' in typical context 4:
# 			Tokens: ὁράω δέ που ὁ μέν καί βλέπω εἰς ὁ γῆ αὐτός ὁ δέ Ἡρακλέης ἰσχύω καί μειδάω ὁ ἔργον
# 	...
#
#
# Παῦλος (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 121587 including 'Παῦλος' in typical context 0:
# 			Tokens: ὁ μέν οἷος ὁ καί ὁ ὁ δέ οἷος ὁ Παῦλος καί ὁ πιστεύω
# 		Example sentence 298337 including 'Παῦλος' in typical context 0:
# 			Tokens: καί ὁ Παῦλος δέ φημί πρός ὁ ὁ κακία
# 		Example sentence 16088 including 'Παῦλος' in typical context 0:
# 			Tokens: γάρ διά ὁ πάτριος γλῶσσα ὁ Παῦλος ὁ μέν ὁ ὁ δέ ὁ οὗτος αὐτός ἑρμηνεύω λέγω ὁ γραφή
# 	...
#
#
# δέω (7 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 178121 including 'δέω' in typical context 0:
# 			Tokens: εἰμί δέ οὗτος ὁ ὁ μόνος δέω ὁ πτισάνη δέ καί ὁ πτισάνη ἔνιοι δέ οὗτος ἐπί μόνος ἄχρι ὁ κρίσις ὠφέλιμος διαφυλάσσω
# 		Example sentence 144502 including 'δέω' in typical context 0:
# 			Tokens: στοχάζομαι δέ δέω ὁ τοιοῦτος πρός ὁ ὁ καί ὁ ὁ μείγνυμι αὐτός χροιά καί ὁ τρόπος ὁ ἕψησις ἐπί μέν ὁ μείγνυμι ὁ ὁπόσος ὁ ξανθός εἰμί καί καί μέλας φάρμακον
# 		Example sentence 23805 including 'δέω' in typical context 0:
# 			Tokens: ὁ δέ σύμπας γιγνώσκω δέω ὁ ἐναντίος ὁ καθίστημι καί νόσημα καί εἶδος καί ὥρα2 καί ἡλικία καί ὁ λύω καί ὁ λύω
# 	...
# 	generalized_context_vector_1:
# 		Example sentence 265436 including 'δέω' in typical context 1:
# 			Tokens: τε ὁ μέν παλαιός ἐκ καί ταπεινός πόλις ὁρμάω διά ὁ σώφρων ζήω καί στρατιωτικός κατέχω Πελοπόννησος μετά δέ οὗτος μέγας φρονέω ὁ δέω καί λαμβάνω καί ὁ κατά γῆ καί ὁ κατά θάλασσα ἀρχή εἰς ὁ αὐτός κίνδυνος καθίστημι
# 		Example sentence 53019 including 'δέω' in typical context 1:
# 			Tokens: οἷος εἰμί μέν ὁ μόνος ὁ δέω εἰμί δέ ὁ καί ὁ δέω καί ἄλλος πρός οὗτος οἷος ὁ θέσις πρός ὁ φαίνω ἐκεῖνος ὅς εἰμί μέν ἀναγκαῖος διά ὁ μένω ὅρος ὅς οὐ ἔξωθεν ὅρος προσδέω2 πρός ὁ συμβαίνω ἀλλά διά ὁ μέν ὅρος συμβαίνω οὐ μήν σαφής λαμβάνω διά πρότασις
# 		Example sentence 6255 including 'δέω' in typical context 1:
# 			Tokens: ὁ μέν γάρ ἀπορέω2 πότερος δέω ὁ τιμάω καί ὁ γονεύς ἀγαπάω ἤ οὐ κόλασις δέω ὁ δέ πότερος ὁ χιών λευκός ἤ οὐ αἴσθησις
# 	...
# 	generalized_context_vector_6:
# 		Example sentence 18225 including 'δέω' in typical context 6:
# 			Tokens: ὁ ἀπόστολος διαδοχή ἐν ὅλος περιγράφω βιβλίον ἐν ὄγδοος οὗτος σύγγραμμα ὁ κατά ἐγώ αὐτός οὐ ὁ τυγχάνω ἄξιος ὄντα ὁ δέω εἰς γνῶσις καί ὁ μετά ἐγώ παραδίδωμι καί γε ὁ λόγος ἐντεῦθεν
# 		Example sentence 74810 including 'δέω' in typical context 6:
# 			Tokens: διά οὗτος ἐπί μέν ὁ δίδωμι καί ζητέω ἐπεί οὗτος δέω ὁ τι σημαίνω ὁ
# 		Example sentence 280387 including 'δέω' in typical context 6:
# 			Tokens: εἰ δέ οὗτος μέν οὐ ποιέω ἐχθρός δέ ἀφία ῥῆμα καί ὁ ὁ ἑταίρα αὐτός οὐ δέω ὁ κιβώτιον
# 	...
# 	generalized_context_vector_2:
# 		Example sentence 267757 including 'δέω' in typical context 2:
# 			Tokens: πᾶς βλάβη καί οὐ δέχομαι ὁ ὁ ἑαυτοῦ οὕτως δέω δέ καί ἐγώ νῦν ὑπό σός φαίνω εἰς οὗτος
# 		Example sentence 49959 including 'δέω' in typical context 2:
# 			Tokens: κάτω δέ μᾶλλον ὁ ἀφαίρεσις ποιέω δέω καί πολλάκις ὑπολείπω ὁ νόσος συμβαίνω
# 		Example sentence 85287 including 'δέω' in typical context 2:
# 			Tokens: δέω δέ ἐνταῦθα γίγνομαι νόμιμος ὁ
# 	...
# 	generalized_context_vector_3:
# 		Example sentence 140608 including 'δέω' in typical context 3:
# 			Tokens: ὅς δέω δείκνυμι
# 		Example sentence 276432 including 'δέω' in typical context 3:
# 			Tokens: ὅς δέω δείκνυμι
# 		Example sentence 276451 including 'δέω' in typical context 3:
# 			Tokens: ὅς δέω δείκνυμι
# 	...
# 	generalized_context_vector_4:
# 		Example sentence 181007 including 'δέω' in typical context 4:
# 			Tokens: ὁ γάρ οἷος δέω ὁ πλεονάζω εἰμί ὁ λυπέω κατά ποιότης ὁ κάμνω διά οὖν συμφέρω φημί ὁ τοιοῦτος κένωσις
# 		Example sentence 179648 including 'δέω' in typical context 4:
# 			Tokens: κίνδυνος γάρ οὐ μικρός ἐν ὀξύς2 νόσημα κακός φαρμακεύω τῷ πᾶς μέν ὁ καθαίρω φάρμακον θερμός ὁ δύναμις εἰμί δέω δέ ὁ ὅς εἰμί κατά ὁ ἑαυτοῦ λόγος οὐ ὅπως ὁ καί ξηραίνω ἀλλά ὁ ἐναντίος αὐτός ὁ τε καί
# 		Example sentence 196194 including 'δέω' in typical context 4:
# 			Tokens: ἵνα μέν γάρ ὁ ῥύσις δέω προκαταλαμβάνω ὁ
# 	...
# 	generalized_context_vector_5:
# 		Example sentence 267502 including 'δέω' in typical context 5:
# 			Tokens: δέω γάρ αὐτός ἀποδείκνυμι ὡς οὐ καταμηνύω ὁ ἀνήρ οὗτος αἴτιος αὐτός εἰμί ὁ θάνατος ὅς οὐ ἄν δύναμαι οὐδέποτε ἀποδείκνυμι
# 		Example sentence 298809 including 'δέω' in typical context 5:
# 			Tokens: γάρ ἄνω2 καί κάτω λέγω ὁ γραφή ὅτι2 δέω προσέχω δέ οὐ ἐγώ εὔδηλος ὅτι2 καί ὁ λόγος αὐτός ἀφίστημι ἀπό ὑμός
# 		Example sentence 160345 including 'δέω' in typical context 5:
# 			Tokens: ἐν μέν ὁ πρῶτος ἡμέρα οὐ δέω ἀποδημέω
# 	...
#
#
# ἐφέζομαι (3 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 14837 including 'ἐφέζομαι' in typical context 0:
# 			Tokens: καί ἐφέζομαι ἐπί πρόσωπον ἐπί ὁ γῆ καί λέγω αὐτός δεσπότης τι προστάσσω ὁ σός οἰκέτης
# 		Example sentence 19470 including 'ἐφέζομαι' in typical context 0:
# 			Tokens: καί ἐφέζομαι ἐπί πρόσωπον ἐπί ὁ γῆ καί λέγω αὐτός δεσπότης τι προστάσσω τῷ οἰκέτης
# 		Example sentence 266064 including 'ἐφέζομαι' in typical context 0:
# 			Tokens: καί ἐφέζομαι ἐπί πρόσωπον ἐπί ὁ γῆ καί λέγω αὐτός δεσπότης τι προστάσσω σός οἰκέτης
# 	...
# 	generalized_context_vector_1:
# 		Example sentence 82356 including 'ἐφέζομαι' in typical context 1:
# 			Tokens: καί καί ἐφέζομαι ἐπί πρόσωπον αὐτός καί ὁ πνεῦμα καί πᾶς σάρξ εἰ ἄνθρωπος ἁμαρτάνω ἐπί πᾶς ὁ συναγωγή ὀργή
# 		Example sentence 305031 including 'ἐφέζομαι' in typical context 1:
# 			Tokens: καί ἐφέζομαι ἐπί πρόσωπον αὐτός ἐνώπιος ὁ βασιλεύς αὐτός ὁ Ἰορδάνης καί λέγω πρός ὁ βασιλεύς μή ὁ κύριος2 καί μή μιμνήσκω ὅσος ὁ ἐν ὁ ἡμέρα ὅς ὁ κύριος2 ἐκπορεύω ἐκ ὁ τίθημι ὁ βασιλεύς εἰς ὁ καρδία αὐτός
# 		Example sentence 304735 including 'ἐφέζομαι' in typical context 1:
# 			Tokens: καί εἰσέρχομαι ὁ γυνή ὁ πρός ὁ βασιλεύς καί ἐφέζομαι ἐπί πρόσωπον αὐτός εἰς ὁ γῆ καί προσκυνέω αὐτός καί λέγω βασιλεύς σῴζω
# 	...
# 	generalized_context_vector_2:
# 		Example sentence 280059 including 'ἐφέζομαι' in typical context 2:
# 			Tokens: φήμη δέ ὡς ἐκτείνω πᾶς ὁ ὁ βασιλεύς υἱός ὁ διαρρήγνυμι ὁ ἐσθής αὐτός ὁ καί ἐφέζομαι ἐπί ὁ γῆ θρηνέω
# 		Example sentence 258869 including 'ἐφέζομαι' in typical context 2:
# 			Tokens: καί ἐφέζομαι εἰς ὁ γῆ ὁ καλός καί δίδωμι καρπός ἀναβαίνω καί αὐξάνω καί φέρω εἰς καί ἐν καί ἐν
# 		Example sentence 49802 including 'ἐφέζομαι' in typical context 2:
# 			Tokens: ἄλλος δέ ἐφέζομαι ἐπί ὁ γῆ ὁ καλός καί δίδωμι καρπός ὁ μέν ὁ δέ ἑξήκοντα ὁ δέ
# 	...
#
#
# ἔνδοξος (3 cluster/s):
# 	generalized_context_vector_1:
# 		Example sentence 148501 including 'ἔνδοξος' in typical context 1:
# 			Tokens: ὁ ὁ εἰμί καί ἔνδοξος
# 		Example sentence 144841 including 'ἔνδοξος' in typical context 1:
# 			Tokens: εἰμί δέ καλός παρά ἐγώ ἐν Ἀσία ὁ τε καλέω καί ὁ καί ὁ ἔνδοξος παρά ὁ ὁ ἐν ὅς πᾶς χράω2 πρός ὁ ὁ φάρμακον καί μάλιστα ὁ ὥσπερ νῦν ὁ
# 		Example sentence 160274 including 'ἔνδοξος' in typical context 1:
# 			Tokens: γάρ ὁ δεσπότης κύριος2 ὁ ἔνδοξος μετά ἰσχύς καί ὁ ὁ ὕβρις καί ὁ πίπτω μάχαιρα ὁ δέ Λίβανος σύν ὁ πίπτω
# 	...
# 	generalized_context_vector_0:
# 		Example sentence 8655 including 'ἔνδοξος' in typical context 0:
# 			Tokens: ἀνάγκη δή ὁ ἀποκρίνω ὑπέχω λόγος ἤτοι ἔνδοξος ἤ ἄδοξος θέσις ἤ καί ἤτοι ἁπλόος τίη τίη ὁρίζω οἷος τίη αὐτός τίη ἄλλος
# 		Example sentence 8677 including 'ἔνδοξος' in typical context 0:
# 			Tokens: ἀνάγκη πᾶς ὁ ἐρωτάω τίη ἔνδοξος εἰμί τίη τίη καί ἤ πρός ὁ λόγος τίη μή πρός ὁ λόγος εἰμί ὁ ἐρωτάω ἐάν μέν εἰμί δοκέω καί μή πρός ὁ λόγος δίδωμι φημί δοκέω ἐάν δέ μή δοκέω καί μή πρός ὁ λόγος δίδωμι μέν δέ ὁ μή δοκέω πρός εὐλάβεια εὐήθεια
# 		Example sentence 6078 including 'ἔνδοξος' in typical context 0:
# 			Tokens: δέ ὁ δοκέω πᾶς τίη ὁ πλεῖστος ἤ ὁ καί οὗτος τίη τίη ὁ πλεῖστος ἤ ὁ μάλιστα καί ἔνδοξος
# 	...
# 	generalized_context_vector_2:
# 		Example sentence 216477 including 'ἔνδοξος' in typical context 2:
# 			Tokens: οὐ γάρ διά ἰατρικός ἀρχός ὁ διαλεκτικός ὁ κατά ὁ ἰατρικός τις δείκνυμι ἰατρός γάρ οὗτος οὐδέ διά ὁ γεωμετρικός εἰμί γάρ ἀνά ἀλλά εἰμί ἴδιος αὐτός ὁ περί πᾶς ὁ προτίθημι διά ἔνδοξος συλλογίζομαι
# 		Example sentence 216460 including 'ἔνδοξος' in typical context 2:
# 			Tokens: φέρω δέ ὁ ὁ διαλεκτικός ὄνομα ἐπί ὁ οὕτως καί διά τοιοῦτος μέθοδος ἀκόλουθος ὁρίζω αὐτός μέθοδος διά ἔνδοξος περί πᾶς ὁ
# 		Example sentence 216503 including 'ἔνδοξος' in typical context 2:
# 			Tokens: δέ ὁ οὕτως λέγω διαλεκτικός μέν καί ἐν ἄλλος πραγματεύομαι μάλιστα δέ ἐν οὗτος ὅς ἐπιγράφω τοπικός ἀπό ὁ τόπος ἐν αὐτός παραδίδωμι ἀπό ὅς ὁρμάω δύναμαι περί πᾶς ὁ προτίθημι διά ἔνδοξος συλλογίζομαι ὡς φημί αὐτός
# 	...
#
#
# οἶδα (4 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 1019 including 'οἶδα' in typical context 0:
# 			Tokens: ὁ μάρτυς ὁ ὁ καρδία οἶδα καί ὁ διαλογισμός
# 		Example sentence 2305 including 'οἶδα' in typical context 0:
# 			Tokens: καί οἶδα ὅτι2 ὁ μέν πολύς αὐτός συνᾴδω καί δύναμαι ἀναφέρω ἐπί ὁ σωτήρ ὅς παραθέω
# 		Example sentence 2372 including 'οἶδα' in typical context 0:
# 			Tokens: δείκνυμι ὅτι2 οὐ οἶδα ὁ ἁμαρτωλός ὅτι2 οὐ οἶδα ὁ ὁ ἀνομία
# 	...
# 	generalized_context_vector_2:
# 		Example sentence 2372 including 'οἶδα' in typical context 2:
# 			Tokens: δείκνυμι ὅτι2 οὐ οἶδα ὁ ἁμαρτωλός ὅτι2 οὐ οἶδα ὁ ὁ ἀνομία
# 		Example sentence 21334 including 'οἶδα' in typical context 2:
# 			Tokens: οὗτος μέντοι θεά εἰμί οὐ οἶδα οὐδέ νομίζω
# 		Example sentence 21336 including 'οἶδα' in typical context 2:
# 			Tokens: οὐ γάρ μά οἶδα πλεῖστος οὗτος βόσκω ἰατροτέχνης σφραγιδονυχαργοκομήτης τε χορός ᾀσματοκάμπτης ἀνήρ μετεωροφέναξ δράω ἀργός ὅτι2 οὗτος
# 	...
# 	generalized_context_vector_1:
# 		Example sentence 140964 including 'οἶδα' in typical context 1:
# 			Tokens: ὁ δέ καί ὁ οὗτος ὕπουλος οἶδα καί ὁ ἐκεῖνος πονηρία καί οὗτος χάρις οὐ ὁ αἴτησις
# 		Example sentence 260314 including 'οἶδα' in typical context 1:
# 			Tokens: ὁ γάρ αὐτός εἰμί ὁ οἶδα ὁ νόσος ὁ καί ὁ θεραπεύω αὐτός ἐφίστημι πᾶς ὁ κωλύω ὁ νόσημα μεγαλύνω
# 		Example sentence 138224 including 'οἶδα' in typical context 1:
# 			Tokens: σύνολος γάρ οἶδα χρή ὅτι2 ὁ πρός ὁ καί ἀφίημι ἐν αἰτία καί ἔγκλημα μέγας γίγνομαι
# 	...
# 	generalized_context_vector_3:
# 		Example sentence 173314 including 'οἶδα' in typical context 3:
# 			Tokens: ὁ δέ ὄνομα οὐ οἶδα ὁ μειράκιον
# 		Example sentence 300769 including 'οἶδα' in typical context 3:
# 			Tokens: ὁ δέ ὅς ποιέω σύ οὐ οἶδα ἄρτι ὁ ἐκ ὁ νίζω σημαίνω ὠφέλεια εἰμί εἰς πᾶς ἄγω ταπεινοφροσύνη σύ
# 		Example sentence 128817 including 'οἶδα' in typical context 3:
# 			Tokens: καί οὗτος οἶδα ὁ
# 	...
#
#
# ἐνταῦθα (3 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 229 including 'ἐνταῦθα' in typical context 0:
# 			Tokens: ὅτι2 ὁ καλέω ὁ ἐν τε ὁ ἀποκαλύπτω ὁ ἄνθρωπος λέγω ἐνταῦθα ὁ ὡς ὅς ὁ διάβολος πᾶς μέν ἀπό ὁ ὁ κύριος2 παρουσία μελετάω αὐτός ἐπί ὁ ὁ ἄνθρωπος βλάβη καί ἤδη γε αὐτός καί ποιέω εἰ μή κατά ὁ ἀπόρρητος αὐτός βουλή κατέχω αὐτός ὁ
# 		Example sentence 368 including 'ἐνταῦθα' in typical context 0:
# 			Tokens: οὗτος ἐνταῦθα ἐκεῖ δέ ἐν ὁ πρότερος ἵνα εὐσχήμων φημί πρός ὁ ἔξω
# 		Example sentence 633 including 'ἐνταῦθα' in typical context 0:
# 			Tokens: σάρξ ἐνταῦθα ὁ λογισμός ὁ γεώδης καλέω ὁ καί ἀμελέω
# 	...
# 	generalized_context_vector_2:
# 		Example sentence 183819 including 'ἐνταῦθα' in typical context 2:
# 			Tokens: φημί ὅτι2 ἐκεῖ μέν ἐπί ὁ λόγος καί ὄνομα ἐνταῦθα δέ εἰ καί μᾶλλον ὁ ἄλλος ἀλλά γε καί ὁ λοιπός φαίνω
# 		Example sentence 256230 including 'ἐνταῦθα' in typical context 2:
# 			Tokens: εἰμί καί ὁ Ἰουλιανός καί Πέτρος ὁ ἐνταῦθα διάγω
# 		Example sentence 117862 including 'ἐνταῦθα' in typical context 2:
# 			Tokens: μέν οὖν λέγω μηδέ ἐνταῦθα λέγω ἐν ὁ τοιοῦτος ἀναγκαῖον γίγνομαι ὁ συμπέρασμα ἀλλά ἐπί ὕλη καί οὗτος πιστόω ἐκ ὁ οὕτως λέγω αὐτός συμβαίνω δέ ποτε καί ὅς ὁ ἕτερος πρότασις ἀνάγκη εἰμί
# 	...
# 	generalized_context_vector_1:
# 		Example sentence 197004 including 'ἐνταῦθα' in typical context 1:
# 			Tokens: ἐνταῦθα μένω ἡμέρα
# 		Example sentence 197022 including 'ἐνταῦθα' in typical context 1:
# 			Tokens: ἐνταῦθα μένω ἡμέρα
# 		Example sentence 197028 including 'ἐνταῦθα' in typical context 1:
# 			Tokens: ἐνταῦθα μένω ἡμέρα
# 	...
#
#
# ψῆφος (2 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 16785 including 'ψῆφος' in typical context 0:
# 			Tokens: ἐν δέ τῷ πέμπτος περί ὁ Ἰωάννης ἀποκάλυψις καί ὁ ψῆφος ὁ ὁ προσηγορία οὕτως διαλαμβάνω
# 		Example sentence 207211 including 'ψῆφος' in typical context 0:
# 			Tokens: ὁ δέ ἄλλος πολύς γάρ ὁ σύν ὁ μέγας δόγμα ἀγνοέω ἅπας ὁ προφανής ἀντιλέγω ὁ παράνομος καί ὁ ἄδικος ψῆφος ἐκεῖνος ὁ ἐπίσκοπος2 διακωλύω ὁ δέ ὁ δρᾶμα ταχύς πρός ὁ βασιλεύς ἀνατρέχω αὐτός ὡς ἀληθής ὁ εὑρίσκω καί δίκαιος ὁ ὁ καθαίρεσις ψῆφος μοιχός ὁμοῦ καί τύραννος ἐξελαύνω ὁ ἱερόν περίβολος καί εἰς πόλις διά ὁ Θρᾴκη πρόσω ἀπάγω ὁ ὁ εὐσέβεια καί σωφροσύνη ἀγωνιστής
# 		Example sentence 291131 including 'ψῆφος' in typical context 0:
# 			Tokens: ὁ οὖν δικάζω ἕκαστος ταχύς εἰς ὁ εἰμί καί ὁ ἑαυτοῦ ψῆφος περί ὁ ἄλλος ὁ ὕστερον ἑαυτοῦ εἰς παράδειγμα παιδεύω μή προστίθημι οὗτος ὁ ὁ πείθω ὅς πρώην καί ὁ ὅλος οὗτος παραδίδωμι τῷ
# 	...
# 	generalized_context_vector_1:
# 		Example sentence 201333 including 'ψῆφος' in typical context 1:
# 			Tokens: ἀδύνατος δέ καί εἰμί περί τοιοῦτος πρᾶγμα φέρω ὁ ψῆφος ἤ κατελεέω ἤ καταχαρίζομαι Ἀνδοκίδης ἐφίστημι ὅτι2 ἐναργής ὁ οὗτος ὁ ἀδικέω
# 		Example sentence 33951 including 'ψῆφος' in typical context 1:
# 			Tokens: πότερος παρά ὁ μάντις ἀκούω ἤ ψῆφος ὁράω δικαστής ἤ λαμβάνω αὐτός ὁμολογέω
# 		Example sentence 79972 including 'ψῆφος' in typical context 1:
# 			Tokens: εἰμί δέ οὗτος πᾶς εἰς ἄκρον παιδεία ἔρχομαι καί φθόνος μᾶλλον ἤ ψῆφος δίκαιος κατακρίνω
# 	...
