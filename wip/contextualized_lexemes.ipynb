# %%
import csv
from sklearn.cluster import DBSCAN
from collections import defaultdict
from itertools import product
from sklearn.metrics.pairwise import cosine_similarity
from scipy.special import softmax
from scipy.spatial.distance import cdist
import itertools
import numpy as np
from gensim.utils import simple_preprocess
from gensim.models import FastText
import os
import codecs

# %%
# set paths
# corpus_path = "/Users/ryderwishart/w2v/ancient-greek-word2vec/data/corpus"
model_path = "/Users/ryderwishart/w2v/ancient-greek-word2vec/models/ft_papyri&corpus_cbow_hs_2_to_5_size300_window5_mincount2.model"

# %% [markdown]
# ## Check for missing files in either the lemmatized or non-lemmatized directories

# %%
import os

lemmatized_path = "/Users/ryderwishart/biblical-machine-learning/data/lemmas"
non_lemmatized_path = "/Users/ryderwishart/biblical-machine-learning/data/texts"

lemmatized_files = set(os.listdir(lemmatized_path))
non_lemmatized_files = set(os.listdir(non_lemmatized_path))

missing_from_lemmatized = non_lemmatized_files - lemmatized_files
missing_from_non_lemmatized = lemmatized_files - non_lemmatized_files

if missing_from_lemmatized:
    print("Missing files in lemmatized directory:")
    print(missing_from_lemmatized)

if missing_from_non_lemmatized:
    print("Missing files in non-lemmatized directory:")
    print(missing_from_non_lemmatized)
    
missing_files = missing_from_lemmatized | missing_from_non_lemmatized
# Out:
# Missing files in non-lemmatized directory:
# {'tlg0013.tlg015.perseus-grc2.txt', 'tlg0013.tlg013.perseus-grc2.txt', 'tlg0013.tlg033.perseus-grc2.txt', 'tlg2313.perseus001.perseus-grc1.txt', 'tlg0082.tlg001.1st1K-grc1.txt', 'tlg0565.tlg002.1st1K-grc1.txt', 'tlg0082.tlg002.1st1K-grc1.txt', 'tlg2313.perseus002.perseus-grc1.txt', 'tlg0013.tlg020.perseus-grc2.txt'}

# %% [markdown]
# ## Preprocessing: Tokenize and lemmatize the corpus, splitting it into sentences or documents.

# %%
# Define preprocessing functions and pad each sentence to the same length
force_lowercase = True
use_lemma_disambiguation = False # Some lemmas are indicated with a numeric suffix (e.g., 'ὅτι2')

# Change to the directory entered (this is necessary to use the codecs.open() method). 
# TODO: rewrite this corpus iterator without the codecs module.

# if not(os.getcwd().split('/')[-1].endswith('corpus')):
#     os.chdir(corpus_directory)

# This class streams through the corpus when called.

def tokenize(string):
    output = string
    if use_lemma_disambiguation:
        pass
    else:
        # Filter numeric digits from token
        output = ''.join(filter(lambda x: not x.isdigit(), string))
    if force_lowercase:
        return [token.lower() for token in output.split()]
    else:
        return output.split()
    
import os
import codecs
import csv

import os
import codecs

class MySentences(object):
    def __init__(self, tsv_path):
        self.tsv_path = tsv_path
        self.files = self._get_tsv_files()

    def __iter__(self):
        for tsv_file in self.files:
            with open(tsv_file, 'r', encoding='utf-8') as f:
                header = next(f)
                for line in f:
                    row = line.rstrip().split('\t')
                    if len(row) > 3 and row[3]:
                        yield tokenize(row[3])
                    else:
                        yield []

    def _get_tsv_files(self):
        tsv_files = []
        for file in os.listdir(self.tsv_path):
            if file.endswith(".tsv"):
                tsv_files.append(os.path.join(self.tsv_path, file))
        return tsv_files

    def get_sentence(self, index, id=None, filename=None):
        if id is not None and filename is not None:
            tsv_file = os.path.join(self.tsv_path, filename)
            with open(tsv_file, 'r', encoding='utf-8') as f:
                header = next(f)
                for line_number, line in enumerate(f):
                    row = line.rstrip().split('\t')
                    if int(row[0]) == id:
                        tokens = tokenize(row[2])
                        lemmas = tokenize(row[3])
                        if len(tokens) != len(lemmas):
                            tokens.append('[LENGTH_MISMATCH]')
                        return lemmas, tokens, tsv_file, line_number

        i = 0
        for tsv_file in self.files:
            with open(tsv_file, 'r', encoding='utf-8') as f:
                header = next(f)
                for line_number, line in enumerate(f):
                    row = line.rstrip().split('\t')
                    tokens = tokenize(row[2])
                    lemmas = tokenize(row[3])
                    if i == index:
                        if len(tokens) != len(lemmas):
                            tokens.append('[LENGTH_MISMATCH]')
                        return lemmas, tokens, tsv_file, line_number
                    i += 1

# %%
# Instantiate corpus reader
corpus = MySentences('/Users/ryderwishart/Documents/Storage/Programming/Corpora/celano/LemmatizedAncientGreekXML/sentence_pair_tsvs/')

# %%
# Calculate max_sentence_length
max_sentence_length = 0
for sentence in corpus:
    if len(sentence) > max_sentence_length:
        max_sentence_length = len(sentence)

# %%
max_sentence_length
# Out:
# 543

# %%
# pad all sentences to maximum length with [PAD] token
# for i, sentence in enumerate(corpus):
#     if len(sentence) == 0:
#         pass
#     elif len(sentence) < max_sentence_length:
#         sentence.extend(['[PAD]'] * (max_sentence_length - len(sentence)))
        
def pad_sentence(sentence, max_sentence_length):
    if len(sentence) == 0:
        return sentence
    elif len(sentence) < max_sentence_length:
        sentence.extend(['[PAD]'] * (max_sentence_length - len(sentence)))
        return sentence
    else:
        return sentence

# %% [markdown]
# ## Initialization of Vocabulary Embeddings: Start with global vectors (e.g., FastText or Word2Vec) as initialization of vocabulary embeddings.

# %%
# initialize FastText model with pre-trained embeddings
model = FastText.load(model_path)

# %% [markdown]
# ## Contextual Vectors: For each sentence in the corpus, calculate the contextual vector for each token by taking a weighted sum of the token's global vector and the global vectors of its neighboring tokens. The weighting can be done using a Gaussian kernel, with the distance between tokens as the input to the kernel.

# %%
# set the number of samples (None to use complete corpus, some subset for testing)
samples = 1000

# define function to calculate contextual vectors for a sentence


def get_word_embedding(token, model):
    if token in model.wv:
        return model.wv[token].reshape(-1)
    else:
        return np.zeros(model.vector_size)


def calculate_contextual_vectors(sentence, model, window_size=5):
    contextual_vectors = []
    embedding_size = model.vector_size
    sentence_len = len(sentence)

    for i, token in enumerate(sentence):
        # Get the global vector for the token from the FastText model
        token_embedding = get_word_embedding(token, model)
        # print('token_embedding.shape', token_embedding.shape)
        # Initialize the contextual vector as the global vector
        contextual_vector = np.zeros(embedding_size)
        # print('contextual_vector.shape', contextual_vector.shape)
        # Calculate the attention scores for neighboring tokens within the window
        for j in range(max(0, i - window_size), min(sentence_len, i + window_size + 1)):
            if j != i:
                neighbor_token = sentence[j]
                neighbor_embedding = get_word_embedding(neighbor_token, model)
                # Print shape of neighbour embedding
                # print('neighbor_embedding.shape', neighbor_embedding.shape)
                if neighbor_token != "[PAD]":
                    # Calculate the distance between the embeddings
                    distance = cdist(token_embedding.reshape(
                        1, -1), neighbor_embedding.reshape(1, -1), metric='cosine')

                    # Convert distance to attention score using softmax
                    attention_score = softmax(-distance)

                    # Update the contextual vector with a weighted sum of the neighbor's global vector
                    contextual_vector += attention_score.reshape(-1) * \
                        neighbor_embedding

        # Normalize the contextual vector
        contextual_vector = contextual_vector / np.linalg.norm(contextual_vector)

        contextual_vectors.append(contextual_vector)

    return np.array(contextual_vectors)


# Calculate contextual vectors for a subset of the corpus
contextual_vectors_corpus = []
for i, sentence in enumerate(corpus):
    padded_sentence = pad_sentence(sentence, max_sentence_length)
    if padded_sentence is None:
        print('padded_sentence is None')
        pass
    elif i < samples:
        # print(i, sentence)
        contextual_vectors = calculate_contextual_vectors(padded_sentence, model)
        contextual_vectors_corpus.append(contextual_vectors)
# Out:
# /var/folders/hz/6rspy0v17q7b21wllgrjbn040000gn/T/ipykernel_15906/893259562.py:46: RuntimeWarning: invalid value encountered in divide
#   contextual_vector = contextual_vector / np.linalg.norm(contextual_vector)

# %% [markdown]
# ## Token-based Contextual Vectors: Create a dictionary where the keys are tokens, and the values are lists of their contextual vectors. Also, store the sentence index and token index in the sentence for each contextual vector.

# %% [markdown]
# ### Clustering: For each token, perform clustering on its contextual vectors. You can use a clustering algorithm like DBSCAN, which doesn't require specifying the number of clusters in advance, or other unsupervised clustering methods.

# %%
# Set cluster params
eps = 0.5 # The maximum distance between two samples for them to be considered as in the same neighborhood.
base_min_samples = 2  # Base value for min_samples
scaling_factor = 0.1  # Adjust this value to control the influence of token frequency on min_samples

# %%
import numpy as np
import math

# 1. Token-based Contextual Vectors
token_context_vectors = defaultdict(list)

for sentence_idx, (sentence, sentence_context_vectors) in enumerate(zip(corpus, contextual_vectors_corpus)):
    for token_idx, (token, context_vector) in enumerate(zip(sentence, sentence_context_vectors)):
        token_context_vectors[token].append(
            (context_vector, sentence_idx, token_idx))

# 2. Clustering
token_clusters = {}
for token, context_vector_data in token_context_vectors.items():
    context_vectors = [data[0] for data in context_vector_data if len(data[0]) > 0]
    
    # Filter out context vectors containing NaN values
    context_vectors = [vec for vec in context_vectors if not np.isnan(vec).any()]
    
    if len(context_vectors) == 0:
        continue
    else:
        token_frequency = len(context_vector_data)
        # min_samples_scaled = int(base_min_samples + (scaling_factor * math.log(token_frequency + 1))) # log scaling
        min_samples_scaled = int(base_min_samples + (scaling_factor * (token_frequency ** 0.5))) # sqrt/power-law scaling

        clustering = DBSCAN(eps=eps, min_samples=min_samples_scaled).fit(context_vectors)
        token_clusters[token] = clustering.labels_

# %% [markdown]
# ### Generalized Context Vectors: For each cluster, calculate the centroid (mean vector) of the contextual vectors in the cluster. This will be the generalized context vector for the cluster.

# %%
# 3. Generalized Context Vectors
token_generalized_vectors = {}
for token, context_vector_data in token_context_vectors.items():
    context_vectors = [data[0] for data in context_vector_data]

    if token not in token_clusters:  # If the token doesn't have a cluster
        token_generalized_vectors[token] = context_vectors
        continue

    labels = token_clusters[token]
    # Ignore noise points labeled as -1
    num_clusters = len(set(labels)) - (1 if -1 in labels else 0)
    generalized_vectors = []
    for cluster_idx in range(num_clusters):
        cluster_vectors = [vec for vec, label in zip(
            context_vectors, labels) if label == cluster_idx]
        centroid = np.mean(cluster_vectors, axis=0)
        generalized_vectors.append(centroid)
    token_generalized_vectors[token] = generalized_vectors

# 4. Example Sentences
token_examples = defaultdict(lambda: defaultdict(list))
num_examples = 3

for token, context_vector_data in token_context_vectors.items():
    context_vectors = [data[0] for data in context_vector_data]

    if token not in token_clusters:  # If the token doesn't have a cluster
        for context_vector, vector_data in zip(context_vectors, context_vector_data):
            sentence_idx, token_idx = vector_data[1:]
            lemmas, tokens, file, line_number = corpus.get_sentence(sentence_idx)
            token_examples[token][-1].append((0, sentence_idx, token_idx, file, line_number))
        token_examples[token][-1] = token_examples[token][-1][:num_examples]
        continue

    labels = token_clusters[token]
    generalized_vectors = token_generalized_vectors[token]
    for context_vector, label, vector_data in zip(context_vectors, labels, context_vector_data):
        sentence_idx, token_idx = vector_data[1:]
        lemmas, tokens, file, line_number = corpus.get_sentence(sentence_idx)
        if label != -1:  # Ignore noise points
            centroid = generalized_vectors[label]
            distance = cdist(context_vector.reshape(1, -1),
                             centroid.reshape(1, -1), metric='cosine')
            token_examples[token][label].append(
                (distance, sentence_idx, token_idx, file, line_number))
            token_examples[token][label].sort(
                key=lambda x: x[0])  # Sort by distance
            # Keep top examples
            token_examples[token][label] = token_examples[token][label][:num_examples]

# %%
# Print output
for token, context_examples in token_examples.items():
    number_of_clusters_for_token = len(context_examples)
    print(f"{token} ({number_of_clusters_for_token} cluster/s):")
    for context_label, examples in context_examples.items():
        print(f"\tgeneralized_context_vector_{context_label}:")
        for example in examples:
            distance, sentence_idx, token_idx, file, line_number = example
            lemmas, tokens, _, _ = corpus.get_sentence(sentence_idx)
            print(
                f"\t\tExample sentence {sentence_idx} including '{token}' in typical context {context_label}:")
            if tokens:
                print(f"\t\t\tTokens: {' '.join(tokens)}")
            print(f"\t\t\tLemmas: {' '.join(lemmas)}")
        # print("\t...")
    print("\n")
# Out:
# . (5 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 2 including '.' in typical context 0:
# 			Tokens: πεπαιδευμένου γάρ ἐστι κατὰ τρόπον τὸ δύνασθαι κρῖναι εὐστόχως τί καλῶς ἢ μὴ καλῶς ἀποδίδωσιν ὁ λέγων.
# 			Lemmas: γάρ εἰμί κατά τρόπος ὁ δύναμαι κρίνω εὔστοχος τίς καλός τίη μή καλός ἀποδίδωμι ὁ λέγω .
# 		Example sentence 18 including '.' in typical context 0:
# 			Tokens: / πρὸς δὲ τούτοις, ἐπεὶ πλείους ὁρῶμεν αἰτίας περὶ τὴν γένεσιν τὴν φυσικήν, οἷον τήν θʼ οὗ ἕνεκα καὶ τὴν ὅθεν ἡ ἀρχὴ τῆς κινήσεως, διοριστέον καὶ περὶ τούτων, ποία πρώτη καὶ δευτέρα πέφυκεν. [LENGTH_MISMATCH]
# 			Lemmas: πρός δέ οὗτος , ἐπεί πολύς ὁράω αἰτία περί ὁ γένεσις ὁ φυσικός , οἷος ὁ οὗ ἕνεκα καί ὁ ὅθεν ὁ ἀρχή ὁ κίνησις , διορίζω καί περί οὗτος , ποιός πρῶτος καί δεύτερος φύω .
# 		Example sentence 24 including '.' in typical context 0:
# 			Tokens: σχεδὸν τοὺς λόγους ἀνάγειν, οὐ διελόμενοι ποσαχῶς λέγεται τὸ ἀναγκαῖον. [LENGTH_MISMATCH]
# 			Lemmas: σχεδόν ὁ λόγος ἀνάγω , οὐ διαιρέω ποσαχῶς λέγω ὁ ἀναγκαῖον .
# 	generalized_context_vector_1:
# 		Example sentence 535 including '.' in typical context 1:
# 			Tokens: τοῦτο γὰρ ἀρχὴ καὶ σωμα καθʼ αὑτὸ τῶν ζῴων ἐστίν. [LENGTH_MISMATCH]
# 			Lemmas: οὗτος γάρ ἀρχή καί ἑαυτοῦ ὁ ζῷον εἰμί .
# 		Example sentence 601 including '.' in typical context 1:
# 			Tokens: ἐν τούτῳ δὲ τῷ γένει καὶ ἡ τῶν ὀδόντων ἐστὶ φύσις, τοῖς μὲν ὑπάρχουσα πρὸς ἓν ἔργον τὴν τῆς τροφῆς ἐργασίαν, τοῖς δὲ πρός τε τούτο καὶ πρὸς ἀλκήν, οἷον τοῖς καρχαρόδουσι καὶ χαυλιόδουσι πἀσιν. [LENGTH_MISMATCH]
# 			Lemmas: ἐν οὗτος δέ τῷ γένος καί ὁ ὁ ὀδούς εἰμί φύσις , ὁ μέν ὑπάρχω πρός ἔργον ὁ ὁ τροφή ἐργασία , ὁ δέ πρός τε καί πρός ἀλκή , οἷος ὁ καί .
# 		Example sentence 92 including '.' in typical context 1:
# 			Tokens: ὑπάρχει γὰρ ἡ φορὰ καὶ ἐν ἑτέροις τῶν ζῴων, διάνοια δʼ οὐδενί. [LENGTH_MISMATCH]
# 			Lemmas: ὑπάρχω γάρ ὁ φορά καί ἐν ἕτερος ὁ ζῷον , διάνοια δέ .
# 	generalized_context_vector_2:
# 		Example sentence 811 including '.' in typical context 2:
# 			Tokens: ἔτι δʼ οἱ τʼ οἱστροι καὶ οἱ μύωπες οἱ μὲν τὰ τῶν ἀνθρύόπων οἱ δὲ καὶ τὰ τῶν ἅλλων ζῷόων δέρματα διαιρούσιν. [LENGTH_MISMATCH]
# 			Lemmas: ἔτι δέ ὁ καί ὁ ὁ μέν ὁ ὁ ὁ δέ καί ὁ ὁ ἄλλος δέρμα .
# 		Example sentence 406 including '.' in typical context 2:
# 			Tokens: ἐπεὶ δὲ πάσης τροφῆς ἐστί τι δεκτικὸν καὶ τῶν γινομένων περιττωμάτων, αἱ δὲ φλέβες οἷον ἀγγεῖον αἵματός εἰσι, φανερὸν ὅτι τὸ αἷμα ἡ τελευταία τροφὴ τοῖς ζῴοις τοῖς ἐναίμοις ἐστί, τοῖς δʼ ἀυαίμοις τὸ ἀνάλογον.
# 			Lemmas: ἐπεί δέ πᾶς τροφή εἰμί τις δεκτικός καί ὁ περίσσωμα , ὁ δέ φλέψ οἷος ἀγγεῖον αἷμα εἰμί , φανερός ὅτι ὁ αἷμα ὁ τελευταῖος τροφή ὁ ὁ εἰμί , ὁ δέ ὁ ἀνάλογος .
# 		Example sentence 95 including '.' in typical context 2:
# 			Tokens: ἕτι δὲ τῶν ἐξ ἀφαιρέσεως οὐδενὸς οἷόν τʼ εἶναι τὴν φυσικὴν θεωρητικὴν, ἐπειδὴ ἡ φύσις ἕνεκά του ποιεῖ πάντα. [LENGTH_MISMATCH]
# 			Lemmas: δέ ὁ ἐκ ἀφαίρεσις εἰμί ὁ θεωρητικός , ἐπεί ὁ φύσις ποιέω πᾶς .
# 	generalized_context_vector_3:
# 		Example sentence 420 including '.' in typical context 3:
# 			Tokens: τὸ γὰρ γεῶδες οὐδέτερον ἔχει τούτων.
# 			Lemmas: ὁ γάρ οὐδέτερος ἔχω οὗτος .
# 		Example sentence 538 including '.' in typical context 3:
# 			Tokens: αὕτη δʼ ἐστὶν ἀρή, ταύτης δʼ αἰσθητήριον τὸ τοιοντον μόριόν ἐστιν, ἤτοι τὸ πρῶτον, ὡσπερ ἡ κόρη τῆς ὅψεως, ἢ τὸ διʼ σὺ συνειλημμένον, ὧσπερ ἄν εἴ τις προσλάβοι τῇ κόρῃ τὸ διαφανὲς πἀν. [LENGTH_MISMATCH]
# 			Lemmas: οὗτος δέ εἰμί ἀρά , οὗτος δέ ὁ μόριος εἰμί , ἤτοι ὁ πρῶτος , ὁ κόρη ὁ , ἤ ὁ συλλαμβάνω , ἄν εἰ τις ὁ κόρη ὁ διαφανής .
# 		Example sentence 217 including '.' in typical context 3:
# 			Tokens: ᾗ δὲ συμβήσεται λέγειν πολλάκις περὶ τοῦ αὐτοῦ πάθους διὰ τὸ κοινῇ πλείοσιν ὑπάρχειν, ταύτῃ δʼ ἐστὶν ὑπάτοπον καὶ μακρὸν τὸ περὶ ἑκάστου λέγειν χωρίς. [LENGTH_MISMATCH]
# 			Lemmas: ὅς δέ συμβαίνω λέγω πολλάκις περί ὁ αὐτός πάθος διά ὁ κοινῇ πολύς ὑπάρχω , οὗτος δέ εἰμί καί μακρός ὁ περί ἕκαστος λέγω χωρίς .
# 	generalized_context_vector_4:
# 		Example sentence 832 including '.' in typical context 4:
# 			Tokens: ἐπεὶ δὲ τὸ ἄρρεν ίσχυρότερον καὶ θυμικωτερον, τὰ μὲν μόνα τὰ δὲ μἅλλον ἔχει τὰ τοιαῦτα τῶν μορίων. [LENGTH_MISMATCH]
# 			Lemmas: ἐπεί δέ ὁ ἄρσην καί , ὁ μέν ὁ δέ ἔχω ὁ τοιοῦτος ὁ μόριον .
# 		Example sentence 774 including '.' in typical context 4:
# 			Tokens: ψελλίζονται γὰρ καὶ τραυλίζουσι, τούτο δʼ ἐστὶν ἔνδεια τῶν γραμμάτων.
# 			Lemmas: ψελλίζω γάρ καί τραυλίζω , δέ εἰμί ὁ γράμμα .
# 		Example sentence 271 including '.' in typical context 4:
# 			Tokens: δευτέρα δὲ σύστασις ἐκ τῶν πρώτων ἡ τῶν ὁμοιομερῶν φύσις ἐν τοῖς ζῴοις ἐστίν, οἷον ὀστοῦ καὶ σαρκὸς καὶ τῶν ἄλλων τῶν τοιούτων τρίτη δὲ καὶ τελευταία κατ ἀριθμὸν ἡ τῶν ἀνομοιομερῶν, οἷον προσώπου καὶ χειρὸς καὶ τῶν τοιούτων μορίων. [LENGTH_MISMATCH]
# 			Lemmas: δεύτερος δέ σύστασις ἐκ ὁ ὁ ὁ φύσις ἐν ὁ ζῷον εἰμί , οἷος καί καί ὁ ἄλλος ὁ τοιοῦτος δέ καί τελευταῖος ἀριθμός ὁ ὁ , οἷος πρόσωπον καί χείρ καί ὁ τοιοῦτος μόριον .
#
#
# πᾶς (5 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 604 including 'πᾶς' in typical context 0:
# 			Tokens: διὸ καὶ πάντα τὰ τοιαῦτα μἀλλον ἐν τοῖς τετράποσιν ὑπάρχει ζῄοις τῶν ζῳοτόκων, διὰ τὸ γεωδεστέραν ἔχειν πάντα τὴν σύστασιν ἢ τὸ τῶν ἀνθρώπων γένος. [LENGTH_MISMATCH]
# 			Lemmas: διό καί πᾶς ὁ τοιοῦτος ἐν ὁ ὑπάρχω ὁ , διά ὁ ἔχω πᾶς ὁ σύστασις ἤ ὁ ὁ ἄνθρωπος γένος .
# 		Example sentence 298 including 'πᾶς' in typical context 0:
# 			Tokens: ὄντων δὲ τῶν μὲν ὀργανικῶν μερῶν τῶν δʼ αἰσθητηρίων ἐν τοῖς ζῴοις, τῶν μὲν ὀργανικῶν ἕκαστον ἀνομοιομερές ἐστιν, ὥσπερ εἶπον πρότερον, ἡ δʼ αἴσθησις συνεγγίνεται πᾶσιν ἐν τοῖς ὁμοιομερέσι, διὰ τὸ τῶν αἰσθήσεων ὁποιανοῦν ἑνός τινος εἶναι γένους, καὶ τὸ αἰσθητήριον ἑκάστου δεκτικὸν εἶναι τῶν αἰσθητῶν. [LENGTH_MISMATCH]
# 			Lemmas: εἰμί δέ ὁ μέν μέρος ὁ δέ αἰσθητήριον ἐν ὁ , ὁ μέν ἕκαστος εἰμί , ὥσπερ λέγω πρότερος , ὁ δέ αἴσθησις πᾶς ἐν ὁ , διά ὁ ὁ αἴσθησις εἰμί γένος , καί ὁ αἰσθητήριον ἕκαστος δεκτικός εἰμί ὁ .
# 		Example sentence 651 including 'πᾶς' in typical context 0:
# 			Tokens: ἔχει δʼ ἐν τᾧ ἔμπροσθεν τὸν ἐγκέφαλον πάντα τὰ ἔχοντα τούτο τὸ μόριον, διὰ τὸ ἔμπροσθεν εἶναι ἑο ὅ αἰσθάνεται, τὴν δʼ αἴσθησιν ἀπὸ τῆς καρδίας, ταύτην δʼ εἶναι ἐν τσῖς ἔμπροσθεν, καὶ τὸ αίσθάνεσθαι διὰ τῶν ἐναίμων γίνεσθαι μορίων, φλεβῶν δʼ εἶναι κενὸν τὸ ὄπισθεν κύτος. [LENGTH_MISMATCH]
# 			Lemmas: ἔχω δέ ἐν ἔμπροσθεν ὁ ἐγκέφαλος πᾶς ὁ ἔχω ὁ μόριον , διά ὁ ἔμπροσθεν εἰμί ὅς , ὁ δέ ἀπό ὁ καρδία , οὗτος δέ εἰμί ἐν ἔμπροσθεν , καί ὁ διά ὁ ἔναιμος γίγνομαι μόριον , δέ εἰμί ὁ ὄπισθεν κύτος .
# 	generalized_context_vector_1:
# 		Example sentence 608 including 'πᾶς' in typical context 1:
# 			Tokens: εἰσὶ δʼ ἀρχαὶ πάντων τούτων τό τε ὀστοῦν καὶ ἡ σάρξ.
# 			Lemmas: εἰμί δέ ἀρχή πᾶς οὗτος ὁ τε καί ὁ σάρξ .
# 		Example sentence 253 including 'πᾶς' in typical context 1:
# 			Tokens: λεκτέον ἄρα πρῶτον τὰς πράξεις τάς τε κοινὰς πάντων καὶ τὰς κατὰ γένος καὶ τὰς κατʼ εἶδος.
# 			Lemmas: λέγω ἄρα πρῶτος ὁ πρᾶξις ὁ τε πᾶς καί ὁ κατά γένος καί ὁ κατά εἶδος .
# 	generalized_context_vector_2:
# 		Example sentence 587 including 'πᾶς' in typical context 2:
# 			Tokens: ὑγροτέραν τε γὰρ ἀναγκαῖον αὐτῶν εἶναι τὴν κίνησιν, ᾥστε δεῖ καὶ τὴν τῶν ἐρεισμάτων μὴ κραύρον εἶναι ἀλλὰ μαλακωτέραν, καὶ τὸ γεῶδες εἰς τὸ δέρμα πᾶν ἀνήλωκεν ἡ φύσις· [LENGTH_MISMATCH]
# 			Lemmas: ὑγρός τε γάρ ἀναγκαῖον αὐτός εἰμί ὁ κίνησις , δέω καί ὁ ὁ ἔρεισμα μή εἰμί ἀλλά μαλακός , καί ὁ εἰς ὁ δέρμα πᾶς ὁ φύσις ·
# 		Example sentence 311 including 'πᾶς' in typical context 2:
# 			Tokens: αἱματικὴ γὰρ ἡ φύσις πάντων αὐτῶν διὰ τὸ τὴν θέσιν ἔχειν ἐπὶ πόροις φλεβικοῖς καὶ διαλήψεσιν. [LENGTH_MISMATCH]
# 			Lemmas: γάρ ὁ φύσις πᾶς αὐτός διά ὁ ὁ θέσις ἔχω ἐπί καί διάληψις .
# 	generalized_context_vector_3:
# 		Example sentence 507 including 'πᾶς' in typical context 3:
# 			Tokens: ἐπεὶ δʼ ἅμαντα δεῖται τὴς ἐναντίας ῥοπῆς, ἵνα τυγχάνῃ τοῦ μετρίου καὶ τού μέσου( τὴν γὰρ οὐσίαν ἔχει τοῦτο καὶ τὸν λόγον, τῶν δʼ ἄκρων ἑκάτερον οὐκ ἔχει χωρίς), διὰ ταύτην τὴν αἰτίαν πρὸς τὸν της καρδίας τόπον καὶ τὴν ἐν αὐτῇ θερμότητα μεμηχάνηται τὸν ἐγκέφαλον ἡ φύσις, καὶ τούτου χαέριν ὑπάρχει τοῦτο τὸ μόριον τοῖς ζῴοις, τὴν φύσιν ἔχον κοινὴν ὕδατος καὶ γῆς, καὶ διὰ τοῦτο τὰ ἔναιμα ἔχει πάντα ἐγκέφαλον, τῶν δʼ ἄλλων οὐδὲν ὡς εἰπεῖν, πλὴν ὅτι κατὰ τὸ ἀνάλογον, οἷον ὁ πολύπους· [LENGTH_MISMATCH]
# 			Lemmas: ἐπεί δέ δέω ἐναντίος ῥοπή , ἵνα τυγχάνω ὁ μέτριος καί ὁ μέσης ( ὁ γάρ οὐσία ἔχω οὗτος καί ὁ λόγος , ὁ δέ ἄκρον ἑκάτερος οὐ ἔχω χωρίς ) , διά οὗτος ὁ αἰτία πρός ὁ καρδία τόπος καί ὁ ἐν αὐτός θερμότης μηχανάομαι ὁ ἐγκέφαλος ὁ φύσις , καί οὗτος ὑπάρχω οὗτος ὁ μόριον ὁ , ὁ φύσις ἔχω κοινός ὕδωρ καί γῆ , καί διά οὗτος ὁ ἔναιμος ἔχω πᾶς , ὁ δέ οὐδείς ὡς λέγω , πλήν ὅτι κατά ὁ , οἷος ὁ πολύπους ·
# 		Example sentence 804 including 'πᾶς' in typical context 3:
# 			Tokens: ἐπιθυμίαν δʼ ἔχει τροφῆς τὰ ζῷα πάντα ὡς ἔχοντα αἱσθησιν τῆς ἡδονῆς τῆς γινομένης ἐκ τῆς τροφῆςʼ ἡ γὰρ ἐπιθυμία τού ἡδέος ἐστίν. [LENGTH_MISMATCH]
# 			Lemmas: ἐπιθυμία δέ ἔχω τροφή ὁ ζῷον πᾶς ὡς ἔχω ὁ ἡδονή ὁ ἐκ ὁ ὁ γάρ ἐπιθυμία εἰμί .
# 	generalized_context_vector_4:
# 		Example sentence 680 including 'πᾶς' in typical context 4:
# 			Tokens: τούτου μὲν οὖν ἕνεκα λεπτὸν τὸ δέρμα τὸ περὶ τὴν κόρην ἐστί, τῆς δὲ σωτηρίας χαέριν τὰ βλέφαραʼ καὶ διὰ τοῦτο σκαρδαμύσσει τε πάντα καὶ μάλιστʼ ἅνθρωπος, πάντα μὲν ὅπως τὰ προσπίπτοντα τοῖς βλεφάροις κωλύωσι( καὶ τοῦτο οὐκ ἐκ προαιρέσεως, ἀλλʼ ἡ φύσις ἐποίησε), πλειστάκις δʼ ὁ ἅνθρωπος διὰ τὸ λεπτοδερμότατος εἷναι. [LENGTH_MISMATCH]
# 			Lemmas: οὗτος μέν οὖν ἕνεκα λεπτός ὁ δέρμα ὁ περί ὁ κόρη εἰμί , ὁ δέ σωτηρία ὁ καί διά οὗτος τε πᾶς καί ἄνθρωπος , πᾶς μέν ὅπως ὁ προσπίπτω ὁ βλέφαρον κωλύω ( καί οὗτος οὐ ἐκ προαίρεσις , ὁ φύσις ποιέω ) , πλειστάκις δέ ὁ ἄνθρωπος διά ὁ ἵημι .
# 		Example sentence 680 including 'πᾶς' in typical context 4:
# 			Tokens: τούτου μὲν οὖν ἕνεκα λεπτὸν τὸ δέρμα τὸ περὶ τὴν κόρην ἐστί, τῆς δὲ σωτηρίας χαέριν τὰ βλέφαραʼ καὶ διὰ τοῦτο σκαρδαμύσσει τε πάντα καὶ μάλιστʼ ἅνθρωπος, πάντα μὲν ὅπως τὰ προσπίπτοντα τοῖς βλεφάροις κωλύωσι( καὶ τοῦτο οὐκ ἐκ προαιρέσεως, ἀλλʼ ἡ φύσις ἐποίησε), πλειστάκις δʼ ὁ ἅνθρωπος διὰ τὸ λεπτοδερμότατος εἷναι. [LENGTH_MISMATCH]
# 			Lemmas: οὗτος μέν οὖν ἕνεκα λεπτός ὁ δέρμα ὁ περί ὁ κόρη εἰμί , ὁ δέ σωτηρία ὁ καί διά οὗτος τε πᾶς καί ἄνθρωπος , πᾶς μέν ὅπως ὁ προσπίπτω ὁ βλέφαρον κωλύω ( καί οὗτος οὐ ἐκ προαίρεσις , ὁ φύσις ποιέω ) , πλειστάκις δέ ὁ ἄνθρωπος διά ὁ ἵημι .
#
#
# τε (5 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 20 including 'τε' in typical context 0:
# 			Tokens: λόγος γὰρ οὗτος, ἀρχὴ δʼ ὁ λόγος ὁμοίως ἔν τε τοῖς κατὰ τέχνην καὶ ἐν τοῖς φύσει συνεστηκόσιν. [LENGTH_MISMATCH]
# 			Lemmas: λόγος γάρ οὗτος , ἀρχή δέ ὁ λόγος ὅμοιος ἐν τε ὁ κατά τέχνη καί ἐν ὁ φύσις συνίστημι .
# 		Example sentence 860 including 'τε' in typical context 0:
# 			Tokens: ἥ δʼ ἀλκὴ ἐν τούτῳ τε καὶ τοῖς ὄνυξι· [LENGTH_MISMATCH]
# 			Lemmas: δέ ἀλκή ἐν οὗτος τε καί ὁ ·
# 	generalized_context_vector_1:
# 		Example sentence 558 including 'τε' in typical context 1:
# 			Tokens: ἔχει δʼ ὁμοίως ἥ τε τῶν ὀστῶν καὶ ἡ τῶν φλεβῶν φύσις. [LENGTH_MISMATCH]
# 			Lemmas: ἔχω δέ ὅμοιος ὁ τε ὁ καί ὁ ὁ φύσις .
# 		Example sentence 532 including 'τε' in typical context 1:
# 			Tokens: τῶν δʼ ὑστερογενῶν τά τε περιττώματα τῆς τροφῆς ἐστί, τό τε τῆς κύστεως ὑπόστημα καὶ τὸ τῆς κοιλίας, καὶ παρὰ ταῦτα γονὴ καὶ γάλα τοῖς πεφυκόσιν ἔχειν ἕκαστα τούτων. [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ ὁ τε περίσσωμα ὁ τροφή εἰμί , ὁ τε ὁ κύστις καί ὁ ὁ κοιλία , καί παρά οὗτος γονή καί γάλα ὁ φύω ἔχω ἕκαστος οὗτος .
# 		Example sentence 220 including 'τε' in typical context 1:
# 			Tokens: σχεδὸν δὲ τοῖς σχήμασι τῶν μορίων καὶ τοῦ σώματος ὅλου, ἐὰν ὁμοιότητα ἔχωσιν, ὥρισται τὰ γένη, οἷον τὸ τῶν ὀρνίθων γένος πρὸς αὐτὰ πέπονθε καὶ τὸ τῶν ἰχθύων καὶ τὰ μαλάκιά τε καὶ τὰ ὄστρεια. [LENGTH_MISMATCH]
# 			Lemmas: σχεδόν δέ ὁ σχῆμα ὁ μόριον καί ὁ σῶμα , ἐάν ὁμοιότης ἔχω , ὁρίζω ὁ γένος , οἷος ὁ ὁ ὄρνις γένος πρός αὐτός πάσχω καί ὁ ὁ ἰχθύς καί ὁ τε καί ὁ ὄστρεον .
# 	generalized_context_vector_2:
# 		Example sentence 597 including 'τε' in typical context 2:
# 			Tokens: σύνεγγυς δὲ κατὰ τὴν ἁρήν ἐστι τοῖς ὀστοῖς καὶ τὰ τοιάδε τῶν μορίων οἷον ὄνυχές τε καὶ ὁπλαὶ καὶ χηλαὶ καὶ κέρατα καὶ ῥύγχη τὰ τῶν ἀρνίθωυ. [LENGTH_MISMATCH]
# 			Lemmas: σύνεγγυς δέ κατά ὁ εἰμί ὁ καί ὁ τοιόσδε ὁ μόριον οἷος τε καί ὁπλή καί καί κέρας καί ῥύγχος ὁ ὁ .
# 		Example sentence 599 including 'τε' in typical context 2:
# 			Tokens: τὰ γὰρ ἐξ οὐτῶν συνεστηκότα ὅλα καὶ συνύνυμα τοῖς μορίοις, οἷον ὁπλή τε ὅλη καὶ κέρας ὅλον,.
# 			Lemmas: ὁ γάρ ἐκ συνίστημι ὅλος καί ὁ μόριος , οἷος ὁπλή τε καί κέρας ὅλος , .
# 	generalized_context_vector_3:
# 		Example sentence 831 including 'τε' in typical context 3:
# 			Tokens: τῶν τε γὰρ πρὸς ἀλκήν τε καὶ βοήθειαν ὀργανικῶν μορίων ἓκαστα ἀποδίδωσιν ἡ φύσις τοῖς δυναμένοις χρῆσθαι μόνοις ἦ μάλλον, μάλιστα δὲ τᾧ μάλιστα, οἷον κέντρον, πλ ῆκτρον, κέρατα, χαυλιόδοντας καὶ εἴ τι τοιἕτερον. [LENGTH_MISMATCH]
# 			Lemmas: ὁ τε γάρ πρός ἀλκή τε καί βοήθεια μόριος ἀποδίδωμι ὁ φύσις ὁ χράω μόνος ἦ , μάλιστα δέ μάλιστα , οἷος κέντρον , , κέρας , καί εἰ τι .
# 		Example sentence 825 including 'τε' in typical context 3:
# 			Tokens: ὅσα δὲ καὶ πρὸς βοήθειάν τε καὶ πρὸς ἀλκήν, τὰ μὲν χαυλιόδοντας ἔχει, καθάπερ ὗς, τὰ δʼ ὀξεῖς καὶ ἐπαλλάττοντας, ὅθεν καρχαρόδοντα καλεῖται. [LENGTH_MISMATCH]
# 			Lemmas: ὅσος δέ καί πρός βοήθεια τε καί πρός ἀλκή , ὁ μέν ἔχω , καθά , ὁ δέ ὀξύς καί , ὅθεν καλέω .
# 		Example sentence 831 including 'τε' in typical context 3:
# 			Tokens: τῶν τε γὰρ πρὸς ἀλκήν τε καὶ βοήθειαν ὀργανικῶν μορίων ἓκαστα ἀποδίδωσιν ἡ φύσις τοῖς δυναμένοις χρῆσθαι μόνοις ἦ μάλλον, μάλιστα δὲ τᾧ μάλιστα, οἷον κέντρον, πλ ῆκτρον, κέρατα, χαυλιόδοντας καὶ εἴ τι τοιἕτερον. [LENGTH_MISMATCH]
# 			Lemmas: ὁ τε γάρ πρός ἀλκή τε καί βοήθεια μόριος ἀποδίδωμι ὁ φύσις ὁ χράω μόνος ἦ , μάλιστα δέ μάλιστα , οἷος κέντρον , , κέρας , καί εἰ τι .
# 	generalized_context_vector_4:
# 		Example sentence 958 including 'τε' in typical context 4:
# 			Tokens: αὐτῷ γὰρ τῷ λόγῳ τούτῳ διύὸρισται τὸ ἔμπροσθεν καὶ ὄπισθεν),ὸ δὲ πλεύμων κεῖται οὐ ἡ καρδία καὶ περὶ ταύτην,ὴ δʼ ἀναπνοὴ διά τε τούτον καὶ διὰ τὴν ἀρχὴν τὴν ἐν τῇ καρδία ἐνυπάρχουσαν. [LENGTH_MISMATCH]
# 			Lemmas: αὐτός γάρ τῷ λόγος οὗτος ὁ ἔμπροσθεν καί ὄπισθεν ) , ὸ δέ πλεῦμος κεῖμαι οὐ ὁ καρδία καί περί οὗτος , ὴ δέ διά τε καί διά ὁ ἀρχή ὁ ἐν ὁ καρδία .
# 		Example sentence 621 including 'τε' in typical context 4:
# 			Tokens: ὥσιε διά τε τοῦτο, καὶ διὰ τὸ γνώριμον εἶναι μάλιστʼ αὐτοῦ τὴν τῶν ἔξωσθεν μορίων μορφήν, περὶ τούτου λεκτέον πρῶτον.
# 			Lemmas: διά τε οὗτος , καί διά ὁ γνώριμος εἰμί αὐτός ὁ ὁ μόριον μορφή , περί οὗτος λέγω πρῶτος .
#
#
# καί (2 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 558 including 'καί' in typical context 0:
# 			Tokens: ἔχει δʼ ὁμοίως ἥ τε τῶν ὀστῶν καὶ ἡ τῶν φλεβῶν φύσις. [LENGTH_MISMATCH]
# 			Lemmas: ἔχω δέ ὅμοιος ὁ τε ὁ καί ὁ ὁ φύσις .
# 		Example sentence 811 including 'καί' in typical context 0:
# 			Tokens: ἔτι δʼ οἱ τʼ οἱστροι καὶ οἱ μύωπες οἱ μὲν τὰ τῶν ἀνθρύόπων οἱ δὲ καὶ τὰ τῶν ἅλλων ζῷόων δέρματα διαιρούσιν. [LENGTH_MISMATCH]
# 			Lemmas: ἔτι δέ ὁ καί ὁ ὁ μέν ὁ ὁ ὁ δέ καί ὁ ὁ ἄλλος δέρμα .
# 		Example sentence 548 including 'καί' in typical context 0:
# 			Tokens: τὰ δʼ ἕντομα τῶν ζῷόων καὶ τὰ μαλάκια τούτοιςτ’ ἐναντίως καὶ αὐτοῖς ἀντικειμένως συνέστηκεν· [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ ὁ καί ὁ οὗτος τ’ ἐναντίος καί αὐτός συνίστημι ·
# 	generalized_context_vector_1:
# 		Example sentence 559 including 'καί' in typical context 1:
# 			Tokens: ἑκατέρα γὰρ οὐτων ἀφοʼ ἑνὸς ἠργμένη συνεχής ἐστι, καὶ οὔτʼ ὀστοῦν ἐστὶν αὐτὸ καθʼ αὑτὸ οὐδέν, ἁλλ’ ἢ μόριον ὡς συνεχοῦς ἤ ἁπτόμενον καὶ προσδεδεμένον, ἵνα χρῆται ἡ φύσις καὶ ὡς ἑνὶ καὶ συνεχεῖ καὶ ὡς δυσὶ καὶ διῃρημένοις πρὸς τὴν κάμυψιν. [LENGTH_MISMATCH]
# 			Lemmas: γάρ ἄρχω συνεχής εἰμί , καί εἰμί αὐτός οὐδείς , τίη ὡς ἤ ἅπτω καί προσδέω , ἵνα χράω ὁ φύσις καί ὡς καί συνόχωκα καί ὡς καί πρός ὁ .
# 		Example sentence 559 including 'καί' in typical context 1:
# 			Tokens: ἑκατέρα γὰρ οὐτων ἀφοʼ ἑνὸς ἠργμένη συνεχής ἐστι, καὶ οὔτʼ ὀστοῦν ἐστὶν αὐτὸ καθʼ αὑτὸ οὐδέν, ἁλλ’ ἢ μόριον ὡς συνεχοῦς ἤ ἁπτόμενον καὶ προσδεδεμένον, ἵνα χρῆται ἡ φύσις καὶ ὡς ἑνὶ καὶ συνεχεῖ καὶ ὡς δυσὶ καὶ διῃρημένοις πρὸς τὴν κάμυψιν. [LENGTH_MISMATCH]
# 			Lemmas: γάρ ἄρχω συνεχής εἰμί , καί εἰμί αὐτός οὐδείς , τίη ὡς ἤ ἅπτω καί προσδέω , ἵνα χράω ὁ φύσις καί ὡς καί συνόχωκα καί ὡς καί πρός ὁ .
# 		Example sentence 82 including 'καί' in typical context 1:
# 			Tokens: καὶ ἔστιν αὕτη καὶ ὡς ἡ κινοῦσα καὶ ὡς τὸ τέλος. [LENGTH_MISMATCH]
# 			Lemmas: καί εἰμί οὗτος καί ὡς ὁ κινέω καί ὡς ὁ τέλος .
#
#
# , (3 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 584 including ',' in typical context 0:
# 			Tokens: τῶν δʼ ἰχθύων τοῖς μὲν ᾠοτόκοις ἅκανθκ, καὶ τοῖς ὄφεσιν ἀκανθύὸδης ἐστὶν ἡ τῶν ὀστῶν φύσις, πλὴν τοῖς λίαν μεγάλοις· [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ ἰχθύς ὁ μέν , καί ὁ εἰμί ὁ ὁ φύσις , πλήν ὁ λίαν μέγας ·
# 		Example sentence 154 including ',' in typical context 0:
# 			Tokens: καὶ ποδότης ὡσαύτως ἡ μὲν πολυσχιδὴς, ἡ δὲ δισχιδής, οἷον τὰ διχαλά, ἡ δʼ ἀσχιδὴς καὶ ἀδιαίρετες, οἷον τὰ μώνυχα. [LENGTH_MISMATCH]
# 			Lemmas: καί ὡσαύτως ὁ μέν , ὁ δέ , οἷος ὁ , ὁ δέ καί , οἷος ὁ μῶνυξ .
# 		Example sentence 630 including ',' in typical context 0:
# 			Tokens: ὅτι μὲν οὖν ἀρχὴ τῶν αἰσθήσεωόν ἐστιν ὁ περὶ τὴν καρδίαν τόπος, διωρισται πρὸτερον ἐν τοῖς περὶ αἰσθήσεωςςʼ καὶ διότι αἱ μὲν δύο φανερῶς ἠρτημέναι πρὸς τὴν καρδίαν εἰσίν, ἢ τε τῶν ἀπτῶν καὶ ἡ τῶν χυμῶν, τῶν δὲ τριῶν ἡ μὲν τῆς ὀσφρήσεως μέση, ἀκοὴ δὲ καὶ ὄψις μάλιστʼ ἐν τῇ κεφαλῇ διὰ τὴν τῶν αἰσθητηρίων φύσιν εἰσί, καὶ τούτων ἡ ὄψις πᾶσιν, ἐπεὶ ἦ γʼ ἀκοὴ καὶ ἡ ὄσφρησις ἐπὶ τῶν ἐχθύων καὶ τάν τοιούτων ποιεῖ τὸ λεγόμενον φανερόν· [LENGTH_MISMATCH]
# 			Lemmas: ὅτι μέν οὖν ἀρχή ὁ εἰμί ὁ περί ὁ καρδία τόπος , ἐν ὁ περί καί διότι ὁ μέν γε φανερός πρός ὁ καρδία εἰμί , ἤ τε ὁ καί ὁ ὁ χυμός , ὁ δέ ὁ μέν ὁ ὄσφρησις , ἀκοή δέ καί ὄψις ἐν ὁ κεφαλή διά ὁ ὁ αἰσθητήριον φύσις εἰμί , καί οὗτος ὄψις πᾶς , ἐπεί ἦ ἀκοή καί ὁ ὄσφρησις ἐπί ὁ καί ὁ τοιοῦτος ποιέω ὁ λέγω φανερός ·
# 	generalized_context_vector_1:
# 		Example sentence 21 including ',' in typical context 1:
# 			Tokens: ἢ γὰρ τῇ διανοίᾳ, ἢ τῇ αἰσθήσει ὁρισάμενος ὁ μὲν ἰατρὸς τὴν ὑγίειαν, ὁ δʼ οἰκοδόμος τὴν οἰκίαν, ἀποδιδόασι τοὺς λόγους καὶ τὰς αἰτίας σὗ ποιοῦσιν ἑκά στου, καὶ διότι ποιητέον οὕτως. [LENGTH_MISMATCH]
# 			Lemmas: τίη γάρ ὁ διάνοια , ἤ ὁ αἴσθησις ὁρίζω ὁ μέν ἰατρός ὁ ὑγίεια , ὁ δέ οἰκοδόμος ὁ οἰκία , ὁ λόγος καί ὁ αἰτία ποιέω , καί διότι ποιέω οὕτως .
# 		Example sentence 32 including ',' in typical context 1:
# 			Tokens: ἐπεὶ γὰρ τοιόνδʼ ἐστὶν ἡ ὑγίεια ἢ ὁ ἅνθρωπος, ἀνάγκη τόδʼ εἶναι ἢ γενέσθαι, ἀλλʼ οὐκ ἐπεὶ τόδʼ ἐστὶν ἢ γέγονεν, ἐκεῖνο ἐξ ἀνάγκης ἐστὶν ἢ ἔσται.
# 			Lemmas: ἐπεί γάρ εἰμί ὁ ὑγίεια ἤ ὁ ἄνθρωπος , ἀνάγκη εἰμί τίη γίγνομαι , ἀλλά οὐ ὅδε εἰμί τίη γίγνομαι , ἐκεῖνος ἐκ ἀνάγκη εἰμί ἤ .
# 		Example sentence 56 including ',' in typical context 1:
# 			Tokens: οἱ μὲν οὖν ἀρχαῖοι καὶ πρῶτοι φιλοσοφήσαντες περὶ φύσεως περὶ τῆς ὑλικῆς ἀρχῆς καὶ τῆς τοιαύτης αἰτίας ἐσκόπουν, τίς καὶ ποία τις, καὶ πῶς ἐκ ταύτης γίνεται τὸ ὅλον, καὶ τίνος κινοῦντος, οἷον νείκους ἢ φιλίας ἢ υοῦ ἢ τοῦ αὐτομάτου, τῆς δʼ ὑποκειμένης ὕλης τοιάνδε τινὰ φύσιν ἐχούσης ἐξ ἀνάγκης, οἷον τοῦ μὲν πυρὸς θερμὴν, τῆς δὲ γῆς ψυχράν, καὶ τοῦ μὲν κούφην, τῆς δὲ βαρεῖαν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ μέν οὖν ἀρχαῖος καί πρῶτος φιλοσοφέω περί φύσις περί ὁ ὑλικός ἀρχή καί ὁ τοιοῦτος αἰτία σκοπέω , τις καί ποιός τις , καί πῶς ἐκ οὗτος γίγνομαι ὁ ὅλος , καί τις κινέω , οἷος νεῖκος τίη φίλιος ἤ ἤ ὁ , ὁ δέ ὕλη τοιόσδε φύσις ἔχω ἐκ ἀνάγκη , οἷος ὁ μέν πῦρ , ὁ δέ γῆ , καί ὁ μέν , ὁ δέ βαρύς .
# 	generalized_context_vector_2:
# 		Example sentence 56 including ',' in typical context 2:
# 			Tokens: οἱ μὲν οὖν ἀρχαῖοι καὶ πρῶτοι φιλοσοφήσαντες περὶ φύσεως περὶ τῆς ὑλικῆς ἀρχῆς καὶ τῆς τοιαύτης αἰτίας ἐσκόπουν, τίς καὶ ποία τις, καὶ πῶς ἐκ ταύτης γίνεται τὸ ὅλον, καὶ τίνος κινοῦντος, οἷον νείκους ἢ φιλίας ἢ υοῦ ἢ τοῦ αὐτομάτου, τῆς δʼ ὑποκειμένης ὕλης τοιάνδε τινὰ φύσιν ἐχούσης ἐξ ἀνάγκης, οἷον τοῦ μὲν πυρὸς θερμὴν, τῆς δὲ γῆς ψυχράν, καὶ τοῦ μὲν κούφην, τῆς δὲ βαρεῖαν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ μέν οὖν ἀρχαῖος καί πρῶτος φιλοσοφέω περί φύσις περί ὁ ὑλικός ἀρχή καί ὁ τοιοῦτος αἰτία σκοπέω , τις καί ποιός τις , καί πῶς ἐκ οὗτος γίγνομαι ὁ ὅλος , καί τις κινέω , οἷος νεῖκος τίη φίλιος ἤ ἤ ὁ , ὁ δέ ὕλη τοιόσδε φύσις ἔχω ἐκ ἀνάγκη , οἷος ὁ μέν πῦρ , ὁ δέ γῆ , καί ὁ μέν , ὁ δέ βαρύς .
# 		Example sentence 299 including ',' in typical context 2:
# 			Tokens: πάσχει δὲ τὸ δυνάμει ὂν ὑπὸ τοῦ ἐνεργείᾳ ὄντος, ὥστʼ ἔστι τὸ αὐτὸ τῷ γένει καὶ ἐκεῖνο ἓν καὶ τοῦτο ἕν, καὶ διὰ τοῦτο χεῖρα μὲν ἢ πρόσωπον ἢ τῶν τοιούτων τι μορίων οὐδεὶς ἐγχειρεῖ λέγειν τῶν φυσιολόγων τὸ μὲν εἶναι γῆν, τὸ δʼ ὕδωρ, τὸ δὲ πῦρ· [LENGTH_MISMATCH]
# 			Lemmas: πάσχω δέ ὁ δύναμις εἰμί ὑπό ὁ ἐνέργεια εἰμί , ὥστε εἰμί ὁ αὐτός τῷ γένος καί ἐκεῖνος καί οὗτος , καί διά οὗτος χείρ μέν τίη πρόσωπον ἤ ὁ τοιοῦτος τι μόριον λέγω ὁ φυσιολόγος ὁ μέν εἰμί γῆ , ὁ δέ ὕδωρ , ὁ δέ πῦρ ·
# 		Example sentence 56 including ',' in typical context 2:
# 			Tokens: οἱ μὲν οὖν ἀρχαῖοι καὶ πρῶτοι φιλοσοφήσαντες περὶ φύσεως περὶ τῆς ὑλικῆς ἀρχῆς καὶ τῆς τοιαύτης αἰτίας ἐσκόπουν, τίς καὶ ποία τις, καὶ πῶς ἐκ ταύτης γίνεται τὸ ὅλον, καὶ τίνος κινοῦντος, οἷον νείκους ἢ φιλίας ἢ υοῦ ἢ τοῦ αὐτομάτου, τῆς δʼ ὑποκειμένης ὕλης τοιάνδε τινὰ φύσιν ἐχούσης ἐξ ἀνάγκης, οἷον τοῦ μὲν πυρὸς θερμὴν, τῆς δὲ γῆς ψυχράν, καὶ τοῦ μὲν κούφην, τῆς δὲ βαρεῖαν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ μέν οὖν ἀρχαῖος καί πρῶτος φιλοσοφέω περί φύσις περί ὁ ὑλικός ἀρχή καί ὁ τοιοῦτος αἰτία σκοπέω , τις καί ποιός τις , καί πῶς ἐκ οὗτος γίγνομαι ὁ ὅλος , καί τις κινέω , οἷος νεῖκος τίη φίλιος ἤ ἤ ὁ , ὁ δέ ὕλη τοιόσδε φύσις ἔχω ἐκ ἀνάγκη , οἷος ὁ μέν πῦρ , ὁ δέ γῆ , καί ὁ μέν , ὁ δέ βαρύς .
#
#
# ὅμοιος (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 58 including 'ὅμοιος' in typical context 0:
# 			Tokens: ὁμοίως δὲ καὶ περὶ τὴν τῶν ζῴων καὶ τῶν φυτῶν γένεσιν λέγουσιν, οἷον ὅτι ἐν τῷ σώματι ῥέοντος μὲν τοῦ ὕδατος κοιλίαν γενέσθαι καὶ πᾶσον ὑποδοχὴν τῆς τε τροφῆς καὶ τοῦ περιττώματος, τοῦ δὲ πνεύματος διαπορευθέντος τοὺς μυκτῆρας ἀναρραγῆναι. [LENGTH_MISMATCH]
# 			Lemmas: ὅμοιος δέ καί περί ὁ ὁ ζῷον καί ὁ γένεσις λέγω , οἷος ὅτι ἐν ὁ σῶμα ῥέω μέν ὁ ὕδωρ κοιλία γίγνομαι καί ὑποδοχή ὁ τε τροφή καί ὁ περίσσωμα , ὁ δέ πνεῦμα ὁ μυκτήρ .
# 		Example sentence 673 including 'ὅμοιος' in typical context 0:
# 			Tokens: ὁμοίως δὲ καὶ τῶν τετραπόδων τὰ ῴοτόκα καὶ φολιδωτά· [LENGTH_MISMATCH]
# 			Lemmas: ὅμοιος δέ καί ὁ τετράπους ὁ καί ·
# 		Example sentence 558 including 'ὅμοιος' in typical context 0:
# 			Tokens: ἔχει δʼ ὁμοίως ἥ τε τῶν ὀστῶν καὶ ἡ τῶν φλεβῶν φύσις. [LENGTH_MISMATCH]
# 			Lemmas: ἔχω δέ ὅμοιος ὁ τε ὁ καί ὁ ὁ φύσις .
#
#
# γε (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 612 including 'γε' in typical context 0:
# 			Tokens: πἀσι γὰρ τοῖς ζῴοις καὶ τελείοις δύο τὰ ἀναγκαιὸτατα μὸρια ἐστιν, ᾖ τε δέχονται τὴν τροφὴν καὶ ᾖ τὸ περίττωμα ἀφήσουσιν· [LENGTH_MISMATCH]
# 			Lemmas: γάρ ὁ καί τέλειος γε ὁ εἰμί , εἰμί τε δέχομαι ὁ τροφή καί εἰμί ὁ περίσσωμα ·
# 		Example sentence 662 including 'γε' in typical context 0:
# 			Tokens: ὦτά τε γὰρ δύο καὶ ὄμματα καὶ ἡ τῶν μυκτήρων δύναμις διφυής ἐστιν.
# 			Lemmas: τε γάρ γε καί ὄμμα καί ὁ ὁ μυκτήρ δύναμις διφυής εἰμί .
#
#
# φαίνω (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 788 including 'φαίνω' in typical context 0:
# 			Tokens: οὐ φαίνονται δʼ οἱ πλεῖστοι ἀητῶν ἔχειν διά τινʼ αἰτίαν εὔλογον· [LENGTH_MISMATCH]
# 			Lemmas: οὐ φαίνω δέ ὁ πλεῖστος ἔχω διά αἰτία εὔλογος ·
# 		Example sentence 668 including 'φαίνω' in typical context 0:
# 			Tokens: οὐκ ἔχει δέ, ἀλλὰ φαίνεται διὰ τὸ μὴ ὀρθὰ εἶναι τὰ ζῷα ἀλλὰ κύπτειν. [LENGTH_MISMATCH]
# 			Lemmas: οὐ ἔχω δέ , ἀλλά φαίνω διά ὁ μή εἰμί ὁ ζῷον ἀλλά κύπτω .
#
#
# τρόπος (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 133 including 'τρόπος' in typical context 0:
# 			Tokens: τού ἐντὸς δὲ θερμοῦ ἀντικόπτοντος ἐν τῇ ψύξει τού θύραθεν ἀέρος ἡ εἴσοδος καὶ ἡ ἔξοδσς ὁ μὲν οὖν τρόπος οὗτος ὁ τῆς μεθόδου, καὶ περὶ ὧν δεῖ λαβεῖν τὰς αἰτίας, ταύτα καὶ τοιαῦτά ἐστιν. [LENGTH_MISMATCH]
# 			Lemmas: ἐντός δέ θέρμος ἀντικόπτω ἐν ὁ ψῦξις θύρα ἀήρ ὁ εἴσοδος καί ὁ ὁ μέν οὖν τρόπος οὗτος ὁ ὁ μέθοδος , καί περί ὅς δέω λαμβάνω ὁ αἰτία , καί εἰμί .
# 		Example sentence 320 including 'τρόπος' in typical context 0:
# 			Tokens: πρῶτον μὲν οὖν καὶ τοῖς ὑγροῖς μορίοις καὶ τοῖς ξηροῖς πολλοὶ τρόποι τῆς αἰτίας εἰσίν. [LENGTH_MISMATCH]
# 			Lemmas: πρῶτος μέν οὖν καί ὁ μόριος καί ὁ πολύς τρόπος ὁ αἰτία εἰμί .
# 		Example sentence 29 including 'τρόπος' in typical context 0:
# 			Tokens: ἀλλʼ ὁ τρόπος τῆς ἀποδείξεως καὶ τῆς ἀνάγκης ἕτερος ἐπί τε τῆς φυσικῆς καὶ τῶν θεωρητικῶν ἐπιστημῶν.
# 			Lemmas: ὁ τρόπος ὁ ἀπόδειξις καί ὁ ἀνάγκη ἕτερος ἐπί τε ὁ φυσικός καί ὁ θεωρητικός ἐπιστήμη .
#
#
# ὁ (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 811 including 'ὁ' in typical context 0:
# 			Tokens: ἔτι δʼ οἱ τʼ οἱστροι καὶ οἱ μύωπες οἱ μὲν τὰ τῶν ἀνθρύόπων οἱ δὲ καὶ τὰ τῶν ἅλλων ζῷόων δέρματα διαιρούσιν. [LENGTH_MISMATCH]
# 			Lemmas: ἔτι δέ ὁ καί ὁ ὁ μέν ὁ ὁ ὁ δέ καί ὁ ὁ ἄλλος δέρμα .
# 		Example sentence 811 including 'ὁ' in typical context 0:
# 			Tokens: ἔτι δʼ οἱ τʼ οἱστροι καὶ οἱ μύωπες οἱ μὲν τὰ τῶν ἀνθρύόπων οἱ δὲ καὶ τὰ τῶν ἅλλων ζῷόων δέρματα διαιρούσιν. [LENGTH_MISMATCH]
# 			Lemmas: ἔτι δέ ὁ καί ὁ ὁ μέν ὁ ὁ ὁ δέ καί ὁ ὁ ἄλλος δέρμα .
# 		Example sentence 811 including 'ὁ' in typical context 0:
# 			Tokens: ἔτι δʼ οἱ τʼ οἱστροι καὶ οἱ μύωπες οἱ μὲν τὰ τῶν ἀνθρύόπων οἱ δὲ καὶ τὰ τῶν ἅλλων ζῷόων δέρματα διαιρούσιν. [LENGTH_MISMATCH]
# 			Lemmas: ἔτι δέ ὁ καί ὁ ὁ μέν ὁ ὁ ὁ δέ καί ὁ ὁ ἄλλος δέρμα .
#
#
# εἰμί (3 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 406 including 'εἰμί' in typical context 0:
# 			Tokens: ἐπεὶ δὲ πάσης τροφῆς ἐστί τι δεκτικὸν καὶ τῶν γινομένων περιττωμάτων, αἱ δὲ φλέβες οἷον ἀγγεῖον αἵματός εἰσι, φανερὸν ὅτι τὸ αἷμα ἡ τελευταία τροφὴ τοῖς ζῴοις τοῖς ἐναίμοις ἐστί, τοῖς δʼ ἀυαίμοις τὸ ἀνάλογον.
# 			Lemmas: ἐπεί δέ πᾶς τροφή εἰμί τις δεκτικός καί ὁ περίσσωμα , ὁ δέ φλέψ οἷος ἀγγεῖον αἷμα εἰμί , φανερός ὅτι ὁ αἷμα ὁ τελευταῖος τροφή ὁ ὁ εἰμί , ὁ δέ ὁ ἀνάλογος .
# 		Example sentence 597 including 'εἰμί' in typical context 0:
# 			Tokens: σύνεγγυς δὲ κατὰ τὴν ἁρήν ἐστι τοῖς ὀστοῖς καὶ τὰ τοιάδε τῶν μορίων οἷον ὄνυχές τε καὶ ὁπλαὶ καὶ χηλαὶ καὶ κέρατα καὶ ῥύγχη τὰ τῶν ἀρνίθωυ. [LENGTH_MISMATCH]
# 			Lemmas: σύνεγγυς δέ κατά ὁ εἰμί ὁ καί ὁ τοιόσδε ὁ μόριον οἷος τε καί ὁπλή καί καί κέρας καί ῥύγχος ὁ ὁ .
# 		Example sentence 754 including 'εἰμί' in typical context 0:
# 			Tokens: ὑπὸ δὲ τοὺς μυκτῆρας ἡ τῶν χειλῶν ἐστὶ φύσις τοῖς ἔχουσι τῶν ἐναίμων ὀδόντας.
# 			Lemmas: ὑπό δέ ὁ μυκτήρ ὁ ὁ εἰμί φύσις ὁ ἔχω ὁ ἔναιμος ὀδούς .
# 	generalized_context_vector_1:
# 		Example sentence 200 including 'εἰμί' in typical context 1:
# 			Tokens: αὕτη δʼ ἐστὶν τὸ σχιζόπουν μόνον, ἢ πάσα ἡ σύμπλεξις, ἐὰν διαιρῆται ἅνθρωπον, οἷον εἴ τις συνθείη ὑπόπουν, δίπουν, σχιζόπουν. [LENGTH_MISMATCH]
# 			Lemmas: οὗτος δέ εἰμί ὁ μόνος , ἤ πάσσω ὁ , ἐάν διαιρέω , οἷος εἰ τις , , .
# 		Example sentence 540 including 'εἰμί' in typical context 1:
# 			Tokens: μόνον γὰρ ἤ μάλιστα τούτʼ ἐστὶ σωματῶδες τῶν αἰσθητηρίων. [LENGTH_MISMATCH]
# 			Lemmas: μόνος γάρ ἤ μάλιστα εἰμί ὁ αἰσθητήριον .
# 		Example sentence 369 including 'εἰμί' in typical context 1:
# 			Tokens: ἴσως γὰρ τὸ ὑποκείμενόν ἐστιν ἢ καπνὸς ἢ ἄνθραξ, ὧν τὸ μὲν ἀεὶ θερμὸν( ἀναθυμίασις γὰρ ὁ καπνός), ὁ δʼ ἄνθραξ ἀποσβεσθεὶς ψυχρὸς. [LENGTH_MISMATCH]
# 			Lemmas: ἴσος γάρ ὁ εἰμί τίη καπνός ἤ ἄνθρα , ὅς ὁ μέν ἀεί θερμός ( γάρ ὁ καπνός ) , ὁ δέ ἄνθρα ψυχρός .
# 	generalized_context_vector_2:
# 		Example sentence 775 including 'εἰμί' in typical context 2:
# 			Tokens: ἔν τε τῷ πλατεῖαν εἶναι καὶ τὸ στενήν ἐστιν·
# 			Lemmas: ἐν τε τῷ πλατύς εἰμί καί ὁ εἰμί ·
# 		Example sentence 299 including 'εἰμί' in typical context 2:
# 			Tokens: πάσχει δὲ τὸ δυνάμει ὂν ὑπὸ τοῦ ἐνεργείᾳ ὄντος, ὥστʼ ἔστι τὸ αὐτὸ τῷ γένει καὶ ἐκεῖνο ἓν καὶ τοῦτο ἕν, καὶ διὰ τοῦτο χεῖρα μὲν ἢ πρόσωπον ἢ τῶν τοιούτων τι μορίων οὐδεὶς ἐγχειρεῖ λέγειν τῶν φυσιολόγων τὸ μὲν εἶναι γῆν, τὸ δʼ ὕδωρ, τὸ δὲ πῦρ· [LENGTH_MISMATCH]
# 			Lemmas: πάσχω δέ ὁ δύναμις εἰμί ὑπό ὁ ἐνέργεια εἰμί , ὥστε εἰμί ὁ αὐτός τῷ γένος καί ἐκεῖνος καί οὗτος , καί διά οὗτος χείρ μέν τίη πρόσωπον ἤ ὁ τοιοῦτος τι μόριον λέγω ὁ φυσιολόγος ὁ μέν εἰμί γῆ , ὁ δέ ὕδωρ , ὁ δέ πῦρ ·
# 		Example sentence 494 including 'εἰμί' in typical context 2:
# 			Tokens: διὸ καὶ συνεχὴς ὁ ῥαχίτης τῷ ἐγκεφάλῳ ἐστίν·
# 			Lemmas: διό καί συνεχής ὁ τῷ ἐγκέφαλος εἰμί ·
#
#
# ὅς (2 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 257 including 'ὅς' in typical context 0:
# 			Tokens: ὁμοίως δὲ κἂν εἴ τινες πρότεραι καὶ τέλος ἑτέρων πράξεων τυγχάνουσιν οὖσαι, τὸν αὐτὸν ἕξει τρόπον καὶ τῶν μορίων ἕκαστον, ὧν αἱ πράξεις αἱ τοιαῦται· [LENGTH_MISMATCH]
# 			Lemmas: ὅμοιος δέ εἰ τις πρότερος καί τέλος ἕτερος πρᾶξις τυγχάνω εἰμί , ὁ αὐτός ἔχω τρόπος καί ὁ μόριος ἕκαστος , ὅς ὁ πρᾶξις ὁ τοιοῦτος ·
# 		Example sentence 245 including 'ὅς' in typical context 0:
# 			Tokens: καὶ τοῖς μὲν αἷμα, τοῖς δὲ τὸ ἀνάλογον τὴν αὐτὴν ἔχον δύναμιν ἥνπερ τοῖς ἐναίμοις τὸ αἷμα. [LENGTH_MISMATCH]
# 			Lemmas: καί ὁ μέν αἷμα , ὁ δέ ὁ ἀνάλογος ὁ αὐτός ἔχω δύναμις ὅς ὁ ὁ αἷμα .
# 		Example sentence 564 including 'ὅς' in typical context 0:
# 			Tokens: ἀρχὴ δὲ τῶν μὲν φλεβῶν ἡ καρδία, τῶν δʼ ὀστῶν ἡ καλουμένη ῥάχις τοῖς ἔχουσιν ὀστᾶ πόσιν, ἀφοʼ ἧς συνεχὴς ἡ τῶν ἄλλων ὀστῶν ἐστὶ φύσις· [LENGTH_MISMATCH]
# 			Lemmas: ἀρχή δέ ὁ μέν ὁ καρδία , ὁ δέ ὁ καλέω ῥάχις ὁ ἔχω πόσις , ὅς συνεχής ὁ ὁ ἄλλος εἰμί φύσις ·
# 	generalized_context_vector_1:
# 		Example sentence 651 including 'ὅς' in typical context 1:
# 			Tokens: ἔχει δʼ ἐν τᾧ ἔμπροσθεν τὸν ἐγκέφαλον πάντα τὰ ἔχοντα τούτο τὸ μόριον, διὰ τὸ ἔμπροσθεν εἶναι ἑο ὅ αἰσθάνεται, τὴν δʼ αἴσθησιν ἀπὸ τῆς καρδίας, ταύτην δʼ εἶναι ἐν τσῖς ἔμπροσθεν, καὶ τὸ αίσθάνεσθαι διὰ τῶν ἐναίμων γίνεσθαι μορίων, φλεβῶν δʼ εἶναι κενὸν τὸ ὄπισθεν κύτος. [LENGTH_MISMATCH]
# 			Lemmas: ἔχω δέ ἐν ἔμπροσθεν ὁ ἐγκέφαλος πᾶς ὁ ἔχω ὁ μόριον , διά ὁ ἔμπροσθεν εἰμί ὅς , ὁ δέ ἀπό ὁ καρδία , οὗτος δέ εἰμί ἐν ἔμπροσθεν , καί ὁ διά ὁ ἔναιμος γίγνομαι μόριον , δέ εἰμί ὁ ὄπισθεν κύτος .
# 		Example sentence 794 including 'ὅς' in typical context 1:
# 			Tokens: σύγκειται γὰρ ἐκ τῆς συμψαύσεωος τῶν βραγχίων, ὧν ἡ φύσις άκανθύδης ἐστίν. [LENGTH_MISMATCH]
# 			Lemmas: σύγκειμαι γάρ ἐκ ὁ ὁ , ὅς ὁ φύσις εἰμί .
# 		Example sentence 527 including 'ὅς' in typical context 1:
# 			Tokens: πρὸς σὖν πολλὴν θερμὸτητα ἀντίκειται πλεέων ὑγρότης καὶ ψυχρότης, καὶ διὰ τὸ πλῆθς ὀψιαίτατα πήγνυται τὸ περὶ τὴν κεφαλὴν ὀσουν, ὃ καλοῦσι βρέγμα τινές, διὰ τὸ πολὺν νον τὸ θερμὸν ἀπατμίζειν· [LENGTH_MISMATCH]
# 			Lemmas: πρός πολύς ἀντίκειμαι καί , καί διά ὁ πήγνυμι ὁ περί ὁ κεφαλή , ὅς καλέω βρέγμα , διά ὁ πολύς ὁ θερμός ·
#
#
# μέν (2 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 811 including 'μέν' in typical context 0:
# 			Tokens: ἔτι δʼ οἱ τʼ οἱστροι καὶ οἱ μύωπες οἱ μὲν τὰ τῶν ἀνθρύόπων οἱ δὲ καὶ τὰ τῶν ἅλλων ζῷόων δέρματα διαιρούσιν. [LENGTH_MISMATCH]
# 			Lemmas: ἔτι δέ ὁ καί ὁ ὁ μέν ὁ ὁ ὁ δέ καί ὁ ὁ ἄλλος δέρμα .
# 		Example sentence 584 including 'μέν' in typical context 0:
# 			Tokens: τῶν δʼ ἰχθύων τοῖς μὲν ᾠοτόκοις ἅκανθκ, καὶ τοῖς ὄφεσιν ἀκανθύὸδης ἐστὶν ἡ τῶν ὀστῶν φύσις, πλὴν τοῖς λίαν μεγάλοις· [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ ἰχθύς ὁ μέν , καί ὁ εἰμί ὁ ὁ φύσις , πλήν ὁ λίαν μέγας ·
# 		Example sentence 832 including 'μέν' in typical context 0:
# 			Tokens: ἐπεὶ δὲ τὸ ἄρρεν ίσχυρότερον καὶ θυμικωτερον, τὰ μὲν μόνα τὰ δὲ μἅλλον ἔχει τὰ τοιαῦτα τῶν μορίων. [LENGTH_MISMATCH]
# 			Lemmas: ἐπεί δέ ὁ ἄρσην καί , ὁ μέν ὁ δέ ἔχω ὁ τοιοῦτος ὁ μόριον .
# 	generalized_context_vector_1:
# 		Example sentence 209 including 'μέν' in typical context 1:
# 			Tokens: λέγω δʼ οἷον ὄρνις ὄρνιθος διαφέρει τῷ μᾶλλον ἢ καθʼ ὑπεροχὴν( τὸ μὲν γὰρ μακρόπτερον τὸ δὲ βραχύπτερον), ἰχθύες δʼ ὄρνιθος τῷ ἀνάλογον( ὃ γὰρ ἐκείνῳ πτερόν, θατέρῳ λεπίς). [LENGTH_MISMATCH]
# 			Lemmas: λέγω δέ οἷος ὄρνις ὄρνις διαφέρω τῷ μᾶλλον ἤ ὑπεροχή ( ὁ μέν γάρ ὁ δέ ) , ἰχθύς δέ ὄρνις τῷ ( ὁ γάρ ἐκεῖνος πτερόν , ἕτερος ) .
# 		Example sentence 188 including 'μέν' in typical context 1:
# 			Tokens: λέγω δʼ οἷον συμβαίνει τοῖς διαιρουμένοις τὸ μὲν ἄπτερον τὸ δὲ πτερωτόν, πτερωτοῦ δὲ τὸ μὲν ἥμερον τὸ δ᾿ ἄγριον, ἢ τὸ μὲν λευκὸν τὸ δὲ μέλαν· [LENGTH_MISMATCH]
# 			Lemmas: λέγω δέ οἷος συμβαίνω ὁ διαιρέω ὁ μέν ἄπτερος ὁ δέ πτερωτός , δέ ὁ μέν ἥμερος ὁ ἄγριος , ἤ ὁ μέν λευκός ὁ δέ μέλας ·
# 		Example sentence 805 including 'μέν' in typical context 1:
# 			Tokens: ἀλλὰ τὸ μὸριον οὐχ ὅμοιον τούτο πἀσιν, ᾧ τὴν αἴσθησιν ποιοῦνται τῆς τροφῆς, ἀλλὰ τοῖς μὲν ἀπολελυμένον τοῖς δὲ προσπεφυκὸς, ὅσοις μηδὲν ἔργον ὑπάρχει φωνῆς, καὶ τοῖς μὲν σκληρὸν τοῖς δὲ μκλακὸν ἤ σαρκῶδες. [LENGTH_MISMATCH]
# 			Lemmas: ἀλλά ὁ ὅμοιος , ὅς ὁ αἴσθησις ποιέω ὁ τροφή , ἀλλά ὁ μέν ἀπολύω ὁ δέ προσφύω , ὅσος ἔργον ὑπάρχω φωνή , καί ὁ μέν σκληρός ὁ δέ ἤ .
#
#
# καλός (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 2 including 'καλός' in typical context 0:
# 			Tokens: πεπαιδευμένου γάρ ἐστι κατὰ τρόπον τὸ δύνασθαι κρῖναι εὐστόχως τί καλῶς ἢ μὴ καλῶς ἀποδίδωσιν ὁ λέγων.
# 			Lemmas: γάρ εἰμί κατά τρόπος ὁ δύναμαι κρίνω εὔστοχος τίς καλός τίη μή καλός ἀποδίδωμι ὁ λέγω .
# 		Example sentence 2 including 'καλός' in typical context 0:
# 			Tokens: πεπαιδευμένου γάρ ἐστι κατὰ τρόπον τὸ δύνασθαι κρῖναι εὐστόχως τί καλῶς ἢ μὴ καλῶς ἀποδίδωσιν ὁ λέγων.
# 			Lemmas: γάρ εἰμί κατά τρόπος ὁ δύναμαι κρίνω εὔστοχος τίς καλός τίη μή καλός ἀποδίδωμι ὁ λέγω .
#
#
# ἔχω (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 832 including 'ἔχω' in typical context 0:
# 			Tokens: ἐπεὶ δὲ τὸ ἄρρεν ίσχυρότερον καὶ θυμικωτερον, τὰ μὲν μόνα τὰ δὲ μἅλλον ἔχει τὰ τοιαῦτα τῶν μορίων. [LENGTH_MISMATCH]
# 			Lemmas: ἐπεί δέ ὁ ἄρσην καί , ὁ μέν ὁ δέ ἔχω ὁ τοιοῦτος ὁ μόριον .
# 		Example sentence 700 including 'ἔχω' in typical context 0:
# 			Tokens: ἡ δὲ τοῦ βλεφάρου χρὴσις ταχεῖαν καὶ δερματικὴν ἔχει τὴν ἐργασίαν· [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ ὁ ταχύς καί ἔχω ὁ ἐργασία ·
# 		Example sentence 807 including 'ἔχω' in typical context 0:
# 			Tokens: τῶν δʼ ἐντὸμων ζῷων ἔνια μὲν ἐντὸς ἔχει τὸ τοιοὺτον μὸριοον, οἷον τὸ τῶν μυρμήκων γένος, ὡσαύτως δὲ καὶ τῶν ὀστρακοδέρμων πολλα· [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ ἔνιοι μέν ἐντός ἔχω ὁ , οἷος ὁ ὁ μύρμηξ γένος , ὡσαύτως δέ καί ὁ ·
#
#
# δέ (3 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 811 including 'δέ' in typical context 0:
# 			Tokens: ἔτι δʼ οἱ τʼ οἱστροι καὶ οἱ μύωπες οἱ μὲν τὰ τῶν ἀνθρύόπων οἱ δὲ καὶ τὰ τῶν ἅλλων ζῷόων δέρματα διαιρούσιν. [LENGTH_MISMATCH]
# 			Lemmas: ἔτι δέ ὁ καί ὁ ὁ μέν ὁ ὁ ὁ δέ καί ὁ ὁ ἄλλος δέρμα .
# 		Example sentence 883 including 'δέ' in typical context 0:
# 			Tokens: τὰ δὲ χαυλιόδοντα, ὥσπερ καὶ τὸ τῶν ὑῶν γένος, διχαλὸν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ , ὥσπερ καί ὁ ὁ υἱός γένος , .
# 		Example sentence 406 including 'δέ' in typical context 0:
# 			Tokens: ἐπεὶ δὲ πάσης τροφῆς ἐστί τι δεκτικὸν καὶ τῶν γινομένων περιττωμάτων, αἱ δὲ φλέβες οἷον ἀγγεῖον αἵματός εἰσι, φανερὸν ὅτι τὸ αἷμα ἡ τελευταία τροφὴ τοῖς ζῴοις τοῖς ἐναίμοις ἐστί, τοῖς δʼ ἀυαίμοις τὸ ἀνάλογον.
# 			Lemmas: ἐπεί δέ πᾶς τροφή εἰμί τις δεκτικός καί ὁ περίσσωμα , ὁ δέ φλέψ οἷος ἀγγεῖον αἷμα εἰμί , φανερός ὅτι ὁ αἷμα ὁ τελευταῖος τροφή ὁ ὁ εἰμί , ὁ δέ ὁ ἀνάλογος .
# 	generalized_context_vector_1:
# 		Example sentence 197 including 'δέ' in typical context 1:
# 			Tokens: ἀλλὰ παρὰ τὴν λέξινσυμβαίνει δοκεῖν τὴν τελευταίαν μόνην εἶναι διαφοράν, σἷον τὸ πολυσχιδὲς ἢ τὸ δίπουν, τὸ δʼ ὑπόπουν καὶ πολύπουν περίεργα. [LENGTH_MISMATCH]
# 			Lemmas: ἀλλά παρά ὁ δοκέω ὁ μόνος εἰμί διαφορά , ὁ ἤ ὁ δίπους , ὁ δέ καί .
# 		Example sentence 805 including 'δέ' in typical context 1:
# 			Tokens: ἀλλὰ τὸ μὸριον οὐχ ὅμοιον τούτο πἀσιν, ᾧ τὴν αἴσθησιν ποιοῦνται τῆς τροφῆς, ἀλλὰ τοῖς μὲν ἀπολελυμένον τοῖς δὲ προσπεφυκὸς, ὅσοις μηδὲν ἔργον ὑπάρχει φωνῆς, καὶ τοῖς μὲν σκληρὸν τοῖς δὲ μκλακὸν ἤ σαρκῶδες. [LENGTH_MISMATCH]
# 			Lemmas: ἀλλά ὁ ὅμοιος , ὅς ὁ αἴσθησις ποιέω ὁ τροφή , ἀλλά ὁ μέν ἀπολύω ὁ δέ προσφύω , ὅσος ἔργον ὑπάρχω φωνή , καί ὁ μέν σκληρός ὁ δέ ἤ .
# 		Example sentence 620 including 'δέ' in typical context 1:
# 			Tokens: τοιούτο δʼ ἐστὶ τὸ τῶν ἀνθρύπων γένοςʼ ἤ γὰρ μόνον μετέχει τού θείου τῶν ἡμῖν γνωρίμων ζῴων, ἢ μάλιστα πάντων. [LENGTH_MISMATCH]
# 			Lemmas: δέ εἰμί ὁ ὁ ἤ γάρ μόνος μετέχω θεῖος ὁ γνώριμος ζῷον , τίη μάλιστα πᾶς .
# 	generalized_context_vector_2:
# 		Example sentence 299 including 'δέ' in typical context 2:
# 			Tokens: πάσχει δὲ τὸ δυνάμει ὂν ὑπὸ τοῦ ἐνεργείᾳ ὄντος, ὥστʼ ἔστι τὸ αὐτὸ τῷ γένει καὶ ἐκεῖνο ἓν καὶ τοῦτο ἕν, καὶ διὰ τοῦτο χεῖρα μὲν ἢ πρόσωπον ἢ τῶν τοιούτων τι μορίων οὐδεὶς ἐγχειρεῖ λέγειν τῶν φυσιολόγων τὸ μὲν εἶναι γῆν, τὸ δʼ ὕδωρ, τὸ δὲ πῦρ· [LENGTH_MISMATCH]
# 			Lemmas: πάσχω δέ ὁ δύναμις εἰμί ὑπό ὁ ἐνέργεια εἰμί , ὥστε εἰμί ὁ αὐτός τῷ γένος καί ἐκεῖνος καί οὗτος , καί διά οὗτος χείρ μέν τίη πρόσωπον ἤ ὁ τοιοῦτος τι μόριον λέγω ὁ φυσιολόγος ὁ μέν εἰμί γῆ , ὁ δέ ὕδωρ , ὁ δέ πῦρ ·
# 		Example sentence 374 including 'δέ' in typical context 2:
# 			Tokens: ὅσα μὲν οὖν ὕδατος μόνον, ταῦτα πήγνυσι τὸ ψυχρὸν, ὅσα δὲ γῆς, τὸ πῦρ· [LENGTH_MISMATCH]
# 			Lemmas: ὅσος μέν οὖν ὕδωρ μόνος , οὗτος πήγνυμι ὁ ψυχρός , ὅσος δέ γῆ , ὁ πῦρ ·
# 		Example sentence 56 including 'δέ' in typical context 2:
# 			Tokens: οἱ μὲν οὖν ἀρχαῖοι καὶ πρῶτοι φιλοσοφήσαντες περὶ φύσεως περὶ τῆς ὑλικῆς ἀρχῆς καὶ τῆς τοιαύτης αἰτίας ἐσκόπουν, τίς καὶ ποία τις, καὶ πῶς ἐκ ταύτης γίνεται τὸ ὅλον, καὶ τίνος κινοῦντος, οἷον νείκους ἢ φιλίας ἢ υοῦ ἢ τοῦ αὐτομάτου, τῆς δʼ ὑποκειμένης ὕλης τοιάνδε τινὰ φύσιν ἐχούσης ἐξ ἀνάγκης, οἷον τοῦ μὲν πυρὸς θερμὴν, τῆς δὲ γῆς ψυχράν, καὶ τοῦ μὲν κούφην, τῆς δὲ βαρεῖαν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ μέν οὖν ἀρχαῖος καί πρῶτος φιλοσοφέω περί φύσις περί ὁ ὑλικός ἀρχή καί ὁ τοιοῦτος αἰτία σκοπέω , τις καί ποιός τις , καί πῶς ἐκ οὗτος γίγνομαι ὁ ὅλος , καί τις κινέω , οἷος νεῖκος τίη φίλιος ἤ ἤ ὁ , ὁ δέ ὕλη τοιόσδε φύσις ἔχω ἐκ ἀνάγκη , οἷος ὁ μέν πῦρ , ὁ δέ γῆ , καί ὁ μέν , ὁ δέ βαρύς .
#
#
# οἷος (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 544 including 'οἷος' in typical context 0:
# 			Tokens: τὰ μὲν οὗν ἔχει τῶν ζῴων ἐντὸς τὴν τοιαύτην βοήθειαν, ἔυια δὲ τῶν ἀναίμων ἐκτός, ὥσπερ τῶν τε μαλακοαστράκων ἕκαστον, οἷον καρκίνοι καὶ τὸ τῶν καράβων γένος, καὶ τὸ τῶν ὀστρακοδέρμων ὡσαύτως, οἷον τὰ καλούμενα ὄστρεα·
# 			Lemmas: ὁ μέν ἔχω ὁ ζῷον ἐντός ὁ τοιοῦτος βοήθεια , δέ ὁ ἄναιμος ἐκτός , ὥσπερ ὁ τε ἕκαστος , οἷος καί ὁ ὁ γένος , καί ὁ ὁ ὡσαύτως , οἷος ὁ καλέω ὄστρεον ·
# 		Example sentence 154 including 'οἷος' in typical context 0:
# 			Tokens: καὶ ποδότης ὡσαύτως ἡ μὲν πολυσχιδὴς, ἡ δὲ δισχιδής, οἷον τὰ διχαλά, ἡ δʼ ἀσχιδὴς καὶ ἀδιαίρετες, οἷον τὰ μώνυχα. [LENGTH_MISMATCH]
# 			Lemmas: καί ὡσαύτως ὁ μέν , ὁ δέ , οἷος ὁ , ὁ δέ καί , οἷος ὁ μῶνυξ .
# 		Example sentence 477 including 'οἷος' in typical context 0:
# 			Tokens: ἐπεὶ δὲ τὴν μὲν τῶν ὀστῶν ἀναγκη φύσιν ὑπάρχειν τοῖς ζῴοις,ὴ τὸ ἀνάλογον τοῖς ὀστοῖς, οἷον τοῖς ἐνύδροις τὴν ἅκανθαν, ἀναγκαῖον ἐνίοις ὑπάρχει καὶ μυελόν, ἐμπεριλαμβανομένης τῆς τροφῆς ἐξ ἧς γίνεται τὰ ὀστᾶ.
# 			Lemmas: ἐπεί δέ ὁ μέν ὁ ὀστέον φύσις ὑπάρχω ὁ , ὴ ὁ ἀνάλογος ὁ , οἷος ὁ ὁ , ἀναγκαῖον ἔνιοι ὑπάρχω καί μυελός , ὁ τροφή ἐκ ὅς γίγνομαι ὁ ὀστέον .
#
#
# τις (2 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 249 including 'τις' in typical context 0:
# 			Tokens: ἐπεὶ δὲ τὸ μὲν ὄργανον πᾶν ἕνεκά του, τῶν δὲ τοῦ σώματος μορίων ἕκαστον ἕνεκά του, τὸ δʼ οὗ ἕνεκα πρᾶξίς τις, φανερὸν ὅτι καὶ τὸ σύνολον σῶμα συνέστηκε πράξεος τινος ἕνεκα πλήρους. [LENGTH_MISMATCH]
# 			Lemmas: ἐπεί δέ ὁ μέν ὄργανον πᾶς ἕνεκα τις , ὁ δέ ὁ σῶμα μόριος ἕκαστος ἕνεκα , ὁ δέ οὗ ἕνεκα πρᾶξις τις , φανερός ὅτι καί ὁ σύνολος σῶμα συνίστημι τις ἕνεκα .
# 		Example sentence 806 including 'τις' in typical context 0:
# 			Tokens: διὸ καὶ τοῖς μαλακοστράκοις, οἷον καράέβοις καὶ τοῖς τοιούτοις, ἐντὸς ὑπάρχει τι τοῦ στὸματος τοιοῦτον, καὶ τοῖς μαλακίοις, οἷον σηπίαις καὶ πολύποσιν.
# 			Lemmas: διό καί ὁ , οἷος καί ὁ τοιοῦτος , ἐντός ὑπάρχω τις ὁ τοιοῦτος , καί ὁ , οἷος σηπία καί .
# 		Example sentence 572 including 'τις' in typical context 0:
# 			Tokens: ὧσπερ γὰρ οἱ πλάττοντες ἐκ πηλού ζῷον ἥ τινος ἄλλης ὑγρᾶς συστάσεως ὑφιστἀσι τῶν στερεᾳν τι σωμάτωον, εἶθʼ οὕτω περιπλάττουσε, τὸν αὐτὸν τρόπον ἡ φύσις δεδνηιούργηχεν ἐκ τῶν σαρκῶν τὸ ζῷον. [LENGTH_MISMATCH]
# 			Lemmas: γάρ ὁ πλάσσω ἐκ ζῷον ὁ ἄλλος σύστασις ὁ τις , οὕτως , ὁ αὐτός τρόπος ὁ φύσις ἐκ ὁ ὁ ζῷον .
# 	generalized_context_vector_1:
# 		Example sentence 276 including 'τις' in typical context 1:
# 			Tokens: πᾶν γὰρ τὸ γινόμενον ἔκ τινος καὶ εἰς τι ποιεῖται τὴν γένεσιν, καὶ ἀπʼ ἀρχῆς ἐπʼ ἀρχὴν, ἀπὸ τῆς πρώτης κινούσης καὶ ἐχούσης ἤδη τινὰ φύσιν ἐπί τινα μορφὴν ἢ τοιοῦτον ἄλλο τέλος· [LENGTH_MISMATCH]
# 			Lemmas: πᾶς γάρ ὁ ἐκ τις καί εἰς τις ποιέω ὁ γένεσις , καί ἀρχή ἐπί ἀρχή , ἀπό ὁ πρῶτος καί ἔχω ἤδη φύσις ἐπί μορφή ἤ τοιοῦτος ἄλλος τέλος ·
# 		Example sentence 276 including 'τις' in typical context 1:
# 			Tokens: πᾶν γὰρ τὸ γινόμενον ἔκ τινος καὶ εἰς τι ποιεῖται τὴν γένεσιν, καὶ ἀπʼ ἀρχῆς ἐπʼ ἀρχὴν, ἀπὸ τῆς πρώτης κινούσης καὶ ἐχούσης ἤδη τινὰ φύσιν ἐπί τινα μορφὴν ἢ τοιοῦτον ἄλλο τέλος· [LENGTH_MISMATCH]
# 			Lemmas: πᾶς γάρ ὁ ἐκ τις καί εἰς τις ποιέω ὁ γένεσις , καί ἀρχή ἐπί ἀρχή , ἀπό ὁ πρῶτος καί ἔχω ἤδη φύσις ἐπί μορφή ἤ τοιοῦτος ἄλλος τέλος ·
#
#
# γάρ (5 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 21 including 'γάρ' in typical context 0:
# 			Tokens: ἢ γὰρ τῇ διανοίᾳ, ἢ τῇ αἰσθήσει ὁρισάμενος ὁ μὲν ἰατρὸς τὴν ὑγίειαν, ὁ δʼ οἰκοδόμος τὴν οἰκίαν, ἀποδιδόασι τοὺς λόγους καὶ τὰς αἰτίας σὗ ποιοῦσιν ἑκά στου, καὶ διότι ποιητέον οὕτως. [LENGTH_MISMATCH]
# 			Lemmas: τίη γάρ ὁ διάνοια , ἤ ὁ αἴσθησις ὁρίζω ὁ μέν ἰατρός ὁ ὑγίεια , ὁ δέ οἰκοδόμος ὁ οἰκία , ὁ λόγος καί ὁ αἰτία ποιέω , καί διότι ποιέω οὕτως .
# 		Example sentence 32 including 'γάρ' in typical context 0:
# 			Tokens: ἐπεὶ γὰρ τοιόνδʼ ἐστὶν ἡ ὑγίεια ἢ ὁ ἅνθρωπος, ἀνάγκη τόδʼ εἶναι ἢ γενέσθαι, ἀλλʼ οὐκ ἐπεὶ τόδʼ ἐστὶν ἢ γέγονεν, ἐκεῖνο ἐξ ἀνάγκης ἐστὶν ἢ ἔσται.
# 			Lemmas: ἐπεί γάρ εἰμί ὁ ὑγίεια ἤ ὁ ἄνθρωπος , ἀνάγκη εἰμί τίη γίγνομαι , ἀλλά οὐ ὅδε εἰμί τίη γίγνομαι , ἐκεῖνος ἐκ ἀνάγκη εἰμί ἤ .
# 		Example sentence 540 including 'γάρ' in typical context 0:
# 			Tokens: μόνον γὰρ ἤ μάλιστα τούτʼ ἐστὶ σωματῶδες τῶν αἰσθητηρίων. [LENGTH_MISMATCH]
# 			Lemmas: μόνος γάρ ἤ μάλιστα εἰμί ὁ αἰσθητήριον .
# 	generalized_context_vector_1:
# 		Example sentence 565 including 'γάρ' in typical context 1:
# 			Tokens: ἡ γὰρ τὸ μὴκρς καὶ τὴν ὁρθὸτητα συνέχουσα τῶν ζῷόων ἡ ῥάχις ἐστίν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ γάρ ὁ καί ὁ συνέχω ὁ ὁ ῥάχις εἰμί .
# 		Example sentence 507 including 'γάρ' in typical context 1:
# 			Tokens: ἐπεὶ δʼ ἅμαντα δεῖται τὴς ἐναντίας ῥοπῆς, ἵνα τυγχάνῃ τοῦ μετρίου καὶ τού μέσου( τὴν γὰρ οὐσίαν ἔχει τοῦτο καὶ τὸν λόγον, τῶν δʼ ἄκρων ἑκάτερον οὐκ ἔχει χωρίς), διὰ ταύτην τὴν αἰτίαν πρὸς τὸν της καρδίας τόπον καὶ τὴν ἐν αὐτῇ θερμότητα μεμηχάνηται τὸν ἐγκέφαλον ἡ φύσις, καὶ τούτου χαέριν ὑπάρχει τοῦτο τὸ μόριον τοῖς ζῴοις, τὴν φύσιν ἔχον κοινὴν ὕδατος καὶ γῆς, καὶ διὰ τοῦτο τὰ ἔναιμα ἔχει πάντα ἐγκέφαλον, τῶν δʼ ἄλλων οὐδὲν ὡς εἰπεῖν, πλὴν ὅτι κατὰ τὸ ἀνάλογον, οἷον ὁ πολύπους· [LENGTH_MISMATCH]
# 			Lemmas: ἐπεί δέ δέω ἐναντίος ῥοπή , ἵνα τυγχάνω ὁ μέτριος καί ὁ μέσης ( ὁ γάρ οὐσία ἔχω οὗτος καί ὁ λόγος , ὁ δέ ἄκρον ἑκάτερος οὐ ἔχω χωρίς ) , διά οὗτος ὁ αἰτία πρός ὁ καρδία τόπος καί ὁ ἐν αὐτός θερμότης μηχανάομαι ὁ ἐγκέφαλος ὁ φύσις , καί οὗτος ὑπάρχω οὗτος ὁ μόριον ὁ , ὁ φύσις ἔχω κοινός ὕδωρ καί γῆ , καί διά οὗτος ὁ ἔναιμος ἔχω πᾶς , ὁ δέ οὐδείς ὡς λέγω , πλήν ὅτι κατά ὁ , οἷος ὁ πολύπους ·
# 		Example sentence 471 including 'γάρ' in typical context 1:
# 			Tokens: αὐξανομένων δὲ καὶ πεττομένων, καθάπερ καὶ τὰ μὸρια μεταβάλλει καὶ τὰ σπλάγχνα τὰς χρὸας( ὑπερβολῇ γὰρ αίματῶδες καὶ τῶν σπλάγχνων ἕκαστόν ἐστιν ἔτι νέων ὄντων), οὕτω καὶὸ μυελὸς καὶ τῶν μὲν πιμελωδῶν λιπαρὸς καὶ πιμελῇ ὅμοιος, ὅσοις δὲ μὴ πιμελῇ ὅμοιος ἀλλὰ στέαρ γίνεται τὸ αἷμα πεττόμενον, τούτοις ὅὲ στεατωὅης.
# 			Lemmas: αὐξάνω δέ καί πέσσω , καθά καί ὁ μεταβάλλω καί ὁ σπλάγχνον ὁ ( ὑπερβολή γάρ καί ὁ σπλάγχνον ἕκαστος εἰμί ἔτι νέος εἰμί ) , οὕτως καί ὸ μυελός καί ὁ μέν λιπαρός καί πιμελή ὅμοιος , ὅσος δέ μή ὅμοιος ἀλλά στέαρ γίγνομαι ὁ αἷμα , οὗτος .
# 	generalized_context_vector_3:
# 		Example sentence 599 including 'γάρ' in typical context 3:
# 			Tokens: τὰ γὰρ ἐξ οὐτῶν συνεστηκότα ὅλα καὶ συνύνυμα τοῖς μορίοις, οἷον ὁπλή τε ὅλη καὶ κέρας ὅλον,.
# 			Lemmas: ὁ γάρ ἐκ συνίστημι ὅλος καί ὁ μόριος , οἷος ὁπλή τε καί κέρας ὅλος , .
# 		Example sentence 321 including 'γάρ' in typical context 3:
# 			Tokens: τὰ μὲν γὰρ ὡς ὕλη τῶν μερῶν τῶν ἀνομοιομερῶν ἐστίν( ἐκ τούτων γὰρ συνέστηκεν ἕκαστον τῶν ὀργανικῶν μερῶν, ἐξ ὀστῶν καὶ νεύρων καὶ σαρκῶν καὶ ἄλλωον τοιούτων συμβαλλομένων τὰ μὲν εἰς τὴν οὐσίαν τὰ δʼ εἰς τὴν ἐργασίαν), τὰ δὲ τροφὴ τούτοις τῶν ὑγρῶν ἐστί( πάντα γὰρ ἐξ ὑγροῦ λαμβάνει τὴν αὔξησιν), τὰ δὲ περιττωματα συμβέβηκεν εἶναι τούτων, οἷον τὴν τε τῆς ξηρᾶς τροφῆς ὑπόστασιν καὶ τὴν τῆς ὑγρᾶς τοῖς ἔχουσι κύστιν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ μέν γάρ ὡς ὕλη ὁ μέρος ὁ εἰμί ( ἐκ οὗτος γάρ συνίστημι ἕκαστος ὁ μέρος , ἐκ καί καί σάρξ καί τοιοῦτος συμβάλλω ὁ μέν εἰς ὁ οὐσία ὁ δέ εἰς ὁ ἐργασία ) , ὁ δέ τροφή οὗτος ὁ ὑγρός εἰμί ( πᾶς γάρ ἐκ λαμβάνω ὁ αὔξησις ) , ὁ δέ συμβαίνω εἰμί οὗτος , οἷος ὁ τε ὁ ξηρός τροφή ὑπόστασις καί ὁ ὁ ὁ ἔχω κύστις .
# 		Example sentence 293 including 'γάρ' in typical context 3:
# 			Tokens: τὰ μὲν γὰρ ἀνομοιομερῆ ἐκ τῶν ὁμοιομερῶν ἐνδέχεται συνεστάναι, καὶ ἐκ πλειόνων καὶ ἑνὸς, οἷον ἔνια τῶν σπλάγχνων·
# 			Lemmas: ὁ μέν γάρ ἐκ ὁ ἐνδέχομαι συνίστημι , καί ἐκ πολύς καί , οἷος ἔνιοι ὁ σπλάγχνον ·
# 	generalized_context_vector_2:
# 		Example sentence 221 including 'γάρ' in typical context 2:
# 			Tokens: τὰ γὰρ μόρια διαφέρουσι τούτων οὐ τῇ ἀνάλογον ὁμοιότητι, οἷον ἐν ἀνθρώπῳ καὶ ἰχθύι πέπονθεν ὀστοῦν πρὸς ἄκανθαν, ἀλλὰ μᾶλλον τοῖς σωματικοῖς πάθεσιν, οἷον μεγέθει μικρότητι, μαλακότητι σκληρότητι, λειότητι τραχύτητ καὶ τοῖς τοιούτοις, ὅλως δὲ τῷ μᾶλλον καὶ ἧττον. [LENGTH_MISMATCH]
# 			Lemmas: ὁ γάρ μόριον διαφέρω οὗτος οὐ ὁ ἀνάλογος ὁμοιότης , οἷος ἐν ἄνθρωπος καί πρός ἄκανθα , ἀλλά μᾶλλον ὁ σωματικός πάθος , οἷος μέγεθος μικρότης , μαλακότης σκληρότης , λειότης καί ὁ τοιοῦτος , ὅλος δέ τῷ μᾶλλον καί ἥσσων .
# 		Example sentence 250 including 'γάρ' in typical context 2:
# 			Tokens: οὐ γὰρ ἡ πρίσις τοῦ πρίονος χάριν γέγονεν, ἀλλʼ ὁ πρίων τῆς πρίσεως· [LENGTH_MISMATCH]
# 			Lemmas: οὐ γάρ ὁ ὁ πρίων χάρις γίγνομαι , ὁ πρίων ὁ ·
# 		Example sentence 189 including 'γάρ' in typical context 2:
# 			Tokens: οὐ γὰρ διαφορὰ τοῦ πτερωτοῦ τὸ ἥμερον οὐδὲ τὸ λευκόν, ἀλλʼ ἑτέρας ἀρχὴ διαφορᾶς·
# 			Lemmas: οὐ γάρ διαφορά ὁ ὁ ἥμερος οὐδέ ὁ λευκός , ἕτερος ἀρχή διαφορά ·
# 	generalized_context_vector_4:
# 		Example sentence 615 including 'γάρ' in typical context 4:
# 			Tokens: ἐκ τῆς γῆς γὰρ λαμβάνει πεπεμμένην τὴν τροφὴν, ἀντὶ δὲ τούτου προῖεται τὰ σπέρματα καὶ τοὺς καρπούς.
# 			Lemmas: ἐκ ὁ γῆ γάρ λαμβάνω ὁ τροφή , ἀντί δέ οὗτος ὁ σπέρμα καί ὁ καρπός .
# 		Example sentence 401 including 'γάρ' in typical context 4:
# 			Tokens: τὰ μὲν γὰρ φυτὰ λαμβάνει τὴν τροφὴν κατειργασμένην ἐκ τῆς γῆς ταῖς ῥίζαις( διὸ καὶ περίττωμα οὐ γένεται τοῖς φυτοῖς· [LENGTH_MISMATCH]
# 			Lemmas: ὁ μέν γάρ ὁ τροφή ἐκ ὁ γῆ ὁ ῥίζα ( διό καί περίσσωμα οὐ ὁ ·
# 		Example sentence 515 including 'γάρ' in typical context 4:
# 			Tokens: ἀναθυμιωμένης γὰρ ἐκ τῆς γῆς τῆς ἀτμίδος καὶ φερομένης ὑπὸ τού θερμού πρὸς τὸν ἄνω τόπον, ὅταν ἐν τῷ ὑπὲρ ην γῆς γένηται ἀέρι ὄντι ψυχρῷ, συνίσταται πάλιν εἰς ὕδωρ διὰ τὴν ψύξιν καὶ ῥεῖ κάτω πρὸς τὴν γῆν. [LENGTH_MISMATCH]
# 			Lemmas: γάρ ἐκ ὁ γῆ ὁ ἀτμός καί φέρω ὑπό πρός ὁ ἄνω τόπος , ὅταν ἐν τῷ ὑπέρ γῆ γίγνομαι ἀήρ εἰμί , συνίστημι πάλιν εἰς ὕδωρ διά ὁ καί ῥέω κάτω πρός ὁ γῆ .
#
#
# κατά (5 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 597 including 'κατά' in typical context 0:
# 			Tokens: σύνεγγυς δὲ κατὰ τὴν ἁρήν ἐστι τοῖς ὀστοῖς καὶ τὰ τοιάδε τῶν μορίων οἷον ὄνυχές τε καὶ ὁπλαὶ καὶ χηλαὶ καὶ κέρατα καὶ ῥύγχη τὰ τῶν ἀρνίθωυ. [LENGTH_MISMATCH]
# 			Lemmas: σύνεγγυς δέ κατά ὁ εἰμί ὁ καί ὁ τοιόσδε ὁ μόριον οἷος τε καί ὁπλή καί καί κέρας καί ῥύγχος ὁ ὁ .
# 		Example sentence 730 including 'κατά' in typical context 0:
# 			Tokens: τοῖς μὲν οὖν ἄλλοις ζῴοις τοῖς τετράποσι καὶ ζῳοτύκοις οὐ πόρρω τρόπον τινὰ διέστηκεν ἀλλήλων τὸ τῆς ὀσφρήσεως αίσθητήριον, ἀλλʼ ὅσα μὲν ἔχει προμήκεις είς στενὸν ἀπηγμένας τὰς σιαγόνας, ἐν τῷ καλουμένῳ ῥύγχει καὶ τὸ τῶν μυκτήρων ἐνυπαρχε μόριον κατὰ τὸν ἐνδεχόμενον τρόπον, τοῖς δʼ ἄλλοις μᾶλλον διηρθρωμένον ἐστὶ πρὸς τὰς σιαγόνας. [LENGTH_MISMATCH]
# 			Lemmas: μέν οὖν ἄλλος ὁ τετράπους καί οὐ τρόπος διΐστημι ἀλλήλων ὁ ὁ ὄσφρησις , ὅσος μέν ἔχω στενός ἀπάγω ὁ σιαγών , ἐν τῷ καλέω ῥύγχος καί ὁ ὁ μυκτήρ μόριον κατά ὁ τρόπος , ὁ δέ μᾶλλον διαρθρόω εἰμί πρός ὁ σιαγών .
# ...
# 	generalized_context_vector_0:
# 		Example sentence 653 including 'ὄσφρησις' in typical context 0:
# 			Tokens: ἡ δὲ τῆς ὀσφρήσεως μεταξὺ τῶν ὀμμάτων εὐλόγως.
# 			Lemmas: ὁ δέ ὁ ὄσφρησις ὁ ὄμμα εὔλογος .
# 		Example sentence 630 including 'ὄσφρησις' in typical context 0:
# 			Tokens: ὅτι μὲν οὖν ἀρχὴ τῶν αἰσθήσεωόν ἐστιν ὁ περὶ τὴν καρδίαν τόπος, διωρισται πρὸτερον ἐν τοῖς περὶ αἰσθήσεωςςʼ καὶ διότι αἱ μὲν δύο φανερῶς ἠρτημέναι πρὸς τὴν καρδίαν εἰσίν, ἢ τε τῶν ἀπτῶν καὶ ἡ τῶν χυμῶν, τῶν δὲ τριῶν ἡ μὲν τῆς ὀσφρήσεως μέση, ἀκοὴ δὲ καὶ ὄψις μάλιστʼ ἐν τῇ κεφαλῇ διὰ τὴν τῶν αἰσθητηρίων φύσιν εἰσί, καὶ τούτων ἡ ὄψις πᾶσιν, ἐπεὶ ἦ γʼ ἀκοὴ καὶ ἡ ὄσφρησις ἐπὶ τῶν ἐχθύων καὶ τάν τοιούτων ποιεῖ τὸ λεγόμενον φανερόν· [LENGTH_MISMATCH]
# 			Lemmas: ὅτι μέν οὖν ἀρχή ὁ εἰμί ὁ περί ὁ καρδία τόπος , ἐν ὁ περί καί διότι ὁ μέν γε φανερός πρός ὁ καρδία εἰμί , ἤ τε ὁ καί ὁ ὁ χυμός , ὁ δέ ὁ μέν ὁ ὄσφρησις , ἀκοή δέ καί ὄψις ἐν ὁ κεφαλή διά ὁ ὁ αἰσθητήριον φύσις εἰμί , καί οὗτος ὄψις πᾶς , ἐπεί ἦ ἀκοή καί ὁ ὄσφρησις ἐπί ὁ καί ὁ τοιοῦτος ποιέω ὁ λέγω φανερός ·
#
#
# ἀκοή (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 630 including 'ἀκοή' in typical context 0:
# 			Tokens: ὅτι μὲν οὖν ἀρχὴ τῶν αἰσθήσεωόν ἐστιν ὁ περὶ τὴν καρδίαν τόπος, διωρισται πρὸτερον ἐν τοῖς περὶ αἰσθήσεωςςʼ καὶ διότι αἱ μὲν δύο φανερῶς ἠρτημέναι πρὸς τὴν καρδίαν εἰσίν, ἢ τε τῶν ἀπτῶν καὶ ἡ τῶν χυμῶν, τῶν δὲ τριῶν ἡ μὲν τῆς ὀσφρήσεως μέση, ἀκοὴ δὲ καὶ ὄψις μάλιστʼ ἐν τῇ κεφαλῇ διὰ τὴν τῶν αἰσθητηρίων φύσιν εἰσί, καὶ τούτων ἡ ὄψις πᾶσιν, ἐπεὶ ἦ γʼ ἀκοὴ καὶ ἡ ὄσφρησις ἐπὶ τῶν ἐχθύων καὶ τάν τοιούτων ποιεῖ τὸ λεγόμενον φανερόν· [LENGTH_MISMATCH]
# 			Lemmas: ὅτι μέν οὖν ἀρχή ὁ εἰμί ὁ περί ὁ καρδία τόπος , ἐν ὁ περί καί διότι ὁ μέν γε φανερός πρός ὁ καρδία εἰμί , ἤ τε ὁ καί ὁ ὁ χυμός , ὁ δέ ὁ μέν ὁ ὄσφρησις , ἀκοή δέ καί ὄψις ἐν ὁ κεφαλή διά ὁ ὁ αἰσθητήριον φύσις εἰμί , καί οὗτος ὄψις πᾶς , ἐπεί ἦ ἀκοή καί ὁ ὄσφρησις ἐπί ὁ καί ὁ τοιοῦτος ποιέω ὁ λέγω φανερός ·
# 		Example sentence 644 including 'ἀκοή' in typical context 0:
# 			Tokens: ἔχει δὲ καὶ τὴν ἀκοὴν εὐλόγως ἔυια τῶν ζῷόων ἐν τῷ τόπῳ τῷ περὶ τὴν κεφαλήν· [LENGTH_MISMATCH]
# 			Lemmas: ἔχω δέ καί ὁ ἀκοή εὔλογος ὁ ἐν ὁ τόπος τῷ περί ὁ κεφαλή ·
#
#
# ὄμμα (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 653 including 'ὄμμα' in typical context 0:
# 			Tokens: ἡ δὲ τῆς ὀσφρήσεως μεταξὺ τῶν ὀμμάτων εὐλόγως.
# 			Lemmas: ὁ δέ ὁ ὄσφρησις ὁ ὄμμα εὔλογος .
# 		Example sentence 726 including 'ὄμμα' in typical context 0:
# 			Tokens: αἱ δʼ ὀφρύες καὶ αἱ βλεφαρίδες ἀμφότεραι βοηθείας χάριν εἰσίν, αί μὲν ὀφρύες τῶν καταβαινόντων ὑγρῶν, ὅπως ἀποστέγωσιν οἷον ἀπογείσωμα τῶν ἀπὸ τῆς κεφαλῆς ὑγρῶν, αἱ δὲ βλεφαρίδες τῶν πρὸς τὰ ὄμματα προσπιπτόντων ἕνεκεν, οἷον τὰ χαρακώματα ποιοῦσί τινες πρὸ τῶν ἐργμάτων. [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ καί ὁ βλεφαρίς ἀμφότερος βοήθεια χάρις εἰμί , μέν ὁ ὑγρός , ὅπως οἷος ὁ ἀπό ὁ κεφαλή ὑγρός , ὁ δέ βλεφαρίς ὁ πρός ὁ ὄμμα προσπίπτω ἕνεκα , οἷος ὁ χαράκωμα ποιέω τις πρό ὁ ἔργμα .
#
#
# διπλόος (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 785 including 'διπλόος' in typical context 0:
# 			Tokens: διπλῆν γὰρ τὴν ἡδονὴν κτάται τῶν χυμῶν, ὥσπερ διπλῆν ἔχοντα τὴν τῆς γεύσεωος αἴσθησιν.
# 			Lemmas: διπλόος γάρ ὁ ἡδονή ὁ χυμός , ὥσπερ διπλόος ἔχω ὁ ὁ αἴσθησις .
# 		Example sentence 785 including 'διπλόος' in typical context 0:
# 			Tokens: διπλῆν γὰρ τὴν ἡδονὴν κτάται τῶν χυμῶν, ὥσπερ διπλῆν ἔχοντα τὴν τῆς γεύσεωος αἴσθησιν.
# 			Lemmas: διπλόος γάρ ὁ ἡδονή ὁ χυμός , ὥσπερ διπλόος ἔχω ὁ ὁ αἴσθησις .
#
#
# γλῶσσα (2 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 763 including 'γλῶσσα' in typical context 0:
# 			Tokens: τὰ μὲν γὰρ τῆς γλώττης εἰσὶ προσβολαί, τὰ δὲ συμβολαὶ τῶν χειλῶν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ μέν γάρ ὁ γλῶσσα εἰμί προσβολή , ὁ δέ συμβολή ὁ .
# 		Example sentence 801 including 'γλῶσσα' in typical context 0:
# 			Tokens: οἱ δʼ ἰχθύες διὰ τὴν εἰρημένην αίτίαν ἔχουσι μὲν οὐ σαφῆ δʼ ἔχουσι τὴν διάρθρωσιν τῆς γλώττης.
# 			Lemmas: ὁ δέ ἰχθύς διά ὁ λέγω ἔχω μέν οὐ σαφής δέ ἔχω ὁ διάρθρωσις ὁ γλῶσσα .
# 		Example sentence 761 including 'γλῶσσα' in typical context 0:
# 			Tokens: ὥσπερ γὰρ τὴν γλῶτταν οὐχ ὁμοίαν τοῖς ἄλλοις ἐποίησεν ἡ φύσις, πρὸς ἐργασίας δύο καταχρησαμένη, καθάπερ εἴπομεν ποιεῖν αὐτὴν ἐπὶ πολλῶν, , a τὴν μὲν γλῶτταν τῶν τε χυμῶν ἕνεκεν καὶ τοῦ λόγου, τὰ δὲ χείλη τούτου θʼ ἓνεκεν καὶ τῆς τῶν ὀδόνφυλακῆς. [LENGTH_MISMATCH]
# 			Lemmas: ὥσπερ γάρ ὁ γλῶσσα ὅμοιος ὁ ἄλλος ποιέω ὁ φύσις , πρός ἐργασία γε , καθά λέγω ποιέω αὐτός ἐπί πολύς , , ὁ μέν γλῶσσα ὁ τε χυμός ἕνεκα καί ὁ λόγος , ὁ δέ οὗτος καί ὁ ὁ .
# 	generalized_context_vector_1:
# 		Example sentence 812 including 'γλῶσσα' in typical context 1:
# 			Tokens: ἐν μὲν σὖν τούτοις τοῖς ζῷύοις ἡ γλῶττα τοιαύτη τὴν φύσιν ἐστίν, ὥσπερ ἀντιστρόφως ἔχουσα τῷ μυκτῆρι τῷ τῶν ἐλεφάντων·
# 			Lemmas: ἐν μέν οὗτος ὁ ὁ γλῶσσα τοιοῦτος ὁ φύσις εἰμί , ὥσπερ ἀντίστροφος ἔχω τῷ μυκτήρ ὁ ὁ ἐλέφας ·
# 		Example sentence 769 including 'γλῶσσα' in typical context 1:
# 			Tokens: ὑπὸ δὲ τὸν οὐρανὸν ἐν τῷ στόματι ἡ γλῶττα τοῖς ζῴοις ἐστί, τοῖς μὲν πεζοῖς σχεδὸν ὁμοίως πἀσι, τοῖς δʼ ἄλλοις ἀνομοίως καὶ αὐτοῖς πρὸς αὐτὰ καὶ πρὸς τὰ πεζὰ τῶν ζῷόων. [LENGTH_MISMATCH]
# 			Lemmas: δέ ὁ οὐρανός ἐν ὁ στόμα ὁ γλῶσσα ὁ εἰμί , ὁ μέν σχεδόν ὅμοιος , ὁ δέ ἄλλος ἀνόμοιος καί αὐτός πρός αὐτός καί πρός ὁ ὁ .
#
#
# τετράπους (2 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 673 including 'τετράπους' in typical context 0:
# 			Tokens: ὁμοίως δὲ καὶ τῶν τετραπόδων τὰ ῴοτόκα καὶ φολιδωτά· [LENGTH_MISMATCH]
# 			Lemmas: ὅμοιος δέ καί ὁ τετράπους ὁ καί ·
# 		Example sentence 778 including 'τετράπους' in typical context 0:
# 			Tokens: τὰ δʼ ἕναιμα καὶ ζφοτόκα τῶν τετραπόδων βραχεῖαν της ψώνῆς ἔχει διάρθρωσιν· [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ καί ὁ τετράπους βραχύς ἔχω διάρθρωσις ·
# 	generalized_context_vector_1:
# 		Example sentence 676 including 'τετράπους' in typical context 1:
# 			Tokens: καὶ οἱ μὲν ἅνθρωποι καὶ οἱ ὅρυιθες καὶ τὰ ζῳοτόκα καὶ τὰ ᾧοτόκα τῶν τετραπόὅων φυλακὴν ἔχουσι τῆς ὄψεως, τὰ μὲν ζῳοτόκα βλέφαρα δύο, οἷς καὶ σκαρδαμύττουσι, τῶν δʼ ὀρνίθων ἅλλοι τε καὶ οἱ βαρεῖς καὶ τὰ ᾧοτόκα τῶν τετραπόδων τῇ κάτω βλεφαρίδι μύουσιν· [LENGTH_MISMATCH]
# 			Lemmas: καί ὁ μέν ἄνθρωπος καί ὁ καί ὁ καί ὁ ὁ φυλακή ἔχω ὁ ὄψις , ὁ μέν βλέφαρον γε , ὅς καί , ὁ δέ ὄρνις τε καί ὁ βαρύς καί ὁ ὁ τετράπους ὁ κάτω μυέω ·
# 		Example sentence 683 including 'τετράπους' in typical context 1:
# 			Tokens: τῶν δʼ ἀρνίθεν ὅσοι τῇ κάτω βλεφαρίδι μύουσι, καὶ τὰ ᾧοτόκα τῶν τετραπόδων, διὰ τὴν σκληρότητα τού δέρματος τού περὶ τὴν κεφαλὴν οὕτω μύουσιν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ ὅσος ὁ κάτω , καί ὁ ὁ τετράπους , διά ὁ σκληρότης δέρμα περί ὁ κεφαλή οὕτως μυέω .
# 		Example sentence 864 including 'τετράπους' in typical context 1:
# 			Tokens: τοιούτῳ γὰρ ὄντι ῥᾳδίως δύνατʼ ὀρύσσειν, ὥσπερ καὶ τῶν τετραπόδων τὸ τῆς ὑός· [LENGTH_MISMATCH]
# 			Lemmas: τοιοῦτος γάρ εἰμί ῥᾴδιος ὀρύσσω , ὥσπερ καί ὁ τετράπους ὁ ὁ ὗς ·
#
#
# βίος (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 862 including 'βίος' in typical context 0:
# 			Tokens: τῶν δʼ ἄλλων ἑκάστῳ πρὸς τὸν βίον χρήσιμόν ἐστι τὸ ῥύγχος, οἷον τοῖς μὲν δρυοκόποις ίσχυρὸν καὶ σκληρόν, καὶ κὸραξι καὶ κορακύδεσι, τοῖς δὲ μικροῖς γλαφυρὸν πρὸς τὰς συλλογὰς τῶν καρπῶν καὶ τὰς λήψεις τῶν ζφδαρίων. [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ ἄλλος ἕκαστος πρός ὁ βίος χρήσιμος εἰμί ὁ ῥύγχος , οἷος ὁ μέν καί σκληρός , καί καί , ὁ δέ μικρός γλαφυρός πρός ὁ συλλογή ὁ καί ὁ λῆψις ὁ .
# 		Example sentence 906 including 'βίος' in typical context 0:
# 			Tokens: οὕτω γὰρ καὶ τὰ κέρατα ἔχοντα πρὸς ἀλκήν τε χρησιμύτατʼ εἶναι καὶ πρὸς τὸν ἄλλον βίον ἀνοχλὸτατα. [LENGTH_MISMATCH]
# 			Lemmas: οὕτως γάρ καί ὁ κέρας ἔχω πρός ἀλκή τε εἰμί καί πρός ὁ ἄλλος βίος .
#
#
# καταχράομαι (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 915 including 'καταχράομαι' in typical context 0:
# 			Tokens: τὴν γοῦν τοιούτου σώματος περιττωματικὴν ὑπερβολὴν ἐν τοῖς μείζοσι τῶν ζῷων ὑπἀρχουσαν ἐπὶ βοήθειαν καὶ τὸ συμφέρον καταχρῆται ἡ φύσις, καὶ τὴν ῥέουσαν ἐξ ἀναγκης είς τὸν ἄνω τόπον τοῖς μὲν εἰς ὀδόντας καὶ χαυλιόδοντας ἀπένειμε, τοῖς δʼ εἰς κέρατα. [LENGTH_MISMATCH]
# 			Lemmas: ὁ γοῦν τοιοῦτος σῶμα ὑπερβολή ἐν ὁ μέγας ὁ ἐπί βοήθεια καί ὁ συμφέρω καταχράομαι ὁ φύσις , καί ὁ ῥέω ἐκ ὁ ἄνω τόπος ὁ μέν εἰς ὀδούς καί ἀπονέμω , ὁ δέ εἰς κέρας .
# 		Example sentence 744 including 'καταχράομαι' in typical context 0:
# 			Tokens: ἀφῃρημένης δὲ τῆς τῶν ποδῶν χρήσεως, καὶ ἡ φύσις, ὥσπερ εἴπομεν, καταχρῆται καὶ πρὸς τὴν ἀπὸ τῶν ποδῶν γινομένην ἂν βοήθειαν τούτῳ τῷ μορίῳ. [LENGTH_MISMATCH]
# 			Lemmas: δέ ὁ ὁ πούς χρῆσις , καί ὁ φύσις , ὥσπερ λέγω , καταχράομαι καί πρός ὁ ἀπό ὁ πούς ἐάν βοήθεια οὗτος ὁ .
# 		Example sentence 847 including 'καταχράομαι' in typical context 0:
# 			Tokens: ἡ γὰρ φύσις αὐτὴ καθʼ αὐτὴν, ὤσπερ εἴπομεν, τοῖς κοινοῖς πάέντων μορίοις είς πολλὰ τῶν ἰδίων καταχρῆται, οἷον καὶ ἐπὶ τού στόματος ἢ μὲν τροφὴ πάντων κοινόν, ἡ δʼ ἀλκὴ τινῶν ἰδίον καὶ ὁ λόγος ἑτέρων, ἔτι δὲ τὸ ἀναπνεῖν οὐ πάντων κοινὸν. [LENGTH_MISMATCH]
# 			Lemmas: ὁ γάρ φύσις αὐτός κατά αὐτός , ὥσπερ λέγω , ὁ κοινός μόριον πολύς ὁ ἴδιος καταχράομαι , οἷος καί ἐπί ὁ στόμα ἤ μέν τροφή πᾶς κοινός , ὁ δέ ἀλκή καί ὁ λόγος ἕτερος , ἔτι δέ ὁ ἀναπνέω οὐ πᾶς κοινός .
#
#
# αὐχήν (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 749 including 'αὐχήν' in typical context 0:
# 			Tokens: δίπουν γάρ ἐστι καὶ πτερυγωτὸν, ὧστʼ ἀνάγκη μικρὸν τὸ βάρος ἔχειν τὸ τοῦ αὐχένος καὶ τὸ τῆς κεφαλῆς, ὤσπερ καὶ τὸ στὴθος στενόν· [LENGTH_MISMATCH]
# 			Lemmas: γάρ εἰμί καί , ἀνάγκη μικρός ὁ βάρος ἔχω ὁ ὁ αὐχήν καί ὁ ὁ κεφαλή , καί ὁ στενός ·
# 		Example sentence 922 including 'αὐχήν' in typical context 0:
# 			Tokens: περὶ μὲν οὖν τῶν ἐν τῇ κεφαλῇ μορίων ταύτῃ διωρίσθω, ὑπὸ δὲ τὴν κεφαλὴν ὁ αὐχὴν πεφυκής ἐστι τοῖς ἔχουσιν αὐχένα τῶν ζῷόων. [LENGTH_MISMATCH]
# 			Lemmas: μέν οὖν ὁ ἐν ὁ κεφαλή οὗτος , ὑπό δέ ὁ κεφαλή ὁ αὐχήν εἰμί ὁ ἔχω αὐχήν ὁ .
# 		Example sentence 922 including 'αὐχήν' in typical context 0:
# 			Tokens: περὶ μὲν οὖν τῶν ἐν τῇ κεφαλῇ μορίων ταύτῃ διωρίσθω, ὑπὸ δὲ τὴν κεφαλὴν ὁ αὐχὴν πεφυκής ἐστι τοῖς ἔχουσιν αὐχένα τῶν ζῷόων. [LENGTH_MISMATCH]
# 			Lemmas: μέν οὖν ὁ ἐν ὁ κεφαλή οὗτος , ὑπό δέ ὁ κεφαλή ὁ αὐχήν εἰμί ὁ ἔχω αὐχήν ὁ .
#
#
# ἀφαιρέω (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 920 including 'ἀφαιρέω' in typical context 0:
# 			Tokens: ἀφῄρηται δὲ τὰ κέρατα ταῖς θηλείαις διὰ τὸ χρὴσιμα μὲν μὴ εἶναι μηδὲ τοῖς ἄρρεσιν, βλάπτεσθαι δʼ ἧσσον διἀ τὴν ἰσχύν. [LENGTH_MISMATCH]
# 			Lemmas: ἀφαιρέω δέ ὁ κέρας ὁ θῆλυς διά ὁ μέν μή εἰμί μηδέ ὁ , βλάπτω δέ ἥσσων ὁ ἰσχύς .
# 		Example sentence 918 including 'ἀφαιρέω' in typical context 0:
# 			Tokens: ἀφελοῦσα γὰρ ἐντεύθεν ἡ φύσις τοῖς κέρασι προσέθηκε, καὶ ἡ διδομένη τροφὴ είς τοὺς ὀδόντας τούτους είς τὴν τῶν κεράτων αὔξησιν ἀναλίσκεται. [LENGTH_MISMATCH]
# 			Lemmas: ἀφαιρέω γάρ ὁ φύσις ὁ κέρας προστίθημι , καί ὁ δίδωμι τροφή ὁ ὀδούς οὗτος ὁ ὁ κέρας αὔξησις ἀναλίσκω .
#
#
# γράμμα (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 823 including 'γράμμα' in typical context 0:
# 			Tokens: πολλἀ γὰρ πρὸς τὴν γένεσιν τῶν γραμμάτων οἱ πρὸσθιοι τῶν ὀδόντων συμβάλλονται. [LENGTH_MISMATCH]
# 			Lemmas: γάρ πρός ὁ γένεσις ὁ γράμμα ὁ ὁ ὀδούς συμβάλλω .
# 		Example sentence 771 including 'γράμμα' in typical context 0:
# 			Tokens: ἁπτικωτάτη γαρ, ἡ δὲ γεῦσις ἀρή τίς ἐστιν), καὶ πρὸς τὴν τῶν γραμμάτων διάρθρωσιν καὶ πρὸς τὸν λόγον ἡ μαλακὴ καὶ πλατεῖα χρήσιμος·
# 			Lemmas: , ὁ δέ γεῦσις τις εἰμί ) , καί πρός ὁ ὁ γράμμα διάρθρωσις καί πρός ὁ λόγος ὁ καί πλατύς χρήσιμος ·
# 		Example sentence 762 including 'γράμμα' in typical context 0:
# 			Tokens: ὁ μὲν γὰρ λόγος ὁ διὰ τῆς φωνῆς ἐκ τῶν γραμμάτων σύγκειται, τῆς δὲ γλύόττης μὴ τοιαύτης οὕσης μηδὲ τῶν χειλῶν ὑγρῶν οὐκ ἄν ἦν φθέγγεσθαι τὰ πλεῖστα τῶν γραμμάτων· [LENGTH_MISMATCH]
# 			Lemmas: ὁ μέν γάρ λόγος ὁ διά ὁ φωνή ἐκ ὁ γράμμα σύγκειμαι , ὁ δέ μή τοιοῦτος μηδέ ὁ ὑγρός οὐ ἄν εἰμί φθέγγομαι ὁ πλεῖστος ὁ γράμμα ·
#
#
# διάρθρωσις (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 789 including 'διάρθρωσις' in typical context 0:
# 			Tokens: ἀκανθώόδης τε γάρ ἐστιν ὁ τόπος τού στόματος πἀσι τοῖς τοιούτοις, καὶ διὰ τὸ μικρὸν χρόνον εἶναι τὴν αἴσθησιν τοῖς ἐνύδροις τῶν χυμῶν, ὤσπερ καὶ ἡ χρῆσις αὐτῆς βραχεῖα, οὕτω βραχεῖαν ἔχουσιν αὐτῆς καὶ τὴν διάρθρωσιν. [LENGTH_MISMATCH]
# 			Lemmas: τε γάρ εἰμί ὁ τόπος στόμα ὁ τοιοῦτος , καί διά ὁ μικρός χρόνος εἰμί ὁ αἴσθησις ὁ ὁ , ὥσπερ καί ὁ χρῆσις αὐτός βραχύς , οὕτως βραχύς ἔχω αὐτός καί ὁ διάρθρωσις .
# 		Example sentence 778 including 'διάρθρωσις' in typical context 0:
# 			Tokens: τὰ δʼ ἕναιμα καὶ ζφοτόκα τῶν τετραπόδων βραχεῖαν της ψώνῆς ἔχει διάρθρωσιν· [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ καί ὁ τετράπους βραχύς ἔχω διάρθρωσις ·
#
#
# βραχύς (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 789 including 'βραχύς' in typical context 0:
# 			Tokens: ἀκανθώόδης τε γάρ ἐστιν ὁ τόπος τού στόματος πἀσι τοῖς τοιούτοις, καὶ διὰ τὸ μικρὸν χρόνον εἶναι τὴν αἴσθησιν τοῖς ἐνύδροις τῶν χυμῶν, ὤσπερ καὶ ἡ χρῆσις αὐτῆς βραχεῖα, οὕτω βραχεῖαν ἔχουσιν αὐτῆς καὶ τὴν διάρθρωσιν. [LENGTH_MISMATCH]
# 			Lemmas: τε γάρ εἰμί ὁ τόπος στόμα ὁ τοιοῦτος , καί διά ὁ μικρός χρόνος εἰμί ὁ αἴσθησις ὁ ὁ , ὥσπερ καί ὁ χρῆσις αὐτός βραχύς , οὕτως βραχύς ἔχω αὐτός καί ὁ διάρθρωσις .
# 		Example sentence 789 including 'βραχύς' in typical context 0:
# 			Tokens: ἀκανθώόδης τε γάρ ἐστιν ὁ τόπος τού στόματος πἀσι τοῖς τοιούτοις, καὶ διὰ τὸ μικρὸν χρόνον εἶναι τὴν αἴσθησιν τοῖς ἐνύδροις τῶν χυμῶν, ὤσπερ καὶ ἡ χρῆσις αὐτῆς βραχεῖα, οὕτω βραχεῖαν ἔχουσιν αὐτῆς καὶ τὴν διάρθρωσιν. [LENGTH_MISMATCH]
# 			Lemmas: τε γάρ εἰμί ὁ τόπος στόμα ὁ τοιοῦτος , καί διά ὁ μικρός χρόνος εἰμί ὁ αἴσθησις ὁ ὁ , ὥσπερ καί ὁ χρῆσις αὐτός βραχύς , οὕτως βραχύς ἔχω αὐτός καί ὁ διάρθρωσις .
#
#
# ἀρτηρία (2 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 955 including 'ἀρτηρία' in typical context 0:
# 			Tokens: διʼ ἣν μὲν οὗν αἰτίαν τὰ μὲν ἔχει τῶν ζῴων τὰ δʼ οὐκ ἔχει, ταῦτʼ εἰρήσθω, καὶ διότι τῆς ἀρτηρίας τὴν φαυλότητα τῆς θέσεωος ίάτρευκεν ἡ φύσις, μηχανησαμένη τὴν καλουμένην ἐπιγλωττίδα. [LENGTH_MISMATCH]
# 			Lemmas: διά ὅς μέν αἰτία ὁ μέν ἔχω ὁ ζῷον ὁ δέ οὐ ἔχω , , καί διότι ὁ ἀρτηρία ὁ φαυλότης ὁ ὁ φύσις , ὁ καλέω .
# 		Example sentence 960 including 'ἀρτηρία' in typical context 0:
# 			Tokens: ὥστ ἐπεὶ τὴν καρδίαν ἐν τοῖς ἔμπροσθεν πρώτην ἀναγκαῖον κεῖσθαι, καὶ τὸν φάρυγγα καὶ τὴν ἀρτηρίαν πρὸτερον ἀναγκαῖον κεῖσθαι τού οἰσοφάγου· [LENGTH_MISMATCH]
# 			Lemmas: ἐπεί ὁ καρδία ἐν ὁ πρῶτος ἀναγκαῖον κεῖμαι , καί ὁ φάρυγξ καί ὁ ἀρτηρία ἀναγκαῖος κεῖμαι ·
# 		Example sentence 954 including 'ἀρτηρία' in typical context 0:
# 			Tokens: οὐκ ἔχει δὲ τὰ λεχθέντα ζῴα τὴν ἐπιγλωττίδα διὰ τὸ ξηρὰς εἶναι τὰς σάρκας αύὺτῶν καὶ τὸ δέρμα σκληρόν, ὧστʼ οὐκ ἄν εὐκίνητον ὴν τὸ τοιούτον μόριον αὑτοῖς ἐκ τοιαύτης σαρκὸς καὶ ἐκ τοιούτου δέρματος συνεστηκς, ἀλλʼ αὐτῆς τῆς ἀρτηρίας τήν ἐσχάτων θάσσον ἐγίνετʼ ἄν ἡ συναγωγὴ τῆς ἐκ τῆς οἰκείας σαρκὸς ἐπιγλωττίδος, ἣν ἔχουσι τὰ τριχωτα. [LENGTH_MISMATCH]
# 			Lemmas: οὐ ἔχω δέ ὁ λέγω ὁ διά ὁ ξηρός εἰμί ὁ σάρξ καί ὁ δέρμα σκληρός , εὐκίνητος ὁ μόριον ἑαυτοῦ ἐκ τοιοῦτος σάρξ καί ἐκ τοιοῦτος δέρμα , αὐτός ὁ ἀρτηρία ὁ ἄν ὁ συναγωγή ὁ ἐκ ὁ σάρξ ἐπιγλωσσίς , ὅς ἔχω ὁ .
# 	generalized_context_vector_1:
# 		Example sentence 959 including 'ἀρτηρία' in typical context 1:
# 			Tokens: ἡ δʼ ἀναπνοὴ γίνεται τοῖς ζῴοις διὰ τὴς ἀρτηρίας· [LENGTH_MISMATCH]
# 			Lemmas: ὁ δέ γίγνομαι ὁ διά ἀρτηρία ·
# 		Example sentence 937 including 'ἀρτηρία' in typical context 1:
# 			Tokens: κεῖται δʼ ἔμπροσθεν ἡ ἀρτηρία τοῦ οἰσοφάγου, καίπερ ἐμποδίξουσα αὐτὸν περὶ τὴν ὑποδοχὴν τῆς τροφης· [LENGTH_MISMATCH]
# 			Lemmas: κεῖμαι δέ ἔμπροσθεν ὁ ἀρτηρία ὁ , καίπερ αὐτός περί ὁ ὑποδοχή ὁ ·
#
#
# ποτός (1 cluster/s):
# 	generalized_context_vector_0:
# 		Example sentence 939 including 'ποτός' in typical context 0:
# 			Tokens: ὅ δὴ καὶ θαυμάσειεν ἄν τις τῶν λεγόντων ὡς ταύτῃ τὸ ποτὸν δέχεται τὸ ζῷον·
# 			Lemmas: ὅς δή καί θαυμάζω ἄν τις ὁ λέγω ὡς οὗτος ὁ ποτός δέχομαι ὁ ·
# 		Example sentence 941 including 'ποτός' in typical context 0:
# 			Tokens: πολλαχ δὲ γελοῖον φαίνεται τὸ λέγειν ὡς ταύτῃ τὸ ποτὸν εἰσδέχεται τὰ ζῷα.
# 			Lemmas: δέ γέλοιος φαίνω ὁ λέγω ὡς οὗτος ὁ ποτός εἰσδέχομαι ὁ ζῷον .
